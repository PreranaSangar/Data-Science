# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
company=pd.read_csv(r'C:\Users\admin\Downloads\archive\spend_analysis_dataset.csv')

# %%
company
# Out:
#     TransactionID                 ItemName         Category  Quantity  \
# 0          TXN001               Desk Chair        Furniture        10
# 1          TXN002                  Stapler  Office Supplies        16
# 2          TXN003  Annual Software License         Software         1
# 3          TXN004                  Notepad       Stationery        13
# 4          TXN005                  Notepad       Stationery        19
# ..            ...                      ...              ...       ...
# 495        TXN496               Whiteboard        Furniture        19
# 496        TXN497                   Laptop      Electronics         5
# 497        TXN498                  Notepad       Stationery         3
# 498        TXN499               Whiteboard        Furniture        17
# 499        TXN500                  Stapler  Office Supplies         4
#
#      UnitPrice  TotalCost PurchaseDate            Supplier            Buyer
# ...

# %%
company.shape
# Out:
# (500, 9)

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  500 non-null    object
#  1   ItemName       500 non-null    object
#  2   Category       500 non-null    object
#  3   Quantity       500 non-null    int64
#  4   UnitPrice      500 non-null    float64
#  5   TotalCost      500 non-null    float64
#  6   PurchaseDate   500 non-null    object
#  7   Supplier       500 non-null    object
#  8   Buyer          500 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 35.3+ KB

# %%
company.isnull().sum()
# Out:
# TransactionID    0
# ItemName         0
# Category         0
# Quantity         0
# UnitPrice        0
# TotalCost        0
# PurchaseDate     0
# Supplier         0
# Buyer            0
# dtype: int64

# %%
company.dtypes
# Out:
# TransactionID     object
# ItemName          object
# Category          object
# Quantity           int64
# UnitPrice        float64
# TotalCost        float64
# PurchaseDate      object
# Supplier          object
# Buyer             object
# dtype: object

# %%
company.columns
# Out:
# Index(['TransactionID', 'ItemName', 'Category', 'Quantity', 'UnitPrice',
#        'TotalCost', 'PurchaseDate', 'Supplier', 'Buyer'],
#       dtype='object')

# %%
len(company.columns)
# Out:
# 9

# %%
company.describe()
# Out:
#          Quantity    UnitPrice    TotalCost
# count  500.000000   500.000000    500.00000
# mean     9.640000   854.245100   2481.16106
# std      6.168834  2132.890832   3527.35316
# min      1.000000     1.060000      1.56000
# 25%      4.000000    14.380000    145.92750
# 50%     10.000000   143.595000    918.56000
# 75%     15.000000   287.925000   3123.56750
# max     20.000000  9909.240000  18494.60000

# %%
company.describe().transpose()
# Out:
#            count        mean          std   min       25%      50%        75%  \
# Quantity   500.0     9.64000     6.168834  1.00    4.0000   10.000    15.0000
# UnitPrice  500.0   854.24510  2132.890832  1.06   14.3800  143.595   287.9250
# TotalCost  500.0  2481.16106  3527.353160  1.56  145.9275  918.560  3123.5675
#
#                 max
# Quantity      20.00
# UnitPrice   9909.24
# TotalCost  18494.60

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.distplot(company.Quantity,color='m',bins=10)
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
sns.distplot(company.UnitPrice,color='c',bins=10)
# Out:
# <Axes: xlabel='UnitPrice', ylabel='Density'>

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.countplot(data=company,x='ItemName',palette='dark')
# Out:
# <Axes: xlabel='ItemName', ylabel='count'>

# %%
sns.countplot(data=company,x='Category',palette='rocket')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(data=company,x='Supplier',palette='Set1')
# Out:
# <Axes: xlabel='Supplier', ylabel='count'>

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.countplot(data=company,x='ItemName',hue='Category',palette='magma')
# Out:
# <Axes: xlabel='ItemName', ylabel='count'>

# %%
sns.countplot(data=company,x='Category',hue='Supplier',palette='cividis')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(data=company,x='Supplier',hue='ItemName',palette='dark')
# Out:
# <Axes: xlabel='Supplier', ylabel='count'>

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.lmplot(data=company,x='Quantity',y='UnitPrice',palette='mako',hue='ItemName')

# %%
sns.lmplot(data=company,x='Quantity',y='UnitPrice',palette='dark',hue='Category')

# %%
sns.lmplot(data=company,x='Quantity',y='UnitPrice',palette='Set1',hue='Supplier')

# %%
sns.lmplot(data=company,x='UnitPrice',y='TotalCost',palette='colorblind',hue='ItemName')

# %%
sns.lmplot(data=company,x='TotalCost',y='Quantity',palette='rocket',hue='ItemName')

# %%
sns.lmplot(data=company,x='UnitPrice',y='TotalCost',palette='deep',hue='Category')

# %%
sns.lmplot(data=company,x='UnitPrice',y='TotalCost',palette='cividis',hue='Supplier')

# %%
sns.lmplot(data=company,x='TotalCost',y='Quantity',palette='magma',hue='Category')

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.jointplot(data=company,x='Quantity',y='UnitPrice',color='m',kind='hex')

# %%
sns.jointplot(data=company,x='UnitPrice',y='TotalCost',color='c',kind='hex')

# %%
sns.jointplot(data=company,x='TotalCost',y='Quantity',color='g',kind='hex')

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.boxenplot(data=company,x='ItemName',y='Quantity',palette='colorblind')
# Out:
# <Axes: xlabel='ItemName', ylabel='Quantity'>

# %%
sns.boxenplot(data=company,x='Category',y='UnitPrice',palette='hls')
# Out:
# <Axes: xlabel='Category', ylabel='UnitPrice'>

# %%
sns.boxenplot(data=company,x='Supplier',y='TotalCost',palette='dark')
# Out:
# <Axes: xlabel='Supplier', ylabel='TotalCost'>

# %%
sns.boxenplot(data=company,x='ItemName',y='UnitPrice',palette='magma')
# Out:
# <Axes: xlabel='ItemName', ylabel='UnitPrice'>

# %%
sns.boxenplot(data=company,x='Category',y='TotalCost',palette='Dark2')
# Out:
# <Axes: xlabel='Category', ylabel='TotalCost'>

# %%
sns.boxenplot(data=company,x='Supplier',y='Quantity',palette='cividis')
# Out:
# <Axes: xlabel='Supplier', ylabel='Quantity'>

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.stripplot(data=company,x='ItemName',y='Quantity',palette='dark')
# Out:
# <Axes: xlabel='ItemName', ylabel='Quantity'>

# %%
sns.stripplot(data=company,x='Category',y='UnitPrice',palette='tab20')
# Out:
# <Axes: xlabel='Category', ylabel='UnitPrice'>

# %%
sns.stripplot(data=company,x='Supplier',y='TotalCost',palette='mako')
# Out:
# <Axes: xlabel='Supplier', ylabel='TotalCost'>

# %%
sns.stripplot(data=company,x='ItemName',y='UnitPrice',palette='colorblind')
# Out:
# <Axes: xlabel='ItemName', ylabel='UnitPrice'>

# %%
sns.stripplot(data=company,x='Category',y='TotalCost',palette='rocket')
# Out:
# <Axes: xlabel='Category', ylabel='TotalCost'>

# %%
sns.stripplot(data=company,x='Supplier',y='Quantity',palette='Set1')
# Out:
# <Axes: xlabel='Supplier', ylabel='Quantity'>

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.kdeplot(data=company,x='Quantity',hue='ItemName',palette='dark',fill=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
sns.kdeplot(data=company,x='UnitPrice',hue='Category',palette='mako',fill=True)
# Out:
# <Axes: xlabel='UnitPrice', ylabel='Density'>

# %%
sns.kdeplot(data=company,x='TotalCost',hue='Supplier',palette='cividis',fill=True)
# Out:
# <Axes: xlabel='TotalCost', ylabel='Density'>

# %%
sns.kdeplot(data=company,x='TotalCost',hue='ItemName',palette='colorblind',fill=True)
# Out:
# <Axes: xlabel='TotalCost', ylabel='Density'>

# %%
sns.kdeplot(data=company,x='Quantity',hue='Category',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
sns.kdeplot(data=company,x='UnitPrice',hue='Supplier',palette='bright',fill=True)
# Out:
# <Axes: xlabel='UnitPrice', ylabel='Density'>

# %%
company.head()
# Out:
#   TransactionID                 ItemName         Category  Quantity  \
# 0        TXN001               Desk Chair        Furniture        10
# 1        TXN002                  Stapler  Office Supplies        16
# 2        TXN003  Annual Software License         Software         1
# 3        TXN004                  Notepad       Stationery        13
# 4        TXN005                  Notepad       Stationery        19
#
#    UnitPrice  TotalCost PurchaseDate         Supplier            Buyer
# 0     113.15    1131.50   2024-04-19    TechMart Inc.     Kelly Joseph
# 1      12.62     201.92   2024-07-06  CloudSoft Corp.     Kelly Joseph
# 2    5649.34    5649.34   2024-09-10    TechMart Inc.     Kelly Joseph
# 3       2.92      37.96   2024-01-21  FurniWorks Ltd.     Luis Holland
# 4       1.39      26.41   2024-02-03    TechMart Inc.  Cynthia Jenkins

# %%
sns.pairplot(company, hue="ItemName",palette='rocket')

# %%
sns.pairplot(company, hue="Category",palette='dark')

# %%
sns.pairplot(company, hue="Supplier",palette='Set1')
