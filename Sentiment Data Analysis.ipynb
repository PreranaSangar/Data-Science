# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=7,3
sns.set_theme(style="whitegrid", palette="deep")

# %%
sentiment=pd.read_csv(r'C:\Users\admin\Downloads\archive\sentimentdataset.csv')

# %%
sentiment
# Out:
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# 728  Attending a surprise birthday party organized ...       Happy
# 729  Successfully fundraising for a school charity ...       Happy
# 730  Participating in a multicultural festival, cel...       Happy
# 731  Organizing a virtual talent show during challe...       Happy
#
#             Timestamp                                   User     Platform  \
# 0    15-01-2023 12:30                          User123          Twitter
# ...

# %%
sentiment.shape
# Out:
# (732, 13)

# %%
sentiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       732 non-null    object
#  1   Sentiment  732 non-null    object
#  2   Timestamp  732 non-null    object
#  3   User       732 non-null    object
#  4   Platform   732 non-null    object
#  5   Hashtags   732 non-null    object
#  6   Retweets   732 non-null    int64
#  7   Likes      732 non-null    int64
#  8   Country    732 non-null    object
#  9   Year       732 non-null    int64
#  10  Month      732 non-null    int64
#  11  Day        732 non-null    int64
#  12  Hour       732 non-null    int64
# dtypes: int64(6), object(7)
# memory usage: 74.5+ KB

# %%
sentiment.isnull().sum()
# Out:
# Text         0
# Sentiment    0
# Timestamp    0
# User         0
# Platform     0
# Hashtags     0
# Retweets     0
# Likes        0
# Country      0
# Year         0
# Month        0
# Day          0
# Hour         0
# dtype: int64

# %%
sentiment.columns
# Out:
# Index(['Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour'],
#       dtype='object')

# %%
len(sentiment.columns)
# Out:
# 13

# %%
sentiment.describe()
# Out:
#          Retweets       Likes         Year       Month         Day        Hour
# count  732.000000  732.000000   732.000000  732.000000  732.000000  732.000000
# mean    21.508197   42.901639  2020.471311    6.122951   15.497268   15.521858
# std      7.061286   14.089848     2.802285    3.411763    8.474553    4.113414
# min      5.000000   10.000000  2010.000000    1.000000    1.000000    0.000000
# 25%     17.750000   34.750000  2019.000000    3.000000    9.000000   13.000000
# 50%     22.000000   43.000000  2021.000000    6.000000   15.000000   16.000000
# 75%     25.000000   50.000000  2023.000000    9.000000   22.000000   19.000000
# max     40.000000   80.000000  2023.000000   12.000000   31.000000   23.000000

# %%
sentiment.describe().transpose()
# Out:
#           count         mean        std     min      25%     50%     75%  \
# Retweets  732.0    21.508197   7.061286     5.0    17.75    22.0    25.0
# Likes     732.0    42.901639  14.089848    10.0    34.75    43.0    50.0
# Year      732.0  2020.471311   2.802285  2010.0  2019.00  2021.0  2023.0
# Month     732.0     6.122951   3.411763     1.0     3.00     6.0     9.0
# Day       732.0    15.497268   8.474553     1.0     9.00    15.0    22.0
# Hour      732.0    15.521858   4.113414     0.0    13.00    16.0    19.0
#
#              max
# Retweets    40.0
# Likes       80.0
# Year      2023.0
# Month       12.0
# Day         31.0
# Hour        23.0

# %%
sentiment.dtypes
# Out:
# Text         object
# Sentiment    object
# Timestamp    object
# User         object
# Platform     object
# Hashtags     object
# Retweets      int64
# Likes         int64
# Country      object
# Year          int64
# Month         int64
# Day           int64
# Hour          int64
# dtype: object

# %%
sentiment.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10     Canada
# ...

# %%
sns.distplot(sentiment.Retweets,color='r',bins=10)
# Out:
# <Axes: xlabel='Retweets', ylabel='Density'>

# %%
sns.distplot(sentiment.Likes,color='b',bins=10)
# Out:
# <Axes: xlabel='Likes', ylabel='Density'>

# %%
sns.distplot(sentiment.Year,color='k',bins=10)
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.distplot(sentiment.Month,color='m',bins=10)
# Out:
# <Axes: xlabel='Month', ylabel='Density'>

# %%
sns.distplot(sentiment.Day,color='orange',bins=10)
# Out:
# <Axes: xlabel='Day', ylabel='Density'>

# %%
sns.distplot(sentiment.Hour,color='g',bins=10)
# Out:
# <Axes: xlabel='Hour', ylabel='Density'>

# %%
sentiment.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10     Canada
# ...

# %%
sns.countplot(data=sentiment,x='Platform',palette='Dark2')
# Out:
# <Axes: xlabel='Platform', ylabel='count'>

# %%
sentiment.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10     Canada
# ...

# %%
sns.lmplot(data=sentiment,x='Retweets',y='Likes',palette='mako',hue='Platform')

# %%
sns.lmplot(data=sentiment,x='Likes',y='Year',palette='colorblind',hue='Platform')

# %%
sns.lmplot(data=sentiment,x='Year',y='Month',palette='hls',hue='Platform')

# %%
sns.lmplot(data=sentiment,x='Month',y='Day',palette='dark',hue='Platform')

# %%
sns.lmplot(data=sentiment,x='Day',y='Hour',palette='rocket',hue='Platform')

# %%
sns.lmplot(data=sentiment,x='Hour',y='Retweets',palette='cividis',hue='Platform')

# %%
sns.lmplot(data=sentiment,x='Retweets',y='Year',palette='Dark2',hue='Platform')

# %%
sentiment.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10     Canada
# ...

# %%
sns.jointplot(data=sentiment,x='Retweets',y='Likes',color='c',kind='hex')

# %%
sns.jointplot(data=sentiment,x='Likes',y='Year',color='r',kind='resid')

# %%
sns.jointplot(data=sentiment,x='Year',y='Month',color='g',kind='scatter')

# %%
sns.jointplot(data=sentiment,x='Month',y='Day',color='m',kind='hex')

# %%
sns.jointplot(data=sentiment,x='Day',y='Hour',color='k',kind='resid')

# %%
sns.jointplot(data=sentiment,x='Hour',y='Retweets',color='purple',kind='resid')

# %%
sentiment.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10     Canada
# ...

# %%
sns.stripplot(data=sentiment,x='Platform',y='Retweets',palette='dark')
# Out:
# <Axes: xlabel='Platform', ylabel='Retweets'>

# %%
sns.stripplot(data=sentiment,x='Platform',y='Likes',palette='hls')
# Out:
# <Axes: xlabel='Platform', ylabel='Likes'>

# %%
sns.stripplot(data=sentiment,x='Platform',y='Year',palette='deep')
# Out:
# <Axes: xlabel='Platform', ylabel='Year'>

# %%
sns.stripplot(data=sentiment,x='Platform',y='Month',palette='mako')
# Out:
# <Axes: xlabel='Platform', ylabel='Month'>

# %%
sns.stripplot(data=sentiment,x='Platform',y='Day',palette='rocket')
# Out:
# <Axes: xlabel='Platform', ylabel='Day'>

# %%
sns.stripplot(data=sentiment,x='Platform',y='Hour',palette='cividis')
# Out:
# <Axes: xlabel='Platform', ylabel='Hour'>

# %%
sentiment.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10     Canada
# ...

# %%
sns.boxplot(data=sentiment,x='Platform',y='Retweets',palette='colorblind')
# Out:
# <Axes: xlabel='Platform', ylabel='Retweets'>

# %%
sns.boxplot(data=sentiment,x='Platform',y='Likes',palette='dark')
# Out:
# <Axes: xlabel='Platform', ylabel='Likes'>

# %%
sns.boxplot(data=sentiment,x='Platform',y='Year',palette='hls')
# Out:
# <Axes: xlabel='Platform', ylabel='Year'>

# %%
sns.boxplot(data=sentiment,x='Platform',y='Month',palette='bright')
# Out:
# <Axes: xlabel='Platform', ylabel='Month'>

# %%
sns.boxplot(data=sentiment,x='Platform',y='Day',palette='Set2')
# Out:
# <Axes: xlabel='Platform', ylabel='Day'>

# %%
sns.boxplot(data=sentiment,x='Platform',y='Hour',palette='Dark2')
# Out:
# <Axes: xlabel='Platform', ylabel='Hour'>

# %%
sentiment.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10     Canada
# ...

# %%
sns.kdeplot(data=sentiment,x='Retweets',hue='Platform',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='Retweets', ylabel='Density'>

# %%
sns.kdeplot(data=sentiment,x='Likes',hue='Platform',palette='dark',fill=True)
# Out:
# <Axes: xlabel='Likes', ylabel='Density'>

# %%
sns.kdeplot(data=sentiment,x='Year',hue='Platform',palette='mako',fill=True)
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.kdeplot(data=sentiment,x='Month',hue='Platform',palette='deep',fill=True)
# Out:
# <Axes: xlabel='Month', ylabel='Density'>

# %%
sns.kdeplot(data=sentiment,x='Day',hue='Platform',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='Day', ylabel='Density'>

# %%
sns.kdeplot(data=sentiment,x='Hour',hue='Platform',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Hour', ylabel='Density'>
