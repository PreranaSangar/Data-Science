# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=10,5

# %%
Time=pd.read_csv(r'C:\Users\admin\Downloads\archive\screen_time.csv')

# %%
Time
# Out:
#      Age                   Gender Screen Time Type Day Type  \
# 0      5                     Male      Educational  Weekday
# 1      5                     Male     Recreational  Weekday
# 2      5                     Male            Total  Weekday
# 3      5                     Male      Educational  Weekend
# 4      5                     Male     Recreational  Weekend
# ..   ...                      ...              ...      ...
# 193   15  Other/Prefer not to say     Recreational  Weekday
# 194   15  Other/Prefer not to say            Total  Weekday
# 195   15  Other/Prefer not to say      Educational  Weekend
# 196   15  Other/Prefer not to say     Recreational  Weekend
# 197   15  Other/Prefer not to say            Total  Weekend
#
#      Average Screen Time (hours)  Sample Size
# 0                           0.44          500
# 1                           1.11          500
# 2                           1.55          500
# 3                           0.50          500
# ...

# %%
Time.shape
# Out:
# (198, 6)

# %%
Time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          198 non-null    int64
#  1   Gender                       198 non-null    object
#  2   Screen Time Type             198 non-null    object
#  3   Day Type                     198 non-null    object
#  4   Average Screen Time (hours)  198 non-null    float64
#  5   Sample Size                  198 non-null    int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.4+ KB

# %%
Time.tail()
# Out:
#      Age                   Gender Screen Time Type Day Type  \
# 193   15  Other/Prefer not to say     Recreational  Weekday
# 194   15  Other/Prefer not to say            Total  Weekday
# 195   15  Other/Prefer not to say      Educational  Weekend
# 196   15  Other/Prefer not to say     Recreational  Weekend
# 197   15  Other/Prefer not to say            Total  Weekend
#
#      Average Screen Time (hours)  Sample Size
# 193                         5.16          300
# 194                         6.50          300
# 195                         2.19          300
# 196                         5.77          300
# 197                         7.96          300

# %%
Time.dtypes
# Out:
# Age                              int64
# Gender                          object
# Screen Time Type                object
# Day Type                        object
# Average Screen Time (hours)    float64
# Sample Size                      int64
# dtype: object

# %%
Time.columns
# Out:
# Index(['Age', 'Gender', 'Screen Time Type', 'Day Type',
#        'Average Screen Time (hours)', 'Sample Size'],
#       dtype='object')

# %%
len(Time.columns)
# Out:
# 6

# %%
Time.describe()
# Out:
#               Age  Average Screen Time (hours)  Sample Size
# count  198.000000                   198.000000   198.000000
# mean    10.000000                     2.993030   400.000000
# std      3.170294                     1.922822    63.405872
# min      5.000000                     0.440000   300.000000
# 25%      7.000000                     1.402500   340.000000
# 50%     10.000000                     2.490000   400.000000
# 75%     13.000000                     4.397500   460.000000
# max     15.000000                     8.190000   500.000000

# %%
Time.describe().transpose()
# Out:
#                              count       mean        std     min       25%  \
# Age                          198.0   10.00000   3.170294    5.00    7.0000
# Average Screen Time (hours)  198.0    2.99303   1.922822    0.44    1.4025
# Sample Size                  198.0  400.00000  63.405872  300.00  340.0000
#
#                                 50%       75%     max
# Age                           10.00   13.0000   15.00
# Average Screen Time (hours)    2.49    4.3975    8.19
# Sample Size                  400.00  460.0000  500.00

# %%
Time.isnull().sum()
# Out:
# Age                            0
# Gender                         0
# Screen Time Type               0
# Day Type                       0
# Average Screen Time (hours)    0
# Sample Size                    0
# dtype: int64

# %%
Time.columns=['Age', 'Gender', 'Screen_Time_Type', 'Day_Type','Average_Screen_Time_hours', 'Sample_Size']

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
plt.plot(Time.Age,color='r',marker='*')

# %%
plt.plot(Time.Average_Screen_Time_hours,color='g',marker='*')

# %%
plt.plot(Time.Sample_Size,color='c',marker='8')

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
sns.boxplot(Time.Average_Screen_Time_hours,color='m')
# Out:
# <Axes: ylabel='Average_Screen_Time_hours'>

# %%
sns.boxplot(Time.Sample_Size,color='y')
# Out:
# <Axes: ylabel='Sample_Size'>

# %%
sns.countplot(data=Time,x='Screen_Time_Type',palette="Set1")
# Out:
# <Axes: xlabel='Screen_Time_Type', ylabel='count'>

# %%
sns.catplot(data=Time,x='Screen_Time_Type',palette="Set2")

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
sns.countplot(data=Time,x='Age',palette="Set1")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=Time,x='Day_Type',palette="Set2")
# Out:
# <Axes: xlabel='Day_Type', ylabel='count'>

# %%
sns.countplot(data=Time,x='Gender',palette="ch:.25")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=Time,x='Gender',hue='Day_Type',palette="ch:.60")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
sns.countplot(data=Time,x='Screen_Time_Type',palette="Set2",hue='Gender')
# Out:
# <Axes: xlabel='Screen_Time_Type', ylabel='count'>

# %%
sns.countplot(data=Time,x='Age',palette="ch:.10",hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.boxplot(data=Time,x='Gender',y='Age',fill=False,color='m')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
sns.boxplot(data=Time,x='Day_Type',y='Average_Screen_Time_hours',fill=False,color='y')
# Out:
# <Axes: xlabel='Day_Type', ylabel='Average_Screen_Time_hours'>

# %%
sns.boxplot(data=Time,x='Gender',y='Average_Screen_Time_hours',color='r')
# Out:
# <Axes: xlabel='Gender', ylabel='Average_Screen_Time_hours'>

# %%
sns.boxplot(data=Time,x='Age',y='Average_Screen_Time_hours',color='g')
# Out:
# <Axes: xlabel='Age', ylabel='Average_Screen_Time_hours'>

# %%
sns.distplot(Time.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(Time.Average_Screen_Time_hours,color='k',bins=10)
# Out:
# <Axes: xlabel='Average_Screen_Time_hours', ylabel='Density'>

# %%
sns.distplot(Time.Sample_Size,color='g',bins=10)
# Out:
# <Axes: xlabel='Sample_Size', ylabel='Density'>

# %%
sns.displot(Time.Sample_Size,color='m')

# %%
sns.displot(Time.Average_Screen_Time_hours,color='c')

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
sns.violinplot(data=Time,x='Day_Type',y='Average_Screen_Time_hours',fill=False,color='b')
# Out:
# <Axes: xlabel='Day_Type', ylabel='Average_Screen_Time_hours'>

# %%
sns.violinplot(data=Time,x='Age',y='Average_Screen_Time_hours',color='c')
# Out:
# <Axes: xlabel='Age', ylabel='Average_Screen_Time_hours'>

# %%
sns.violinplot(data=Time,x='Gender',y='Average_Screen_Time_hours',fill=False,color='k')
# Out:
# <Axes: xlabel='Gender', ylabel='Average_Screen_Time_hours'>

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
sns.lmplot(data=Time,x='Age',y='Average_Screen_Time_hours',hue='Gender')

# %%
sns.lmplot(data=Time,x='Age',y='Sample_Size',hue='Screen_Time_Type')

# %%
sns.lmplot(data=Time,x='Age',y='Average_Screen_Time_hours',hue='Screen_Time_Type')

# %%
sns.lmplot(data=Time,x='Age',y='Average_Screen_Time_hours',hue='Day_Type')

# %%
sns.jointplot(data=Time,x='Age',y='Average_Screen_Time_hours',hue='Day_Type',kind='hist')

# %%
sns.jointplot(data=Time,x='Age',y='Average_Screen_Time_hours',kind='hex',color='m')

# %%
sns.jointplot(data=Time,x='Age',y='Sample_Size',hue='Screen_Time_Type',color='r')

# %%
sns.jointplot(data=Time,x='Age',y='Average_Screen_Time_hours',kind='reg',color='k')

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
sns.barplot(data=Time,x='Gender',y='Average_Screen_Time_hours',color='y')
# Out:
# <Axes: xlabel='Gender', ylabel='Average_Screen_Time_hours'>

# %%
sns.barplot(data=Time,x='Screen_Time_Type',y='Average_Screen_Time_hours',color='c')
# Out:
# <Axes: xlabel='Screen_Time_Type', ylabel='Average_Screen_Time_hours'>

# %%
Time.head()
# Out:
#    Age Gender Screen_Time_Type Day_Type  Average_Screen_Time_hours  \
# 0    5   Male      Educational  Weekday                       0.44
# 1    5   Male     Recreational  Weekday                       1.11
# 2    5   Male            Total  Weekday                       1.55
# 3    5   Male      Educational  Weekend                       0.50
# 4    5   Male     Recreational  Weekend                       1.44
#
#    Sample_Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
sns.kdeplot(data=Time,x='Average_Screen_Time_hours',color='k',fill=True)
# Out:
# <Axes: xlabel='Average_Screen_Time_hours', ylabel='Density'>

# %%
sns.kdeplot(data=Time,x='Age',color='b',fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=Time,x='Sample_Size',color='m',fill=True)
# Out:
# <Axes: xlabel='Sample_Size', ylabel='Density'>

# %%
Scren_Time = Time.select_dtypes(include=['number'])

# Set figure size
fig = plt.figure(figsize=(10, 7))

# Plot heatmap
sns.heatmap(Scren_Time.corr(), annot=True, cmap='cubehelix', linewidths=1, 
            linecolor='k', square=True, vmin=-1, vmax=1, 
            cbar_kws={"orientation": "vertical"}, cbar=True)
# Out:
# <Axes: >

# %%
sns.kdeplot(data=Time,x='Age',y='Average_Screen_Time_hours',shade = True,shade_lowest=False,cmap='inferno')
# Out:
# <Axes: xlabel='Age', ylabel='Average_Screen_Time_hours'>

# %%
sns.kdeplot(data=Time,x='Age',y='Average_Screen_Time_hours',shade = True,shade_lowest=False,cmap='PuRd')
# Out:
# <Axes: xlabel='Age', ylabel='Average_Screen_Time_hours'>

# %%
sns.kdeplot(data=Time,x='Age',y='Average_Screen_Time_hours',shade = True,shade_lowest=False,cmap='Spectral')
# Out:
# <Axes: xlabel='Age', ylabel='Average_Screen_Time_hours'>
