# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r'D:\ExcelR Data Science\July\July 9\Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score
# 0             1    Male   19                  15               39
# 1             2    Male   21                  15               81
# 2             3  Female   20                  16                6
# 3             4  Female   23                  16               77
# 4             5  Female   31                  17               40
# ..          ...     ...  ...                 ...              ...
# 195         196  Female   35                 120               79
# 196         197  Female   45                 126               28
# 197         198    Male   32                 126               74
# 198         199    Male   32                 137               18
# 199         200    Male   30                 137               83
#
# [200 rows x 5 columns]

# %%
df.columns=['CustomerID','Gender','Age','Annual_Income','Spending_Score']
df
# Out:
#      CustomerID  Gender  Age  Annual_Income  Spending_Score
# 0             1    Male   19             15              39
# 1             2    Male   21             15              81
# 2             3  Female   20             16               6
# 3             4  Female   23             16              77
# 4             5  Female   31             17              40
# ..          ...     ...  ...            ...             ...
# 195         196  Female   35            120              79
# 196         197  Female   45            126              28
# 197         198    Male   32            126              74
# 198         199    Male   32            137              18
# 199         200    Male   30            137              83
#
# [200 rows x 5 columns]

# %%
sns.distplot(df['Annual_Income'],color='hotpink')
# Out:
# <Axes: xlabel='Annual_Income', ylabel='Density'>

# %%
from scipy.stats import skew
print("skew of the raw data %f"%df['Annual_Income'].skew())
# Out:
# skew of the raw data 0.321843

# %%
from scipy.stats import kurtosis
print("skew of the raw data %f"%df['Annual_Income'].kurtosis())
# Out:
# skew of the raw data -0.098487

# %%
sns.distplot(df['Spending_Score'],color='lightgreen')
# Out:
# <Axes: xlabel='Spending_Score', ylabel='Density'>

# %%
print("skew of the raw data %f"%df['Spending_Score'].skew())
# Out:
# skew of the raw data -0.047220

# %%
print("skew of the raw data %f"%df['Spending_Score'].kurtosis())
# Out:
# skew of the raw data -0.826629

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual_Income  Spending_Score
# count  200.000000  200.000000     200.000000      200.000000
# mean   100.500000   38.850000      60.560000       50.200000
# std     57.879185   13.969007      26.264721       25.823522
# min      1.000000   18.000000      15.000000        1.000000
# 25%     50.750000   28.750000      41.500000       34.750000
# 50%    100.500000   36.000000      61.500000       50.000000
# 75%    150.250000   49.000000      78.000000       73.000000
# max    200.000000   70.000000     137.000000       99.000000

# %%
sns.distplot(df['Annual_Income'],hist=False,color='darkred')
# Out:
# <Axes: xlabel='Annual_Income', ylabel='Density'>

# %%
sns.distplot(df['Spending_Score'],hist=False,color='m')
# Out:
# <Axes: xlabel='Spending_Score', ylabel='Density'>
