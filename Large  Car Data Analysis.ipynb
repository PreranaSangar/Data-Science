# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
car=pd.read_csv(r'C:\Users\admin\Downloads\archive\Large Cars Dataset.csv')

# %%
car
# Out:
#      Brand                    Model VehicleClass  Region DriveTrain      MSRP  \
# 0    Acura                      MDX          SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr        Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr        Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr        Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr        Sedan    Asia      Front  $43,755
# ..     ...                      ...          ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr        Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr        Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr        Sedan  Europe      Front  $45,210
# 426  Volvo                      V40        Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70        Wagon  Europe        All  $35,145
#
# ...

# %%
car.shape
# Out:
# (428, 15)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         428 non-null    object
#  1   Model         428 non-null    object
#  2   VehicleClass  428 non-null    object
#  3   Region        428 non-null    object
#  4   DriveTrain    428 non-null    object
#  5   MSRP          428 non-null    object
#  6   DealerCost    428 non-null    object
#  7   EngineSize    428 non-null    float64
#  8   Cylinders     426 non-null    float64
#  9   HorsePower    428 non-null    int64
#  10  MPG_City      428 non-null    int64
#  11  MPG_Highway   428 non-null    int64
#  12  Weight        428 non-null    int64
#  13  Wheelbase     428 non-null    int64
#  14  Length        428 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.3+ KB

# %%
car.isnull().sum()
# Out:
# Brand           0
# Model           0
# VehicleClass    0
# Region          0
# DriveTrain      0
# MSRP            0
# DealerCost      0
# EngineSize      0
# Cylinders       2
# HorsePower      0
# MPG_City        0
# MPG_Highway     0
# Weight          0
# Wheelbase       0
# Length          0
# dtype: int64

# %%
car.dtypes
# Out:
# Brand            object
# Model            object
# VehicleClass     object
# Region           object
# DriveTrain       object
# MSRP             object
# DealerCost       object
# EngineSize      float64
# Cylinders       float64
# HorsePower        int64
# MPG_City          int64
# MPG_Highway       int64
# Weight            int64
# Wheelbase         int64
# Length            int64
# dtype: object

# %%
car.columns
# Out:
# Index(['Brand', 'Model', 'VehicleClass', 'Region', 'DriveTrain', 'MSRP',
#        'DealerCost', 'EngineSize', 'Cylinders', 'HorsePower', 'MPG_City',
#        'MPG_Highway', 'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
len(car.columns)
# Out:
# 15

# %%
car.describe()
# Out:
#        EngineSize   Cylinders  HorsePower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
car.describe().transpose()
# Out:
#              count         mean         std     min       25%     50%  \
# EngineSize   428.0     3.196729    1.108595     1.3     2.375     3.0
# Cylinders    426.0     5.807512    1.558443     3.0     4.000     6.0
# HorsePower   428.0   215.885514   71.836032    73.0   165.000   210.0
# MPG_City     428.0    20.060748    5.238218    10.0    17.000    19.0
# MPG_Highway  428.0    26.843458    5.741201    12.0    24.000    26.0
# Weight       428.0  3577.953271  758.983215  1850.0  3104.000  3474.5
# Wheelbase    428.0   108.154206    8.311813    89.0   103.000   107.0
# Length       428.0   186.362150   14.357991   143.0   178.000   187.0
#
#                  75%     max
# EngineSize      3.90     8.3
# Cylinders       6.00    12.0
# HorsePower    255.00   500.0
# MPG_City       21.25    60.0
# MPG_Highway    29.00    66.0
# Weight       3977.75  7190.0
# Wheelbase     112.00   144.0
# Length        194.00   238.0

# %%
car.tail()
# Out:
#      Brand                    Model VehicleClass  Region DriveTrain      MSRP  \
# 423  Volvo  C70 LPT convertible 2dr        Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr        Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr        Sedan  Europe      Front  $45,210
# 426  Volvo                      V40        Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70        Wagon  Europe        All  $35,145
#
#     DealerCost  EngineSize  Cylinders  HorsePower  MPG_City  MPG_Highway  \
# 423   $38,203          2.4        5.0         197        21           28
# 424   $40,083          2.3        5.0         242        20           26
# 425   $42,573          2.9        6.0         268        19           26
# 426   $24,641          1.9        4.0         170        22           29
# 427   $33,112          2.5        5.0         208        20           27
#
#      Weight  Wheelbase  Length
# ...

# %%
car.head()
# Out:
#    Brand           Model VehicleClass Region DriveTrain      MSRP DealerCost  \
# 0  Acura             MDX          SUV   Asia        All  $36,945    $33,337
# 1  Acura  RSX Type S 2dr        Sedan   Asia      Front  $23,820    $21,761
# 2  Acura         TSX 4dr        Sedan   Asia      Front  $26,990    $24,647
# 3  Acura          TL 4dr        Sedan   Asia      Front  $33,195    $30,299
# 4  Acura      3.5 RL 4dr        Sedan   Asia      Front  $43,755    $39,014
#
#    EngineSize  Cylinders  HorsePower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# ...

# %%
sns.distplot(car.EngineSize,color='m',bins=10)
# Out:
# <Axes: xlabel='EngineSize', ylabel='Density'>

# %%
sns.distplot(car.Cylinders,color='k',bins=10)
# Out:
# <Axes: xlabel='Cylinders', ylabel='Density'>

# %%
sns.distplot(car.HorsePower,color='b',bins=10)
# Out:
# <Axes: xlabel='HorsePower', ylabel='Density'>

# %%
sns.distplot(car.MPG_City,color='g',bins=10)
# Out:
# <Axes: xlabel='MPG_City', ylabel='Density'>

# %%
sns.distplot(car.MPG_Highway,color='r',bins=10)
# Out:
# <Axes: xlabel='MPG_Highway', ylabel='Density'>

# %%
car.head()
# Out:
#    Brand           Model VehicleClass Region DriveTrain      MSRP DealerCost  \
# 0  Acura             MDX          SUV   Asia        All  $36,945    $33,337
# 1  Acura  RSX Type S 2dr        Sedan   Asia      Front  $23,820    $21,761
# 2  Acura         TSX 4dr        Sedan   Asia      Front  $26,990    $24,647
# 3  Acura          TL 4dr        Sedan   Asia      Front  $33,195    $30,299
# 4  Acura      3.5 RL 4dr        Sedan   Asia      Front  $43,755    $39,014
#
#    EngineSize  Cylinders  HorsePower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# ...

# %%
sns.countplot(data=car,x='VehicleClass',palette='rocket')
# Out:
# <Axes: xlabel='VehicleClass', ylabel='count'>

# %%
sns.countplot(data=car,x='Region',palette='magma')
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
sns.countplot(data=car,x='DriveTrain',palette='ch:34')
# Out:
# <Axes: xlabel='DriveTrain', ylabel='count'>

# %%
sns.countplot(data=car,x='VehicleClass',palette='rocket',hue='Region')
# Out:
# <Axes: xlabel='VehicleClass', ylabel='count'>

# %%
sns.countplot(data=car,x='Region',palette='colorblind',hue='DriveTrain')
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
sns.countplot(data=car,x='DriveTrain',palette='dark',hue='VehicleClass')
# Out:
# <Axes: xlabel='DriveTrain', ylabel='count'>

# %%
car.head()
# Out:
#    Brand           Model VehicleClass Region DriveTrain      MSRP DealerCost  \
# 0  Acura             MDX          SUV   Asia        All  $36,945    $33,337
# 1  Acura  RSX Type S 2dr        Sedan   Asia      Front  $23,820    $21,761
# 2  Acura         TSX 4dr        Sedan   Asia      Front  $26,990    $24,647
# 3  Acura          TL 4dr        Sedan   Asia      Front  $33,195    $30,299
# 4  Acura      3.5 RL 4dr        Sedan   Asia      Front  $43,755    $39,014
#
#    EngineSize  Cylinders  HorsePower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# ...

# %%
sns.boxplot(data=car,x='VehicleClass',y='EngineSize',palette='dark')
# Out:
# <Axes: xlabel='VehicleClass', ylabel='EngineSize'>

# %%
sns.boxplot(data=car,x='Region',y='Cylinders',palette='ch:89')
# Out:
# <Axes: xlabel='Region', ylabel='Cylinders'>

# %%
sns.boxplot(data=car,x='DriveTrain',y='HorsePower',palette='cividis')
# Out:
# <Axes: xlabel='DriveTrain', ylabel='HorsePower'>

# %%
sns.boxplot(data=car,x='VehicleClass',y='MPG_City',palette='magma')
# Out:
# <Axes: xlabel='VehicleClass', ylabel='MPG_City'>

# %%
sns.boxplot(data=car,x='Region',y='MPG_Highway',palette='Dark2')
# Out:
# <Axes: xlabel='Region', ylabel='MPG_Highway'>

# %%
sns.boxplot(data=car,x='DriveTrain',y='Weight',palette='rocket')
# Out:
# <Axes: xlabel='DriveTrain', ylabel='Weight'>

# %%
car.head()
# Out:
#    Brand           Model VehicleClass Region DriveTrain      MSRP DealerCost  \
# 0  Acura             MDX          SUV   Asia        All  $36,945    $33,337
# 1  Acura  RSX Type S 2dr        Sedan   Asia      Front  $23,820    $21,761
# 2  Acura         TSX 4dr        Sedan   Asia      Front  $26,990    $24,647
# 3  Acura          TL 4dr        Sedan   Asia      Front  $33,195    $30,299
# 4  Acura      3.5 RL 4dr        Sedan   Asia      Front  $43,755    $39,014
#
#    EngineSize  Cylinders  HorsePower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# ...

# %%
sns.lmplot(data=car,x='EngineSize',y='Cylinders',palette='ch:89',hue='VehicleClass')

# %%
sns.lmplot(data=car,x='HorsePower',y='MPG_City',palette='dark',hue='Region')

# %%
sns.lmplot(data=car,x='MPG_Highway',y='Weight',palette='rocket',hue='DriveTrain')

# %%
sns.lmplot(data=car,x='Wheelbase',y='Length',palette='cividis',hue='Region')

# %%
sns.lmplot(data=car,x='Length',y='EngineSize',palette='magma',hue='DriveTrain')

# %%
car.head()
# Out:
#    Brand           Model VehicleClass Region DriveTrain      MSRP DealerCost  \
# 0  Acura             MDX          SUV   Asia        All  $36,945    $33,337
# 1  Acura  RSX Type S 2dr        Sedan   Asia      Front  $23,820    $21,761
# 2  Acura         TSX 4dr        Sedan   Asia      Front  $26,990    $24,647
# 3  Acura          TL 4dr        Sedan   Asia      Front  $33,195    $30,299
# 4  Acura      3.5 RL 4dr        Sedan   Asia      Front  $43,755    $39,014
#
#    EngineSize  Cylinders  HorsePower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# ...

# %%
sns.stripplot(data=car,x='VehicleClass',y='EngineSize',palette='YlOrBr')
# Out:
# <Axes: xlabel='VehicleClass', ylabel='EngineSize'>

# %%
sns.stripplot(data=car,x='Region',y='Cylinders',palette='dark')
# Out:
# <Axes: xlabel='Region', ylabel='Cylinders'>

# %%
sns.stripplot(data=car,x='VehicleClass',y='HorsePower',palette='ch:56')
# Out:
# <Axes: xlabel='VehicleClass', ylabel='HorsePower'>

# %%
sns.stripplot(data=car,x='Region',y='MPG_City',palette='Set1')
# Out:
# <Axes: xlabel='Region', ylabel='MPG_City'>

# %%
sns.stripplot(data=car,x='DriveTrain',y='MPG_Highway',palette='magma')
# Out:
# <Axes: xlabel='DriveTrain', ylabel='MPG_Highway'>

# %%
sns.stripplot(data=car,x='DriveTrain',y='Weight',palette='rocket')
# Out:
# <Axes: xlabel='DriveTrain', ylabel='Weight'>

# %%
car.head()
# Out:
#    Brand           Model VehicleClass Region DriveTrain      MSRP DealerCost  \
# 0  Acura             MDX          SUV   Asia        All  $36,945    $33,337
# 1  Acura  RSX Type S 2dr        Sedan   Asia      Front  $23,820    $21,761
# 2  Acura         TSX 4dr        Sedan   Asia      Front  $26,990    $24,647
# 3  Acura          TL 4dr        Sedan   Asia      Front  $33,195    $30,299
# 4  Acura      3.5 RL 4dr        Sedan   Asia      Front  $43,755    $39,014
#
#    EngineSize  Cylinders  HorsePower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# ...

# %%
sns.kdeplot(data=car,x='EngineSize',hue='VehicleClass',palette='dark',fill=True)
# Out:
# <Axes: xlabel='EngineSize', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='Cylinders',hue='Region',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='Cylinders', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='HorsePower',hue='DriveTrain',palette='ch:64',fill=True)
# Out:
# <Axes: xlabel='HorsePower', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='MPG_City',hue='VehicleClass',palette='magma',fill=True)
# Out:
# <Axes: xlabel='MPG_City', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='MPG_Highway',hue='Region',palette='mako',fill=True)
# Out:
# <Axes: xlabel='MPG_Highway', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='Weight',hue='DriveTrain',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='Wheelbase',hue='VehicleClass',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Wheelbase', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='Length',hue='Region',palette='colorblind',fill=True)
# Out:
# <Axes: xlabel='Length', ylabel='Density'>

# %%
car.head()
# Out:
#    Brand           Model VehicleClass Region DriveTrain      MSRP DealerCost  \
# 0  Acura             MDX          SUV   Asia        All  $36,945    $33,337
# 1  Acura  RSX Type S 2dr        Sedan   Asia      Front  $23,820    $21,761
# 2  Acura         TSX 4dr        Sedan   Asia      Front  $26,990    $24,647
# 3  Acura          TL 4dr        Sedan   Asia      Front  $33,195    $30,299
# 4  Acura      3.5 RL 4dr        Sedan   Asia      Front  $43,755    $39,014
#
#    EngineSize  Cylinders  HorsePower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# ...

# %%
sns.pairplot(car, hue="Brand",palette='dark')

# %%
sns.pairplot(car, hue="VehicleClass",palette='colorblind')

# %%
sns.pairplot(car, hue="Region",palette='rocket')

# %%
sns.pairplot(car, hue="DriveTrain",palette='Set1')
