# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
lung=pd.read_csv(r'C:\Users\admin\Downloads\archive\LungCapData.csv')

# %%
lung
# Out:
#      Unnamed: 0  LungCap  Age  Height Smoke  Gender Caesarean
# 0             1    6.475    6    62.1    no    male        no
# 1             2   10.125   18    74.7   yes  female        no
# 2             3    9.550   16    69.7    no  female       yes
# 3             4   11.125   14    71.0    no    male        no
# 4             5    4.800    5    56.9    no    male        no
# ..          ...      ...  ...     ...   ...     ...       ...
# 720         721    5.725    9    56.0    no  female        no
# 721         722    9.050   18    72.0   yes    male       yes
# 722         723    3.850   11    60.5   yes  female        no
# 723         724    9.825   15    64.9    no  female        no
# 724         725    7.100   10    67.7    no    male        no
#
# [725 rows x 7 columns]

# %%
lung.shape
# Out:
# (725, 7)

# %%
lung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  725 non-null    int64
#  1   LungCap     725 non-null    float64
#  2   Age         725 non-null    int64
#  3   Height      725 non-null    float64
#  4   Smoke       725 non-null    object
#  5   Gender      725 non-null    object
#  6   Caesarean   725 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 39.8+ KB

# %%
lung.isnull().sum()
# Out:
# Unnamed: 0    0
# LungCap       0
# Age           0
# Height        0
# Smoke         0
# Gender        0
# Caesarean     0
# dtype: int64

# %%
lung.dtypes
# Out:
# Unnamed: 0      int64
# LungCap       float64
# Age             int64
# Height        float64
# Smoke          object
# Gender         object
# Caesarean      object
# dtype: object

# %%
lung = lung.drop('Unnamed: 0', axis=1)

# %%
lung.columns
# Out:
# Index(['LungCap', 'Age', 'Height', 'Smoke', 'Gender', 'Caesarean'], dtype='object')

# %%
len(lung.columns)
# Out:
# 6

# %%
lung.describe()
# Out:
#           LungCap         Age      Height
# count  725.000000  725.000000  725.000000
# mean     7.863148   12.326897   64.836276
# std      2.662008    4.004750    7.202144
# min      0.507000    3.000000   45.300000
# 25%      6.150000    9.000000   59.900000
# 50%      8.000000   13.000000   65.400000
# 75%      9.800000   15.000000   70.300000
# max     14.675000   19.000000   81.800000

# %%
lung.describe().transpose()
# Out:
#          count       mean       std     min    25%   50%   75%     max
# LungCap  725.0   7.863148  2.662008   0.507   6.15   8.0   9.8  14.675
# Age      725.0  12.326897  4.004750   3.000   9.00  13.0  15.0  19.000
# Height   725.0  64.836276  7.202144  45.300  59.90  65.4  70.3  81.800

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.distplot(lung.LungCap,color='m',bins=10)
# Out:
# <Axes: xlabel='LungCap', ylabel='Density'>

# %%
sns.distplot(lung.Age,color='g',bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(lung.Height,color='k',bins=10)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.countplot(data=lung,x='Smoke',palette='dark')
# Out:
# <Axes: xlabel='Smoke', ylabel='count'>

# %%
sns.countplot(data=lung,x='Gender',palette='rocket')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=lung,x='Caesarean',palette='ch:34')
# Out:
# <Axes: xlabel='Caesarean', ylabel='count'>

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.countplot(data=lung,x='Smoke',hue='Gender',palette='colorblind')
# Out:
# <Axes: xlabel='Smoke', ylabel='count'>

# %%
sns.countplot(data=lung,x='Gender',hue='Caesarean',palette='Set1')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=lung,x='Caesarean',hue='Smoke',palette='Dark2')
# Out:
# <Axes: xlabel='Caesarean', ylabel='count'>

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.lmplot(data=lung,x='Age',y='LungCap',palette='dark',hue='Smoke')

# %%
sns.lmplot(data=lung,x='Age',y='LungCap',palette='ch:45',hue='Gender')

# %%
sns.lmplot(data=lung,x='Height',y='LungCap',palette='Set1',hue='Smoke')

# %%
sns.lmplot(data=lung,x='Height',y='LungCap',palette='magma',hue='Caesarean')

# %%
sns.lmplot(data=lung,x='Age',y='Height',palette='rocket',hue='Caesarean')

# %%
sns.lmplot(data=lung,x='Age',y='Height',palette='colorblind',hue='Gender')

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.jointplot(data=lung,x='LungCap',y='Age',color='m',kind='hex')

# %%
sns.jointplot(data=lung,x='Age',y='Height',color='b',kind='hex')

# %%
sns.jointplot(data=lung,x='LungCap',y='Height',color='r',kind='hex')

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.boxplot(data=lung,x='Smoke',y='LungCap',palette='dark')
# Out:
# <Axes: xlabel='Smoke', ylabel='LungCap'>

# %%
sns.boxplot(data=lung,x='Caesarean',y='Age',palette='Set1')
# Out:
# <Axes: xlabel='Caesarean', ylabel='Age'>

# %%
sns.boxplot(data=lung,x='Gender',y='Height',palette='mako')
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.stripplot(data=lung,x='Smoke',y='LungCap',palette='rocket')
# Out:
# <Axes: xlabel='Smoke', ylabel='LungCap'>

# %%
sns.stripplot(data=lung,x='Caesarean',y='Age',palette='Set1')
# Out:
# <Axes: xlabel='Caesarean', ylabel='Age'>

# %%
sns.stripplot(data=lung,x='Gender',y='Height',palette='Dark2')
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.kdeplot(data=lung,x='LungCap',hue='Smoke',palette='dark',fill=True)
# Out:
# <Axes: xlabel='LungCap', ylabel='Density'>

# %%
sns.kdeplot(data=lung,x='Age',hue='Caesarean',palette='cividis',fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=lung,x='Height',hue='Gender',palette='colorblind',fill=True)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(data=lung,x='LungCap',hue='Gender',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='LungCap', ylabel='Density'>

# %%
sns.kdeplot(data=lung,x='Age',hue='Smoke',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=lung,x='Height',hue='Caesarean',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
lung.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
sns.pairplot(lung, hue="Gender",palette='Set1')

# %%
sns.pairplot(lung,hue="Smoke",palette='Dark2')

# %%
sns.pairplot(lung, hue="Caesarean",palette='rocket')
