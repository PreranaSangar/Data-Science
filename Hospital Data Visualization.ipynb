# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=9,5
sns.set_style('darkgrid')

# %%
hospital=pd.read_csv(r'C:\Users\admin\Downloads\Hospital_Data.csv')

# %%
hospital
# Out:
#         Hospital_Name   Location        Department  Doctors_Count  \
# 0     Wellness Clinic    Chennai       Orthopedics             47
# 1         Fortis Care       Pune               ENT             15
# 2     Wellness Clinic  Ahmedabad        Pediatrics             20
# 3   Heritage Hospital  Hyderabad           Urology              8
# 4       City Hospital    Kolkata        Gynecology             35
# ..                ...        ...               ...            ...
# 95    Wellness Clinic  Bangalore        Gynecology             28
# 96  Heritage Hospital     Jaipur  General Medicine             26
# 97      Healing Touch  Bangalore          Oncology             40
# 98     Metro Hospital    Lucknow         Neurology             42
# 99      Healing Touch  Bangalore           Urology             14
#
#     Patients_Count Admission_Date Discharge_Date  Medical_Expenses
# 0              182     13-12-2023     14-12-2023          31364.88
# ...

# %%
hospital.shape
# Out:
# (100, 8)

# %%
hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0    Hospital_Name    100 non-null    object
#  1   Location          100 non-null    object
#  2   Department        100 non-null    object
#  3   Doctors_Count     100 non-null    int64
#  4   Patients_Count    100 non-null    int64
#  5   Admission_Date    100 non-null    object
#  6   Discharge_Date    100 non-null    object
#  7   Medical_Expenses  100 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
hospital.isnull().sum()
# Out:
#  Hospital_Name      0
# Location            0
# Department          0
# Doctors_Count       0
# Patients_Count      0
# Admission_Date      0
# Discharge_Date      0
# Medical_Expenses    0
# dtype: int64

# %%
hospital.columns
# Out:
# Index([' Hospital_Name', 'Location', 'Department', 'Doctors_Count',
#        'Patients_Count', 'Admission_Date', 'Discharge_Date',
#        'Medical_Expenses'],
#       dtype='object')

# %%
len(hospital.columns)
# Out:
# 8

# %%
hospital.dtypes
# Out:
#  Hospital_Name       object
# Location             object
# Department           object
# Doctors_Count         int64
# Patients_Count        int64
# Admission_Date       object
# Discharge_Date       object
# Medical_Expenses    float64
# dtype: object

# %%
hospital.describe()
# Out:
#        Doctors_Count  Patients_Count  Medical_Expenses
# count     100.000000      100.000000        100.000000
# mean       26.710000       93.470000      27173.110600
# std        13.248438       48.167942      14001.995544
# min         5.000000       20.000000       2854.220000
# 25%        15.000000       56.750000      14688.322500
# 50%        27.500000       84.500000      26320.945000
# 75%        38.250000      131.500000      40741.427500
# max        49.000000      198.000000      49955.410000

# %%
hospital.describe().transpose()
# Out:
#                   count        mean           std      min         25%  \
# Doctors_Count     100.0     26.7100     13.248438     5.00     15.0000
# Patients_Count    100.0     93.4700     48.167942    20.00     56.7500
# Medical_Expenses  100.0  27173.1106  14001.995544  2854.22  14688.3225
#
#                         50%         75%       max
# Doctors_Count        27.500     38.2500     49.00
# Patients_Count       84.500    131.5000    198.00
# Medical_Expenses  26320.945  40741.4275  49955.41

# %%
hospital.head()
# Out:
#        Hospital_Name   Location   Department  Doctors_Count  Patients_Count  \
# 0    Wellness Clinic    Chennai  Orthopedics             47             182
# 1        Fortis Care       Pune          ENT             15              51
# 2    Wellness Clinic  Ahmedabad   Pediatrics             20             120
# 3  Heritage Hospital  Hyderabad      Urology              8             172
# 4      City Hospital    Kolkata   Gynecology             35              76
#
#   Admission_Date Discharge_Date  Medical_Expenses
# 0     13-12-2023     14-12-2023          31364.88
# 1     29-12-2023     09-01-2024          47280.19
# 2     07-10-2023     21-10-2023          28574.72
# 3     29-04-2023     11-05-2023           7000.83
# 4     10-02-2023     12-02-2023          47210.46

# %%
hospital.tail()
# Out:
#         Hospital_Name   Location        Department  Doctors_Count  \
# 95    Wellness Clinic  Bangalore        Gynecology             28
# 96  Heritage Hospital     Jaipur  General Medicine             26
# 97      Healing Touch  Bangalore          Oncology             40
# 98     Metro Hospital    Lucknow         Neurology             42
# 99      Healing Touch  Bangalore           Urology             14
#
#     Patients_Count Admission_Date Discharge_Date  Medical_Expenses
# 95             126     29-11-2023     10-12-2023          21065.59
# 96             169     18-02-2023     19-02-2023          41677.34
# 97             193     01-11-2023     15-11-2023          47625.70
# 98             163     19-05-2023     26-05-2023           8684.16
# 99              37     09-12-2023     15-12-2023          17213.05

# %%
plt.plot(hospital.Doctors_Count,color='r')

# %%
plt.plot(hospital.Patients_Count,color='k')

# %%
sns.distplot(hospital.Doctors_Count,color='c')
# Out:
# <Axes: xlabel='Doctors_Count', ylabel='Density'>

# %%
sns.distplot(hospital.Patients_Count,color='Purple')
# Out:
# <Axes: xlabel='Patients_Count', ylabel='Density'>

# %%
sns.distplot(hospital.Medical_Expenses,color='Orange')
# Out:
# <Axes: xlabel='Medical_Expenses', ylabel='Density'>

# %%
hospital.head(1)
# Out:
#      Hospital_Name Location   Department  Doctors_Count  Patients_Count  \
# 0  Wellness Clinic  Chennai  Orthopedics             47             182
#
#   Admission_Date Discharge_Date  Medical_Expenses
# 0     13-12-2023     14-12-2023          31364.88

# %%
sns.countplot(data=hospital,x='Location',palette='Dark2')
# Out:
# <Axes: xlabel='Location', ylabel='count'>

# %%
sns.countplot(data=hospital,x='Department',palette='magma')
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
sns.countplot(data=hospital,x='Department',hue='Location',palette='dark')
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
hospital.head()
# Out:
#        Hospital_Name   Location   Department  Doctors_Count  Patients_Count  \
# 0    Wellness Clinic    Chennai  Orthopedics             47             182
# 1        Fortis Care       Pune          ENT             15              51
# 2    Wellness Clinic  Ahmedabad   Pediatrics             20             120
# 3  Heritage Hospital  Hyderabad      Urology              8             172
# 4      City Hospital    Kolkata   Gynecology             35              76
#
#   Admission_Date Discharge_Date  Medical_Expenses
# 0     13-12-2023     14-12-2023          31364.88
# 1     29-12-2023     09-01-2024          47280.19
# 2     07-10-2023     21-10-2023          28574.72
# 3     29-04-2023     11-05-2023           7000.83
# 4     10-02-2023     12-02-2023          47210.46

# %%
sns.lmplot(data=hospital,x='Doctors_Count',y='Patients_Count',palette='Set1',hue='Location')

# %%
sns.lmplot(data=hospital,x='Doctors_Count',y='Patients_Count',palette='dark',hue='Department')

# %%
sns.lmplot(data=hospital,x='Doctors_Count',y='Medical_Expenses',palette='hls',hue='Department')

# %%
sns.lmplot(data=hospital,x='Medical_Expenses',y='Patients_Count',palette='magma',hue='Department')

# %%
sns.lmplot(data=hospital,x='Doctors_Count',y='Medical_Expenses',palette='deep',hue='Location')

# %%
sns.lmplot(data=hospital,x='Medical_Expenses',y='Patients_Count',palette='bright',hue='Location')

# %%
sns.jointplot(data=hospital,x='Doctors_Count',y='Patients_Count',palette='Set1',hue='Location')

# %%
sns.jointplot(data=hospital,x='Doctors_Count',y='Patients_Count',palette='dark',hue='Department')

# %%
sns.jointplot(data=hospital,x='Doctors_Count',y='Medical_Expenses',palette='hls',hue='Department')

# %%
sns.jointplot(data=hospital,x='Medical_Expenses',y='Patients_Count',palette='magma',hue='Department')

# %%
sns.jointplot(data=hospital,x='Doctors_Count',y='Medical_Expenses',palette='deep',hue='Location')

# %%
sns.jointplot(data=hospital,x='Medical_Expenses',y='Patients_Count',palette='bright',hue='Location')

# %%
hospital.head()
# Out:
#        Hospital_Name   Location   Department  Doctors_Count  Patients_Count  \
# 0    Wellness Clinic    Chennai  Orthopedics             47             182
# 1        Fortis Care       Pune          ENT             15              51
# 2    Wellness Clinic  Ahmedabad   Pediatrics             20             120
# 3  Heritage Hospital  Hyderabad      Urology              8             172
# 4      City Hospital    Kolkata   Gynecology             35              76
#
#   Admission_Date Discharge_Date  Medical_Expenses
# 0     13-12-2023     14-12-2023          31364.88
# 1     29-12-2023     09-01-2024          47280.19
# 2     07-10-2023     21-10-2023          28574.72
# 3     29-04-2023     11-05-2023           7000.83
# 4     10-02-2023     12-02-2023          47210.46

# %%
sns.boxplot(data=hospital,x='Location',y='Doctors_Count',palette='Set1')
# Out:
# <Axes: xlabel='Location', ylabel='Doctors_Count'>

# %%
sns.boxplot(data=hospital,x='Department',y='Doctors_Count',palette='magma')
# Out:
# <Axes: xlabel='Department', ylabel='Doctors_Count'>

# %%
sns.boxplot(data=hospital,x='Location',y='Patients_Count',palette='dark')
# Out:
# <Axes: xlabel='Location', ylabel='Patients_Count'>

# %%
sns.boxplot(data=hospital,x='Department',y='Patients_Count',palette='hls')
# Out:
# <Axes: xlabel='Department', ylabel='Patients_Count'>

# %%
sns.boxplot(data=hospital,x='Location',y='Doctors_Count',palette='bright')
# Out:
# <Axes: xlabel='Location', ylabel='Doctors_Count'>

# %%
sns.boxplot(data=hospital,x='Location',y='Medical_Expenses',palette='bright')
# Out:
# <Axes: xlabel='Location', ylabel='Medical_Expenses'>

# %%
sns.boxplot(data=hospital,x='Department',y='Medical_Expenses',palette='Dark2')
# Out:
# <Axes: xlabel='Department', ylabel='Medical_Expenses'>
