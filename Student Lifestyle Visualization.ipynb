# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=10,5
sns.set_style('darkgrid')

# %%
life=pd.read_csv(r'C:\Users\admin\Downloads\archive\student_lifestyle_dataset..csv')

# %%
life
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0              1                  6.9                            3.8
# 1              2                  5.3                            3.5
# 2              3                  5.1                            3.9
# 3              4                  6.5                            2.1
# 4              5                  8.1                            0.6
# ...          ...                  ...                            ...
# 1995        1996                  6.5                            0.2
# 1996        1997                  6.3                            2.8
# 1997        1998                  6.2                            0.0
# 1998        1999                  8.1                            0.7
# 1999        2000                  9.0                            1.7
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 0                     8.7                   2.8
# ...

# %%
life.shape
# Out:
# (2000, 9)

# %%
life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Student_ID                       2000 non-null   int64
#  1   Study_Hours_Per_Day              2000 non-null   float64
#  2   Extracurricular_Hours_Per_Day    2000 non-null   float64
#  3   Sleep_Hours_Per_Day              2000 non-null   float64
#  4   Social_Hours_Per_Day             2000 non-null   float64
#  5   Physical_Activity_Hours_Per_Day  2000 non-null   float64
#  6   Stress_Level                     2000 non-null   object
#  7   Gender                           2000 non-null   object
#  8   Grades                           2000 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 140.8+ KB

# %%
life.isnull().sum()
# Out:
# Student_ID                         0
# Study_Hours_Per_Day                0
# Extracurricular_Hours_Per_Day      0
# Sleep_Hours_Per_Day                0
# Social_Hours_Per_Day               0
# Physical_Activity_Hours_Per_Day    0
# Stress_Level                       0
# Gender                             0
# Grades                             0
# dtype: int64

# %%
life.columns
# Out:
# Index(['Student_ID', 'Study_Hours_Per_Day', 'Extracurricular_Hours_Per_Day',
#        'Sleep_Hours_Per_Day', 'Social_Hours_Per_Day',
#        'Physical_Activity_Hours_Per_Day', 'Stress_Level', 'Gender', 'Grades'],
#       dtype='object')

# %%
len(life.columns)
# Out:
# 9

# %%
life.dtypes
# Out:
# Student_ID                           int64
# Study_Hours_Per_Day                float64
# Extracurricular_Hours_Per_Day      float64
# Sleep_Hours_Per_Day                float64
# Social_Hours_Per_Day               float64
# Physical_Activity_Hours_Per_Day    float64
# Stress_Level                        object
# Gender                              object
# Grades                             float64
# dtype: object

# %%
life.describe()
# Out:
#         Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# count  2000.000000          2000.000000                    2000.000000
# mean   1000.500000             7.475800                       1.990100
# std     577.494589             1.423888                       1.155855
# min       1.000000             5.000000                       0.000000
# 25%     500.750000             6.300000                       1.000000
# 50%    1000.500000             7.400000                       2.000000
# 75%    1500.250000             8.700000                       3.000000
# max    2000.000000            10.000000                       4.000000
#
#        Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# count          2000.000000           2000.000000
# mean              7.501250              2.704550
# std               1.460949              1.688514
# min               5.000000              0.000000
# 25%               6.200000              1.200000
# ...

# %%
life.describe().transpose()
# Out:
#                                   count         mean         std  min     25%  \
# Student_ID                       2000.0  1000.500000  577.494589  1.0  500.75
# Study_Hours_Per_Day              2000.0     7.475800    1.423888  5.0    6.30
# Extracurricular_Hours_Per_Day    2000.0     1.990100    1.155855  0.0    1.00
# Sleep_Hours_Per_Day              2000.0     7.501250    1.460949  5.0    6.20
# Social_Hours_Per_Day             2000.0     2.704550    1.688514  0.0    1.20
# Physical_Activity_Hours_Per_Day  2000.0     4.328300    2.514110  0.0    2.40
# Grades                           2000.0     7.789825    0.746777  5.6    7.25
#
#                                      50%      75%     max
# Student_ID                       1000.50  1500.25  2000.0
# Study_Hours_Per_Day                 7.40     8.70    10.0
# Extracurricular_Hours_Per_Day       2.00     3.00     4.0
# Sleep_Hours_Per_Day                 7.50     8.80    10.0
# ...

# %%
life.tail()
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 1995        1996                  6.5                            0.2
# 1996        1997                  6.3                            2.8
# 1997        1998                  6.2                            0.0
# 1998        1999                  8.1                            0.7
# 1999        2000                  9.0                            1.7
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 1995                  7.4                   2.1
# 1996                  8.8                   1.5
# 1997                  6.2                   0.8
# 1998                  7.6                   3.5
# 1999                  7.3                   3.1
#
#       Physical_Activity_Hours_Per_Day Stress_Level  Gender  Grades
# 1995                              7.8     Moderate    Male    8.30
# 1996                              4.6     Moderate  Female    6.62
# ...

# %%
life.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#   Stress_Level  Gender  Grades
# 0     Moderate    Male    7.48
# 1          Low  Female    6.88
# ...

# %%
sns.distplot(life.Study_Hours_Per_Day,color='g')
# Out:
# <Axes: xlabel='Study_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(life.Extracurricular_Hours_Per_Day,color='c')
# Out:
# <Axes: xlabel='Extracurricular_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(life.Sleep_Hours_Per_Day,color='r')
# Out:
# <Axes: xlabel='Sleep_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(life.Social_Hours_Per_Day,color='b')
# Out:
# <Axes: xlabel='Social_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(life.Physical_Activity_Hours_Per_Day,color='y')
# Out:
# <Axes: xlabel='Physical_Activity_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(life.Grades,color='Purple')
# Out:
# <Axes: xlabel='Grades', ylabel='Density'>

# %%
life.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#   Stress_Level  Gender  Grades
# 0     Moderate    Male    7.48
# 1          Low  Female    6.88
# ...

# %%
sns.countplot(data=life,x='Stress_Level',palette='Dark2')
# Out:
# <Axes: xlabel='Stress_Level', ylabel='count'>

# %%
sns.countplot(data=life,x='Gender',palette='ch:34')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=life,x='Stress_Level',palette='dark',hue='Gender')
# Out:
# <Axes: xlabel='Stress_Level', ylabel='count'>

# %%
life.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#   Stress_Level  Gender  Grades
# 0     Moderate    Male    7.48
# 1          Low  Female    6.88
# ...

# %%
sns.lmplot(data=life,x='Study_Hours_Per_Day',y='Study_Hours_Per_Day',palette='colorblind',hue='Gender')

# %%
sns.lmplot(data=life,x='Study_Hours_Per_Day',y='Study_Hours_Per_Day',palette='colorblind',hue='Stress_Level')

# %%
sns.lmplot(data=life,x='Study_Hours_Per_Day',y='Sleep_Hours_Per_Day',palette='muted',hue='Stress_Level')

# %%
sns.lmplot(data=life,x='Study_Hours_Per_Day',y='Social_Hours_Per_Day',palette='ch:34',hue='Gender')

# %%
sns.lmplot(data=life,x='Study_Hours_Per_Day',y='Physical_Activity_Hours_Per_Day',palette='Set1',hue='Gender')

# %%
sns.lmplot(data=life,x='Study_Hours_Per_Day',y='Grades',palette='dark',hue='Gender')

# %%
sns.lmplot(data=life,x='Study_Hours_Per_Day',y='Grades',palette='magma',hue='Stress_Level')

# %%
life.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#   Stress_Level  Gender  Grades
# 0     Moderate    Male    7.48
# 1          Low  Female    6.88
# ...

# %%
sns.boxplot(data=life,x='Stress_Level',y='Study_Hours_Per_Day',palette='magma')
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Study_Hours_Per_Day'>

# %%
sns.boxplot(data=life,x='Gender',y='Extracurricular_Hours_Per_Day',palette='Dark2')
# Out:
# <Axes: xlabel='Gender', ylabel='Extracurricular_Hours_Per_Day'>

# %%
sns.boxplot(data=life,x='Stress_Level',y='Extracurricular_Hours_Per_Day',palette='dark',fill=False)
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Extracurricular_Hours_Per_Day'>

# %%
sns.boxplot(data=life,x='Gender',y='Sleep_Hours_Per_Day',palette='Set1')
# Out:
# <Axes: xlabel='Gender', ylabel='Sleep_Hours_Per_Day'>

# %%
sns.boxplot(data=life,x='Stress_Level',y='Social_Hours_Per_Day',palette='ch:78')
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Social_Hours_Per_Day'>

# %%
sns.boxplot(data=life,x='Stress_Level',y='Grades',palette='ch:34')
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Grades'>

# %%
sns.boxplot(data=life,x='Gender',y='Grades',palette='colorblind',fill=False)
# Out:
# <Axes: xlabel='Gender', ylabel='Grades'>

# %%
life.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#   Stress_Level  Gender  Grades
# 0     Moderate    Male    7.48
# 1          Low  Female    6.88
# ...

# %%
sns.kdeplot(life.Study_Hours_Per_Day,color='k',fill=True)
# Out:
# <Axes: xlabel='Study_Hours_Per_Day', ylabel='Density'>

# %%
sns.kdeplot(life.Extracurricular_Hours_Per_Day,color='c',fill=True)
# Out:
# <Axes: xlabel='Extracurricular_Hours_Per_Day', ylabel='Density'>

# %%
sns.kdeplot(life.Social_Hours_Per_Day,color='g',fill=True)
# Out:
# <Axes: xlabel='Social_Hours_Per_Day', ylabel='Density'>

# %%
sns.kdeplot(life.Physical_Activity_Hours_Per_Day,color='b',fill=True)
# Out:
# <Axes: xlabel='Physical_Activity_Hours_Per_Day', ylabel='Density'>

# %%
sns.kdeplot(life.Grades,color='Orange',fill=True)
# Out:
# <Axes: xlabel='Grades', ylabel='Density'>
