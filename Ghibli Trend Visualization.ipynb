# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=10,4
sns.set_style('darkgrid')

# %%
ghibli=pd.read_csv(r'C:\Users\admin\Downloads\archive\ai_ghibli_trend_dataset_v2.csv')

# %%
ghibli
# Out:
#                                  image_id   user_id  \
# 0    77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1    7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2    d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3    cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4    7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
# ..                                    ...       ...
# 495  135267ba-3941-42ae-a421-3be20e3856d1  c80e6866
# 496  b2ced831-5b08-403d-bfb3-b562e256f359  81669630
# 497  8c87b8aa-b304-43cf-82b3-3a199367ec17  258613ea
# 498  04dba0f4-fdb7-4341-8bb6-dca5a595cd81  23b56439
# 499  1960cd2d-0e99-4e09-b426-62212dd8b37f  7dea460a
#
#                                                 prompt  likes  shares  \
# 0         Studio Ghibli-inspired ocean with giant fish    916     410
# 1                       Ghibli-style village at sunset   2965    1361
# 2          A lone traveler exploring an enchanted ruin   4727     655
# ...

# %%
ghibli.shape
# Out:
# (500, 16)

# %%
ghibli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   image_id               500 non-null    object
#  1   user_id                500 non-null    object
#  2   prompt                 500 non-null    object
#  3   likes                  500 non-null    int64
#  4   shares                 500 non-null    int64
#  5   comments               500 non-null    int64
#  6   platform               500 non-null    object
#  7   generation_time        500 non-null    float64
#  8   gpu_usage              500 non-null    int64
#  9   file_size_kb           500 non-null    int64
#  10  resolution             500 non-null    object
#  11  style_accuracy_score   500 non-null    int64
#  12  is_hand_edited         500 non-null    object
#  13  ethical_concerns_flag  500 non-null    object
# ...

# %%
ghibli.isnull().sum()
# Out:
# image_id                 0
# user_id                  0
# prompt                   0
# likes                    0
# shares                   0
# comments                 0
# platform                 0
# generation_time          0
# gpu_usage                0
# file_size_kb             0
# resolution               0
# style_accuracy_score     0
# is_hand_edited           0
# ethical_concerns_flag    0
# creation_date            0
# top_comment              0
# dtype: int64

# %%
ghibli.columns
# Out:
# Index(['image_id', 'user_id', 'prompt', 'likes', 'shares', 'comments',
#        'platform', 'generation_time', 'gpu_usage', 'file_size_kb',
#        'resolution', 'style_accuracy_score', 'is_hand_edited',
#        'ethical_concerns_flag', 'creation_date', 'top_comment'],
#       dtype='object')

# %%
len(ghibli.columns)
# Out:
# 16

# %%
ghibli.dtypes
# Out:
# image_id                  object
# user_id                   object
# prompt                    object
# likes                      int64
# shares                     int64
# comments                   int64
# platform                  object
# generation_time          float64
# gpu_usage                  int64
# file_size_kb               int64
# resolution                object
# style_accuracy_score       int64
# is_hand_edited            object
# ethical_concerns_flag     object
# creation_date             object
# top_comment               object
# dtype: object

# %%
ghibli.describe()
# Out:
#              likes       shares    comments  generation_time   gpu_usage  \
# count   500.000000   500.000000  500.000000       500.000000  500.000000
# mean   2601.262000  1040.182000  506.872000         8.317780   61.124000
# std    1429.433498   562.668738  283.384066         3.903103   18.151131
# min     105.000000    13.000000    5.000000         1.540000   30.000000
# 25%    1343.500000   587.750000  276.750000         5.027500   45.000000
# 50%    2566.500000  1092.000000  518.000000         8.380000   63.000000
# 75%    3913.250000  1502.000000  744.250000        11.540000   77.000000
# max    4944.000000  1999.000000  998.000000        14.990000   90.000000
#
#        file_size_kb  style_accuracy_score
# count    500.000000            500.000000
# mean    2511.822000             74.626000
# std     1390.178578             14.679001
# min      101.000000             50.000000
# 25%     1374.750000             62.000000
# 50%     2498.000000             74.000000
# ...

# %%
ghibli.describe().transpose()
# Out:
#                       count        mean          std     min        25%  \
# likes                 500.0  2601.26200  1429.433498  105.00  1343.5000
# shares                500.0  1040.18200   562.668738   13.00   587.7500
# comments              500.0   506.87200   283.384066    5.00   276.7500
# generation_time       500.0     8.31778     3.903103    1.54     5.0275
# gpu_usage             500.0    61.12400    18.151131   30.00    45.0000
# file_size_kb          500.0  2511.82200  1390.178578  101.00  1374.7500
# style_accuracy_score  500.0    74.62600    14.679001   50.00    62.0000
#
#                           50%      75%      max
# likes                 2566.50  3913.25  4944.00
# shares                1092.00  1502.00  1999.00
# comments               518.00   744.25   998.00
# generation_time          8.38    11.54    14.99
# gpu_usage               63.00    77.00    90.00
# file_size_kb          2498.00  3729.00  4973.00
# style_accuracy_score    74.00    87.25   100.00

# %%
ghibli.tail()
# Out:
#                                  image_id   user_id  \
# 495  135267ba-3941-42ae-a421-3be20e3856d1  c80e6866
# 496  b2ced831-5b08-403d-bfb3-b562e256f359  81669630
# 497  8c87b8aa-b304-43cf-82b3-3a199367ec17  258613ea
# 498  04dba0f4-fdb7-4341-8bb6-dca5a595cd81  23b56439
# 499  1960cd2d-0e99-4e09-b426-62212dd8b37f  7dea460a
#
#                                                 prompt  likes  shares  \
# 495  Anime-style train passing through a fantasy world   1634    1328
# 496          Serene meadow with a tiny spirit creature   4198     833
# 497        Ghibli-style mountain with floating islands   1237    1703
# 498     Cozy tea shop in a mystical town, Ghibli style   1852    1158
# 499       Mysterious temple hidden in a magical forest   3944    1059
#
#      comments platform  generation_time  gpu_usage  file_size_kb resolution  \
# 495       624   TikTok            10.56         73          3255  1024x1024
# ...

# %%
ghibli.head()
# Out:
#                                image_id   user_id  \
# 0  77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1  7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2  d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3  cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4  7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
#
#                                          prompt  likes  shares  comments  \
# 0  Studio Ghibli-inspired ocean with giant fish    916     410       555
# 1                Ghibli-style village at sunset   2965    1361       417
# 2   A lone traveler exploring an enchanted ruin   4727     655       785
# 3    Spirited Away-style bustling market street   1629    1954       212
# 4  Magical Ghibli forest with floating lanterns   2573    1281       913
#
#     platform  generation_time  gpu_usage  file_size_kb resolution  \
# 0     Reddit             4.80         49          1684  1024x1024
# 1     Reddit            11.11         81          2808  1024x1024
# ...

# %%
sns.distplot(ghibli.likes,color='k')
# Out:
# <Axes: xlabel='likes', ylabel='Density'>

# %%
sns.distplot(ghibli.shares,color='r')
# Out:
# <Axes: xlabel='shares', ylabel='Density'>

# %%
sns.distplot(ghibli.comments,color='b')
# Out:
# <Axes: xlabel='comments', ylabel='Density'>

# %%
sns.distplot(ghibli.generation_time,color='g')
# Out:
# <Axes: xlabel='generation_time', ylabel='Density'>

# %%
sns.distplot(ghibli.gpu_usage,color='orange')
# Out:
# <Axes: xlabel='gpu_usage', ylabel='Density'>

# %%
sns.distplot(ghibli.file_size_kb,color='purple')
# Out:
# <Axes: xlabel='file_size_kb', ylabel='Density'>

# %%
sns.distplot(ghibli.style_accuracy_score,color='y')
# Out:
# <Axes: xlabel='style_accuracy_score', ylabel='Density'>

# %%
ghibli.head()
# Out:
#                                image_id   user_id  \
# 0  77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1  7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2  d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3  cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4  7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
#
#                                          prompt  likes  shares  comments  \
# 0  Studio Ghibli-inspired ocean with giant fish    916     410       555
# 1                Ghibli-style village at sunset   2965    1361       417
# 2   A lone traveler exploring an enchanted ruin   4727     655       785
# 3    Spirited Away-style bustling market street   1629    1954       212
# 4  Magical Ghibli forest with floating lanterns   2573    1281       913
#
#     platform  generation_time  gpu_usage  file_size_kb resolution  \
# 0     Reddit             4.80         49          1684  1024x1024
# 1     Reddit            11.11         81          2808  1024x1024
# ...

# %%
sns.countplot(data=ghibli,x='platform',palette='dark')
# Out:
# <Axes: xlabel='platform', ylabel='count'>

# %%
sns.countplot(data=ghibli,x='is_hand_edited',palette='Set1')
# Out:
# <Axes: xlabel='is_hand_edited', ylabel='count'>

# %%
sns.countplot(data=ghibli,x='ethical_concerns_flag',palette='ch:45')
# Out:
# <Axes: xlabel='ethical_concerns_flag', ylabel='count'>

# %%
sns.countplot(data=ghibli,x='platform',palette='Dark2',hue='ethical_concerns_flag')
# Out:
# <Axes: xlabel='platform', ylabel='count'>

# %%
sns.countplot(data=ghibli,x='platform',palette='ch:45',hue='is_hand_edited')
# Out:
# <Axes: xlabel='platform', ylabel='count'>

# %%
sns.countplot(data=ghibli,x='ethical_concerns_flag',palette='hls',hue='is_hand_edited')
# Out:
# <Axes: xlabel='ethical_concerns_flag', ylabel='count'>

# %%
sns.countplot(data=ghibli,x='ethical_concerns_flag',palette='ch:45')
# Out:
# <Axes: xlabel='ethical_concerns_flag', ylabel='count'>

# %%
ghibli.head()
# Out:
#                                image_id   user_id  \
# 0  77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1  7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2  d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3  cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4  7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
#
#                                          prompt  likes  shares  comments  \
# 0  Studio Ghibli-inspired ocean with giant fish    916     410       555
# 1                Ghibli-style village at sunset   2965    1361       417
# 2   A lone traveler exploring an enchanted ruin   4727     655       785
# 3    Spirited Away-style bustling market street   1629    1954       212
# 4  Magical Ghibli forest with floating lanterns   2573    1281       913
#
#     platform  generation_time  gpu_usage  file_size_kb resolution  \
# 0     Reddit             4.80         49          1684  1024x1024
# 1     Reddit            11.11         81          2808  1024x1024
# ...

# %%
sns.lmplot(data=ghibli,x='likes',y='shares',palette='Set1',hue='ethical_concerns_flag')

# %%
sns.lmplot(data=ghibli,x='likes',y='shares',palette='Set1',hue='platform')

# %%
sns.lmplot(data=ghibli,x='comments',y='shares',palette='dark',hue='platform')

# %%
sns.lmplot(data=ghibli,x='generation_time',y='gpu_usage',palette='Dark2',hue='platform')

# %%
sns.lmplot(data=ghibli,x='generation_time',y='file_size_kb',palette='ch:45',hue='platform')

# %%
sns.lmplot(data=ghibli,x='style_accuracy_score',y='file_size_kb',palette='hls',hue='platform')

# %%
ghibli.head()
# Out:
#                                image_id   user_id  \
# 0  77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1  7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2  d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3  cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4  7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
#
#                                          prompt  likes  shares  comments  \
# 0  Studio Ghibli-inspired ocean with giant fish    916     410       555
# 1                Ghibli-style village at sunset   2965    1361       417
# 2   A lone traveler exploring an enchanted ruin   4727     655       785
# 3    Spirited Away-style bustling market street   1629    1954       212
# 4  Magical Ghibli forest with floating lanterns   2573    1281       913
#
#     platform  generation_time  gpu_usage  file_size_kb resolution  \
# 0     Reddit             4.80         49          1684  1024x1024
# 1     Reddit            11.11         81          2808  1024x1024
# ...

# %%
sns.jointplot(data=ghibli,x='likes',y='shares',color='g',hue='ethical_concerns_flag')

# %%
sns.jointplot(data=ghibli,x='comments',y='shares',palette='dark',hue='platform')

# %%
sns.jointplot(data=ghibli,x='generation_time',y='gpu_usage',palette='Dark2',hue='platform')

# %%
sns.jointplot(data=ghibli,x='generation_time',y='file_size_kb',palette='ch:45',hue='platform')

# %%
sns.jointplot(data=ghibli,x='style_accuracy_score',y='file_size_kb',palette='hls',hue='platform')

# %%
sns.jointplot(data=ghibli,x='generation_time',y='file_size_kb',color='r',kind='hex')

# %%
sns.jointplot(data=ghibli,x='generation_time',y='gpu_usage',color='b',kind='reg')

# %%
sns.jointplot(data=ghibli,x='likes',y='shares',color='Orange',kind='kde')

# %%
ghibli.head()
# Out:
#                                image_id   user_id  \
# 0  77ce5c72-eb45-4651-bcb1-c0677c0fceaf  6a7adf3d
# 1  7d66c67f-0d11-4ef9-895c-d865ef11fe40  523b8706
# 2  d7978afd-3932-4cce-9a21-5f9bf2bc1f64  0e02592a
# 3  cb34636a-a15c-4b15-999c-759dbb8896fe  9ed78a42
# 4  7511fbb8-db05-4584-a3a4-e8bb525ed58b  69ec8f02
#
#                                          prompt  likes  shares  comments  \
# 0  Studio Ghibli-inspired ocean with giant fish    916     410       555
# 1                Ghibli-style village at sunset   2965    1361       417
# 2   A lone traveler exploring an enchanted ruin   4727     655       785
# 3    Spirited Away-style bustling market street   1629    1954       212
# 4  Magical Ghibli forest with floating lanterns   2573    1281       913
#
#     platform  generation_time  gpu_usage  file_size_kb resolution  \
# 0     Reddit             4.80         49          1684  1024x1024
# 1     Reddit            11.11         81          2808  1024x1024
# ...

# %%
sns.boxplot(data=ghibli,x='platform',y='likes',palette='dark')
# Out:
# <Axes: xlabel='platform', ylabel='likes'>

# %%
sns.boxplot(data=ghibli,x='platform',y='generation_time',palette='Dark2')
# Out:
# <Axes: xlabel='platform', ylabel='generation_time'>

# %%
sns.boxplot(data=ghibli,x='is_hand_edited',y='generation_time',palette='hls')
# Out:
# <Axes: xlabel='is_hand_edited', ylabel='generation_time'>

# %%
sns.boxplot(data=ghibli,x='ethical_concerns_flag',y='generation_time',palette='Set1')
# Out:
# <Axes: xlabel='ethical_concerns_flag', ylabel='generation_time'>
