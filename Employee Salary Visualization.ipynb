# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
emp=pd.read_csv(r'C:\Users\admin\Downloads\archive\Employee_Salary_Dataset.csv')

# %%
emp.head()
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
emp.shape
# Out:
# (35, 5)

# %%
emp.tail()
# Out:
#     ID  Experience_Years  Age  Gender   Salary
# 30  31                10   34    Male    80000
# 31  32                15   54    Male   900000
# 32  33                20   55  Female  1540000
# 33  34                19   53  Female  9300000
# 34  35                16   49    Male  7600000

# %%
emp.isnull()
# Out:
#        ID  Experience_Years    Age  Gender  Salary
# 0   False             False  False   False   False
# 1   False             False  False   False   False
# 2   False             False  False   False   False
# 3   False             False  False   False   False
# 4   False             False  False   False   False
# 5   False             False  False   False   False
# 6   False             False  False   False   False
# 7   False             False  False   False   False
# 8   False             False  False   False   False
# 9   False             False  False   False   False
# 10  False             False  False   False   False
# 11  False             False  False   False   False
# 12  False             False  False   False   False
# 13  False             False  False   False   False
# 14  False             False  False   False   False
# 15  False             False  False   False   False
# 16  False             False  False   False   False
# ...

# %%
emp.isnull().sum()
# Out:
# ID                  0
# Experience_Years    0
# Age                 0
# Gender              0
# Salary              0
# dtype: int64

# %%
emp.columns
# Out:
# Index(['ID', 'Experience_Years', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
len(emp.columns)
# Out:
# 5

# %%
emp.describe()
# Out:
#               ID  Experience_Years        Age        Salary
# count  35.000000          35.00000  35.000000  3.500000e+01
# mean   18.000000           9.20000  35.485714  2.059147e+06
# std    10.246951           7.55295  14.643552  3.170124e+06
# min     1.000000           1.00000  17.000000  3.000000e+03
# 25%     9.500000           2.50000  22.500000  2.250000e+04
# 50%    18.000000           6.00000  29.000000  2.500000e+05
# 75%    26.500000          15.00000  53.500000  3.270000e+06
# max    35.000000          27.00000  62.000000  1.000000e+07

# %%
emp.dtypes
# Out:
# ID                   int64
# Experience_Years     int64
# Age                  int64
# Gender              object
# Salary               int64
# dtype: object

# %%
emp.head()
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
#emp['Salary']=emp['Salary'].astype(int)

# %%
vis=sns.distplot(emp.Salary)

# %%
vis=sns.distplot(emp.Experience_Years)

# %%
vis=sns.distplot(emp.Age)

# %%
sns.displot(emp.Salary)

# %%
plt.plot(emp.Salary)

# %%
plt.plot(emp.Experience_Years,c='r')

# %%
plt.boxplot(data=emp,x='Age')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20006982390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20006981a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20006982180>],
#  'medians': [<matplotlib.lines.Line2D at 0x20006982d20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20006983170>],
#  'means': []}

# %%
sns.lmplot(data=emp,x='Age',y='Experience_Years')

# %%
sns.lmplot(data=emp,x='Age',y='Experience_Years',fit_reg=False)

# %%
sns.lmplot(data=emp,x='Experience_Years',y='Salary',fit_reg=True,hue='Age')

# %%
sns.distplot(emp.Experience_Years,bins=20,)
# Out:
# <Axes: xlabel='Experience_Years', ylabel='Density'>

# %%
plt.hist(emp.Age,bins=20)
# Out:
# (array([2., 5., 5., 0., 4., 2., 0., 2., 2., 1., 1., 0., 0., 0., 1., 0., 8.,
#         0., 0., 2.]),
#  array([17.  , 19.25, 21.5 , 23.75, 26.  , 28.25, 30.5 , 32.75, 35.  ,
#         37.25, 39.5 , 41.75, 44.  , 46.25, 48.5 , 50.75, 53.  , 55.25,
#         57.5 , 59.75, 62.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.boxplot(data=emp,x='Experience_Years',y='Salary')
# Out:
# <Axes: xlabel='Experience_Years', ylabel='Salary'>

# %%
sns.jointplot(data=emp,x='Experience_Years',y='Salary')

# %%
sns.set_style('darkgrid')
sns.jointplot(data=emp,x='Age',y='Experience_Years')

# %%
emp.plot(kind='line')
# Out:
# <Axes: >

# %%
emp.plot(kind='barh')
# Out:
# <Axes: >
