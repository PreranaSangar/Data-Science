# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
bollywood=pd.read_csv(r'C:\Users\admin\Downloads\Data for repository.csv')

# %%
bollywood
# Out:
#                              Movie Name Release Period Whether Remake  \
# 0                           Golden Boys         Normal             No
# 1                         Kaccha Limboo        Holiday             No
# 2                      Not A Love Story        Holiday             No
# 3                            Qaidi Band        Holiday             No
# 4                             Chaatwali        Holiday             No
# ...                                 ...            ...            ...
# 1693                         Fight Club        Holiday             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
# 1697                   Mr. Hot Mr. Kool         Normal             No
#
#      Whether Franchise     Genre New Actor New Director New Music Director  \
# ...

# %%
bollywood.shape
# Out:
# (1698, 14)

# %%
bollywood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          1698 non-null   object
#  1   Release Period      1698 non-null   object
#  2   Whether Remake      1698 non-null   object
#  3   Whether Franchise   1698 non-null   object
#  4   Genre               1698 non-null   object
#  5   New Actor           1698 non-null   object
#  6   New Director        1698 non-null   object
#  7   New Music Director  1698 non-null   object
#  8   Lead Star           1698 non-null   object
#  9   Director            1698 non-null   object
#  10  Music Director      1698 non-null   object
#  11  Number of Screens   1698 non-null   int64
#  12  Revenue(INR)        1698 non-null   int64
#  13  Budget(INR)         1698 non-null   int64
# dtypes: int64(3), object(11)
# memory usage: 185.8+ KB

# %%
bollywood.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
bollywood.columns
# Out:
# Index(['Movie Name', 'Release Period', 'Whether Remake', 'Whether Franchise',
#        'Genre', 'New Actor', 'New Director', 'New Music Director', 'Lead Star',
#        'Director', 'Music Director', 'Number of Screens', 'Revenue(INR)',
#        'Budget(INR)'],
#       dtype='object')

# %%
bollywood.columns=['Movie_Name', 'Release_Period', 'Whether_Remake', 'Whether_Franchise','Genre', 'New_Actor', 'New_Director', 'New_Music_Director', 'Lead_Star','Director', 'Music_Director', 'Number_of_Screens', 'Revenue', 'Budget']

# %%
len(bollywood.columns)
# Out:
# 14

# %%
bollywood.dtypes
# Out:
# Movie_Name            object
# Release_Period        object
# Whether_Remake        object
# Whether_Franchise     object
# Genre                 object
# New_Actor             object
# New_Director          object
# New_Music_Director    object
# Lead_Star             object
# Director              object
# Music_Director        object
# Number_of_Screens      int64
# Revenue                int64
# Budget                 int64
# dtype: object

# %%
bollywood.describe()
# Out:
#        Number_of_Screens       Revenue        Budget
# count        1698.000000  1.698000e+03  1.698000e+03
# mean          553.831567  1.501674e+08  2.377287e+08
# std           782.951839  2.434838e+08  6.134398e+08
# min             1.000000  3.250000e+05  7.250000e+03
# 25%            30.000000  1.500000e+07  1.150000e+06
# 50%           200.000000  5.500000e+07  1.240000e+07
# 75%           800.000000  1.900000e+08  1.778325e+08
# max          4600.000000  2.100000e+09  8.016120e+09

# %%
bollywood.describe().transpose()
# Out:
#                     count          mean           std       min         25%  \
# Number_of_Screens  1698.0  5.538316e+02  7.829518e+02       1.0        30.0
# Revenue            1698.0  1.501674e+08  2.434838e+08  325000.0  15000000.0
# Budget             1698.0  2.377287e+08  6.134398e+08    7250.0   1150000.0
#
#                           50%          75%           max
# Number_of_Screens       200.0        800.0  4.600000e+03
# Revenue            55000000.0  190000000.0  2.100000e+09
# Budget             12400000.0  177832500.0  8.016120e+09

# %%
bollywood.head()
# Out:
#          Movie_Name Release_Period Whether_Remake Whether_Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New_Actor New_Director New_Music_Director         Lead_Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music_Director  Number_of_Screens    Revenue    Budget
# ...

# %%
sns.distplot(bollywood.Number_of_Screens,color='r',bins=20)
# Out:
# <Axes: xlabel='Number_of_Screens', ylabel='Density'>

# %%
sns.distplot(bollywood.Revenue,color='g',bins=20)
# Out:
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
sns.distplot(bollywood.Budget,color='m',bins=20)
# Out:
# <Axes: xlabel='Budget', ylabel='Density'>

# %%
bollywood.head()
# Out:
#          Movie_Name Release_Period Whether_Remake Whether_Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New_Actor New_Director New_Music_Director         Lead_Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music_Director  Number_of_Screens    Revenue    Budget
# ...

# %%
sns.countplot(data=bollywood,x='Whether_Remake',palette='rocket')
# Out:
# <Axes: xlabel='Whether_Remake', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='Release_Period',palette='hls')
# Out:
# <Axes: xlabel='Release_Period', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='Whether_Franchise',palette='magma')
# Out:
# <Axes: xlabel='Whether_Franchise', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='Genre',palette='Set1')
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='New_Actor',palette='dark')
# Out:
# <Axes: xlabel='New_Actor', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='New_Director',palette='cividis')
# Out:
# <Axes: xlabel='New_Director', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='New_Music_Director',palette='colorblind')
# Out:
# <Axes: xlabel='New_Music_Director', ylabel='count'>

# %%
bollywood.head()
# Out:
#          Movie_Name Release_Period Whether_Remake Whether_Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New_Actor New_Director New_Music_Director         Lead_Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music_Director  Number_of_Screens    Revenue    Budget
# ...

# %%
sns.countplot(data=bollywood,x='Release_Period',hue='Whether_Remake',palette='mako')
# Out:
# <Axes: xlabel='Release_Period', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='Whether_Franchise',hue='Genre',palette='dark')
# Out:
# <Axes: xlabel='Whether_Franchise', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='New_Actor',hue='New_Director',palette='muted')
# Out:
# <Axes: xlabel='New_Actor', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='New_Music_Director',hue='Release_Period',palette='rocket')
# Out:
# <Axes: xlabel='New_Music_Director', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='Release_Period',hue='Genre',palette='Dark2')
# Out:
# <Axes: xlabel='Release_Period', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='Genre',hue='New_Actor',palette='magma')
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
sns.countplot(data=bollywood,x='Genre',hue='New_Director',palette='colorblind')
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
bollywood.head()
# Out:
#          Movie_Name Release_Period Whether_Remake Whether_Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New_Actor New_Director New_Music_Director         Lead_Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music_Director  Number_of_Screens    Revenue    Budget
# ...

# %%
sns.boxenplot(data=bollywood,x='Release_Period',y='Number_of_Screens',palette='hls')
# Out:
# <Axes: xlabel='Release_Period', ylabel='Number_of_Screens'>

# %%
sns.boxenplot(data=bollywood,x='Release_Period',y='Revenue',palette='dark')
# Out:
# <Axes: xlabel='Release_Period', ylabel='Revenue'>

# %%
sns.boxenplot(data=bollywood,x='Release_Period',y='Budget',palette='tab20')
# Out:
# <Axes: xlabel='Release_Period', ylabel='Budget'>

# %%
sns.boxenplot(data=bollywood,x='Whether_Remake',y='Revenue',palette='magma')
# Out:
# <Axes: xlabel='Whether_Remake', ylabel='Revenue'>

# %%
sns.boxenplot(data=bollywood,x='Whether_Franchise',y='Budget',palette='rocket')
# Out:
# <Axes: xlabel='Whether_Franchise', ylabel='Budget'>

# %%
sns.boxenplot(data=bollywood,x='Genre',y='Number_of_Screens',palette='Dark2')
# Out:
# <Axes: xlabel='Genre', ylabel='Number_of_Screens'>

# %%
sns.boxenplot(data=bollywood,x='Genre',y='Revenue',palette='tab10')
# Out:
# <Axes: xlabel='Genre', ylabel='Revenue'>

# %%
sns.boxenplot(data=bollywood,x='Genre',y='Budget',palette='deep')
# Out:
# <Axes: xlabel='Genre', ylabel='Budget'>

# %%
sns.boxenplot(data=bollywood,x='New_Actor',y='Revenue',palette='colorblind')
# Out:
# <Axes: xlabel='New_Actor', ylabel='Revenue'>

# %%
sns.boxenplot(data=bollywood,x='New_Director',y='Budget',palette='mako')
# Out:
# <Axes: xlabel='New_Director', ylabel='Budget'>

# %%
sns.boxenplot(data=bollywood,x='New_Music_Director',y='Budget',palette='Set1')
# Out:
# <Axes: xlabel='New_Music_Director', ylabel='Budget'>

# %%
bollywood.head()
# Out:
#          Movie_Name Release_Period Whether_Remake Whether_Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New_Actor New_Director New_Music_Director         Lead_Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music_Director  Number_of_Screens    Revenue    Budget
# ...

# %%
sns.lmplot(data=bollywood,x='Number_of_Screens',y='Revenue',palette='dark',hue='Release_Period')

# %%
sns.lmplot(data=bollywood,x='Number_of_Screens',y='Revenue',palette='hls',hue='Whether_Remake')

# %%
sns.lmplot(data=bollywood,x='Number_of_Screens',y='Revenue',palette='colorblind',hue='Whether_Franchise')

# %%
sns.lmplot(data=bollywood,x='Revenue',y='Budget',palette='cividis',hue='Genre')

# %%
sns.lmplot(data=bollywood,x='Revenue',y='Budget',palette='mako',hue='New_Actor')

# %%
sns.lmplot(data=bollywood,x='Revenue',y='Budget',palette='Set1',hue='New_Director')

# %%
sns.lmplot(data=bollywood,x='Budget',y='Number_of_Screens',palette='deep',hue='New_Music_Director')

# %%
sns.lmplot(data=bollywood,x='Budget',y='Number_of_Screens',palette='Dark2',hue='Genre')

# %%
sns.lmplot(data=bollywood,x='Budget',y='Number_of_Screens',palette='rocket',hue='Release_Period')

# %%
bollywood.head()
# Out:
#          Movie_Name Release_Period Whether_Remake Whether_Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New_Actor New_Director New_Music_Director         Lead_Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music_Director  Number_of_Screens    Revenue    Budget
# ...

# %%
sns.jointplot(data=bollywood,x='Number_of_Screens',y='Revenue',color='c',kind='hex')

# %%
sns.jointplot(data=bollywood,x='Revenue',y='Budget',color='m',kind='kde')

# %%
sns.jointplot(data=bollywood,x='Budget',y='Number_of_Screens',color='g',kind='scatter')

# %%
bollywood.head()
# Out:
#          Movie_Name Release_Period Whether_Remake Whether_Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New_Actor New_Director New_Music_Director         Lead_Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music_Director  Number_of_Screens    Revenue    Budget
# ...

# %%
sns.stripplot(data=bollywood,x='Release_Period',y='Number_of_Screens',palette='Set1')
# Out:
# <Axes: xlabel='Release_Period', ylabel='Number_of_Screens'>

# %%
sns.stripplot(data=bollywood,x='Whether_Remake',y='Revenue',palette='mako')
# Out:
# <Axes: xlabel='Whether_Remake', ylabel='Revenue'>

# %%
sns.stripplot(data=bollywood,x='Whether_Franchise',y='Budget',palette='dark')
# Out:
# <Axes: xlabel='Whether_Franchise', ylabel='Budget'>

# %%
sns.stripplot(data=bollywood,x='Genre',y='Number_of_Screens',palette='rocket')
# Out:
# <Axes: xlabel='Genre', ylabel='Number_of_Screens'>

# %%
sns.stripplot(data=bollywood,x='New_Music_Director',y='Budget',palette='deep')
# Out:
# <Axes: xlabel='New_Music_Director', ylabel='Budget'>

# %%
sns.stripplot(data=bollywood,x='Genre',y='Revenue',palette='Dark2')
# Out:
# <Axes: xlabel='Genre', ylabel='Revenue'>

# %%
sns.stripplot(data=bollywood,x='New_Actor',y='Number_of_Screens',palette='magma')
# Out:
# <Axes: xlabel='New_Actor', ylabel='Number_of_Screens'>

# %%
sns.stripplot(data=bollywood,x='New_Director',y='Revenue',palette='colorblind')
# Out:
# <Axes: xlabel='New_Director', ylabel='Revenue'>

# %%
bollywood.head()
# Out:
#          Movie_Name Release_Period Whether_Remake Whether_Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New_Actor New_Director New_Music_Director         Lead_Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music_Director  Number_of_Screens    Revenue    Budget
# ...

# %%
sns.kdeplot(data=bollywood,x='Number_of_Screens',hue='Release_Period',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='Number_of_Screens', ylabel='Density'>

# %%
sns.kdeplot(data=bollywood,x='Revenue',hue='Whether_Remake',palette='hls',fill=True)
# Out:
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
sns.kdeplot(data=bollywood,x='Budget',hue='Whether_Franchise',palette='dark',fill=True)
# Out:
# <Axes: xlabel='Budget', ylabel='Density'>

# %%
sns.kdeplot(data=bollywood,x='Number_of_Screens',hue='Genre',palette='cividis',fill=True)
# Out:
# <Axes: xlabel='Number_of_Screens', ylabel='Density'>

# %%
sns.kdeplot(data=bollywood,x='Revenue',hue='Genre',palette='tab20',fill=True)
# Out:
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
sns.kdeplot(data=bollywood,x='Budget',hue='Genre',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='Budget', ylabel='Density'>

# %%
sns.kdeplot(data=bollywood,x='Number_of_Screens',hue='New_Actor',palette='muted',fill=True)
# Out:
# <Axes: xlabel='Number_of_Screens', ylabel='Density'>

# %%
sns.kdeplot(data=bollywood,x='Revenue',hue='New_Director',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
sns.kdeplot(data=bollywood,x='Budget',hue='New_Music_Director',palette='colorblind',fill=True)
# Out:
# <Axes: xlabel='Budget', ylabel='Density'>

# %%
sns.pairplot(bollywood, hue="Genre",palette='dark')

# %%
sns.pairplot(bollywood, hue="Release_Period",palette='muted')

# %%
sns.pairplot(bollywood, hue="New_Director",palette='cividis')

# %%
sns.pairplot(bollywood, hue="New_Music_Director",palette='Set1')

# %%
sns.pairplot(bollywood, hue="Whether_Franchise",palette='colorblind')

# %%
sns.pairplot(bollywood, hue="New_Actor",palette='Dark2')

# %%
sns.pairplot(bollywood, hue="Whether_Remake",palette='rocket')
