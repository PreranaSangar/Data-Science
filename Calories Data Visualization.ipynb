# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="deep")

# %%
calories=pd.read_csv(r'C:\Users\admin\Downloads\archive\calories.csv')

# %%
calories
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
calories.shape
# Out:
# (15000, 9)

# %%
calories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
calories.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
calories.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories'],
#       dtype='object')

# %%
len(calories.columns)
# Out:
# 9

# %%
calories.dtypes
# Out:
# User_ID         int64
# Gender         object
# Age             int64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object

# %%
calories.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
calories.describe().transpose()
# Out:
#               count          mean           std         min          25%  \
# User_ID     15000.0  1.497736e+07  2.872851e+06  10001159.0  12474190.75
# Age         15000.0  4.278980e+01  1.698026e+01        20.0        28.00
# Height      15000.0  1.744651e+02  1.425811e+01       123.0       164.00
# Weight      15000.0  7.496687e+01  1.503566e+01        36.0        63.00
# Duration    15000.0  1.553060e+01  8.319203e+00         1.0         8.00
# Heart_Rate  15000.0  9.551853e+01  9.583328e+00        67.0        88.00
# Body_Temp   15000.0  4.002545e+01  7.792299e-01        37.1        39.60
# Calories    15000.0  8.953953e+01  6.245698e+01         1.0        35.00
#
#                    50%          75%         max
# User_ID     14997285.0  17449278.75  19999647.0
# Age               39.0        56.00        79.0
# Height           175.0       185.00       222.0
# Weight            74.0        87.00       132.0
# Duration          16.0        23.00        30.0
# ...

# %%
calories.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
sns.distplot(calories.Age,color='b',bins=16)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(calories.Height,color='r',bins=16)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(calories.Weight,color='g',bins=16)
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.distplot(calories.Duration,color='m',bins=16)
# Out:
# <Axes: xlabel='Duration', ylabel='Density'>

# %%
sns.distplot(calories.Heart_Rate,color='k',bins=16)
# Out:
# <Axes: xlabel='Heart_Rate', ylabel='Density'>

# %%
sns.distplot(calories.Body_Temp,color='y',bins=16)
# Out:
# <Axes: xlabel='Body_Temp', ylabel='Density'>

# %%
sns.distplot(calories.Calories,color='purple',bins=16)
# Out:
# <Axes: xlabel='Calories', ylabel='Density'>

# %%
calories.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
sns.countplot(data=calories,x='Gender',palette='dark')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
calories.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
sns.lmplot(data=calories,x='Age',y='Height',palette='deep',hue='Gender')

# %%
sns.lmplot(data=calories,x='Height',y='Weight',palette='hls',hue='Gender')

# %%
sns.lmplot(data=calories,x='Duration',y='Heart_Rate',palette='Dark2',hue='Gender')

# %%
sns.lmplot(data=calories,x='Weight',y='Duration',palette='cividis',hue='Gender')

# %%
sns.lmplot(data=calories,x='Heart_Rate',y='Body_Temp',palette='tab10',hue='Gender')

# %%
sns.lmplot(data=calories,x='Body_Temp',y='Calories',palette='mako',hue='Gender')

# %%
sns.lmplot(data=calories,x='Age',y='Calories',palette='rocket',hue='Gender')

# %%
sns.lmplot(data=calories,x='Age',y='Weight',palette='colorblind',hue='Gender')

# %%
calories.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
sns.jointplot(data=calories,x='Age',y='Height',palette='deep',hue='Gender')

# %%
sns.jointplot(data=calories,x='Height',y='Weight',palette='hls',hue='Gender')

# %%
sns.jointplot(data=calories,x='Duration',y='Heart_Rate',palette='Dark2',hue='Gender')

# %%
sns.jointplot(data=calories,x='Weight',y='Duration',palette='cividis',hue='Gender')

# %%
sns.jointplot(data=calories,x='Heart_Rate',y='Body_Temp',palette='tab10',hue='Gender')

# %%
sns.jointplot(data=calories,x='Body_Temp',y='Calories',palette='mako',hue='Gender')

# %%
sns.jointplot(data=calories,x='Age',y='Calories',palette='rocket',hue='Gender')

# %%
sns.jointplot(data=calories,x='Age',y='Weight',palette='colorblind',hue='Gender')

# %%
calories.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
sns.jointplot(data=calories,x='Age',y='Height',color='m',kind='hex')

# %%
sns.jointplot(data=calories,x='Height',y='Weight',color='c',kind='reg')

# %%
sns.jointplot(data=calories,x='Duration',y='Heart_Rate',color='g',kind='scatter')

# %%
sns.jointplot(data=calories,x='Heart_Rate',y='Body_Temp',color='r',kind='hex')

# %%
sns.jointplot(data=calories,x='Body_Temp',y='Calories',color='orange',kind='resid')

# %%
sns.jointplot(data=calories,x='Age',y='Calories',color='b',kind='resid')

# %%
sns.jointplot(data=calories,x='Weight',y='Duration',color='k',kind='hex')

# %%
calories.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
sns.stripplot(data=calories,x='Gender',y='Age',palette='bright')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.stripplot(data=calories,x='Gender',y='Height',palette='dark')
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %%
sns.stripplot(data=calories,x='Gender',y='Weight',palette='hls')
# Out:
# <Axes: xlabel='Gender', ylabel='Weight'>

# %%
sns.stripplot(data=calories,x='Gender',y='Duration',palette='colorblind')
# Out:
# <Axes: xlabel='Gender', ylabel='Duration'>

# %%
sns.stripplot(data=calories,x='Gender',y='Heart_Rate',palette='mako')
# Out:
# <Axes: xlabel='Gender', ylabel='Heart_Rate'>

# %%
sns.stripplot(data=calories,x='Gender',y='Body_Temp',palette='rocket')
# Out:
# <Axes: xlabel='Gender', ylabel='Body_Temp'>

# %%
sns.stripplot(data=calories,x='Gender',y='Calories',palette='Dark2')
# Out:
# <Axes: xlabel='Gender', ylabel='Calories'>

# %%
calories.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
sns.kdeplot(data=calories,x='Age',hue='Gender',palette='mako',fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=calories,x='Height',hue='Gender',palette='cividis',fill=True)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(data=calories,x='Weight',hue='Gender',palette='bright',fill=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.kdeplot(data=calories,x='Duration',hue='Gender',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Duration', ylabel='Density'>

# %%
sns.kdeplot(data=calories,x='Heart_Rate',hue='Gender',palette='magma',fill=True)
# Out:
# <Axes: xlabel='Heart_Rate', ylabel='Density'>

# %%
sns.kdeplot(data=calories,x='Body_Temp',hue='Gender',palette='colorblind',fill=True)
# Out:
# <Axes: xlabel='Body_Temp', ylabel='Density'>

# %%
sns.kdeplot(data=calories,x='Calories',hue='Gender',palette='dark',fill=True)
# Out:
# <Axes: xlabel='Calories', ylabel='Density'>

# %%
calories.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
sns.boxplot(data=calories,x='Gender',y='Age',palette='dark')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(data=calories,x='Gender',y='Weight',palette='cividis')
# Out:
# <Axes: xlabel='Gender', ylabel='Weight'>

# %%
sns.boxplot(data=calories,x='Gender',y='Height',palette='deep')
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %%
sns.boxplot(data=calories,x='Gender',y='Duration',palette='mako')
# Out:
# <Axes: xlabel='Gender', ylabel='Duration'>

# %%
sns.boxplot(data=calories,x='Gender',y='Heart_Rate',palette='colorblind')
# Out:
# <Axes: xlabel='Gender', ylabel='Heart_Rate'>

# %%
sns.boxplot(data=calories,x='Gender',y='Body_Temp',palette='rocket')
# Out:
# <Axes: xlabel='Gender', ylabel='Body_Temp'>

# %%
sns.boxplot(data=calories,x='Gender',y='Calories',palette='Dark2')
# Out:
# <Axes: xlabel='Gender', ylabel='Calories'>
