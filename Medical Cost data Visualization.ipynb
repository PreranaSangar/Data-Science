# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
medical=pd.read_csv(r'C:\Users\admin\Downloads\archive (1)\insurance.csv')

# %%
medical
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
medical.shape
# Out:
# (1338, 7)

# %%
medical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
medical.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
medical.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
len(medical.columns)
# Out:
# 7

# %%
medical.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
medical.describe().transpose()
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
medical.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
medical.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
medical.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.distplot(medical.age,color='c')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(medical.bmi,color='r')
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(medical.children,color='purple')
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
sns.distplot(medical.charges,color='g')
# Out:
# <Axes: xlabel='charges', ylabel='Density'>

# %%
medical.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.countplot(data=medical,x='sex',palette='colorblind')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=medical,x='children',palette='dark')
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(data=medical,x='smoker',palette='mako')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=medical,x='region',palette='hls')
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.countplot(data=medical,x='sex',palette='colorblind',hue='children')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=medical,x='region',palette='hls',hue='sex')
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.countplot(data=medical,x='children',palette='dark',hue='smoker')
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(data=medical,x='smoker',palette='mako',hue='region')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=medical,x='sex',palette='rocket',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=medical,x='sex',palette='deep',hue='region')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
medical.head
# Out:
# <bound method NDFrame.head of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
sns.lmplot(data=medical,x='age',y='children',palette='Set1',hue='sex')

# %%
sns.lmplot(data=medical,x='age',y='children',palette='hls',hue='smoker')

# %%
sns.lmplot(data=medical,x='age',y='bmi',palette='mako',hue='region')

# %%
sns.lmplot(data=medical,x='age',y='bmi',palette='magma',hue='sex')

# %%
sns.lmplot(data=medical,x='children',y='charges',palette='bright',hue='smoker')

# %%
sns.lmplot(data=medical,x='age',y='charges',palette='deep',hue='region')

# %%
medical.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.stripplot(data=medical,x='sex',y='age',palette='bright')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(data=medical,x='smoker',y='bmi',palette='mako')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.stripplot(data=medical,x='sex',y='charges',palette='deep')
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sns.stripplot(data=medical,x='smoker',y='charges',palette='rocket')
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
sns.stripplot(data=medical,x='region',y='children',palette='hls')
# Out:
# <Axes: xlabel='region', ylabel='children'>

# %%
sns.stripplot(data=medical,x='region',y='charges',palette='magma')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
medical.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.boxplot(data=medical,x='sex',y='age',palette='muted')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=medical,x='region',y='children',palette='mako')
# Out:
# <Axes: xlabel='region', ylabel='children'>

# %%
sns.boxplot(data=medical,x='smoker',y='bmi',palette='cividis')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.boxplot(data=medical,x='sex',y='children',palette='dark')
# Out:
# <Axes: xlabel='sex', ylabel='children'>

# %%
sns.boxplot(data=medical,x='region',y='charges',palette='crest')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.boxplot(data=medical,x='smoker',y='age',palette='flare')
# Out:
# <Axes: xlabel='smoker', ylabel='age'>

# %%
sns.boxenplot(data=medical,x='region',y='children',palette='mako')
# Out:
# <Axes: xlabel='region', ylabel='children'>

# %%
sns.boxenplot(data=medical,x='region',y='children',palette='YlGn')
# Out:
# <Axes: xlabel='region', ylabel='children'>

# %%
sns.boxenplot(data=medical,x='sex',y='children',palette='YlGnBu')
# Out:
# <Axes: xlabel='sex', ylabel='children'>

# %%
sns.boxenplot(data=medical,x='smoker',y='bmi',palette='cividis')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.boxenplot(data=medical,x='region',y='charges',palette='crest')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.boxenplot(data=medical,x='smoker',y='age',palette='flare')
# Out:
# <Axes: xlabel='smoker', ylabel='age'>

# %%
medical.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.kdeplot(data=medical, x='age', hue='smoker', fill=True, palette='flare')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=medical,x='charges',hue='region',palette='crest',fill=True)
# Out:
# <Axes: xlabel='charges', ylabel='Density'>

# %%
sns.kdeplot(data=medical,x='children',hue='sex',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
sns.kdeplot(data=medical,x='bmi',hue='smoker',palette='cividis',fill=True)
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
sns.kdeplot(data=medical,x='children',hue='region',palette='YlGn',fill=True)
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
sns.kdeplot(data=medical,x='age',hue='region',palette='mako',fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
medical.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
g = sns.JointGrid(x="age", y="bmi", data=medical, height=5, ratio=2)
g = g.plot_joint(sns.kdeplot, cmap="Reds_d")
g = g.plot_marginals(sns.kdeplot, color="r", shade=True)

# %%
g = sns.JointGrid(x="children", y="charges", data=medical, height=5, ratio=2)
g = g.plot_joint(sns.kdeplot, cmap="magma")
g = g.plot_marginals(sns.kdeplot, color="orange", shade=True)

# %%
g = sns.JointGrid(x="age", y="charges", data=medical, height=5, ratio=2)
g = g.plot_joint(sns.kdeplot,cmap="mako")
g = g.plot_marginals(sns.kdeplot,fill=True,color="k")

# %%
g = sns.JointGrid(x="age", y="children", data=medical, height=5, ratio=2)
g = g.plot_joint(sns.kdeplot,cmap="mako")
g = g.plot_marginals(sns.kdeplot, fill=True,color="g")
