# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=7,4
sns.set_theme(style="whitegrid", palette="dark")

# %%
sleep=pd.read_csv(r'C:\Users\admin\Downloads\archive\Sleep_Efficiency.csv')

# %%
sleep
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
sleep.shape
# Out:
# (452, 15)

# %%
sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
# ...

# %%
sleep.isnull().sum()
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Bedtime                    0
# Wakeup time                0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       14
# Smoking status             0
# Exercise frequency         6
# dtype: int64

# %%
sleep.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Bedtime', 'Wakeup time', 'Sleep duration',
#        'Sleep efficiency', 'REM sleep percentage', 'Deep sleep percentage',
#        'Light sleep percentage', 'Awakenings', 'Caffeine consumption',
#        'Alcohol consumption', 'Smoking status', 'Exercise frequency'],
#       dtype='object')

# %%
len(sleep.columns)
# Out:
# 15

# %%
sleep.columns=['ID', 'Age', 'Gender', 'Bedtime', 'Wakeup_time', 'Sleep_duration','Sleep_efficiency', 'REM_sleep_percentage', 'Deep_sleep_percentage','Light_sleep_percentage', 'Awakenings', 'Caffeine_consumption','Alcohol_consumption', 'Smoking_status', 'Exercise_frequency']

# %%
sleep['Awakenings']=sleep['Awakenings'].fillna(np.mean(pd.to_numeric(sleep['Awakenings'])))
sleep['Caffeine_consumption']=sleep['Caffeine_consumption'].fillna(np.mean(pd.to_numeric(sleep['Caffeine_consumption'])))
sleep['Alcohol_consumption']=sleep['Alcohol_consumption'].fillna(np.mean(pd.to_numeric(sleep['Alcohol_consumption'])))

# %%
sleep.dtypes
# Out:
# ID                          int64
# Age                         int64
# Gender                     object
# Bedtime                    object
# Wakeup_time                object
# Sleep_duration            float64
# Sleep_efficiency          float64
# REM_sleep_percentage        int64
# Deep_sleep_percentage       int64
# Light_sleep_percentage      int64
# Awakenings                float64
# Caffeine_consumption      float64
# Alcohol_consumption       float64
# Smoking_status             object
# Exercise_frequency        float64
# dtype: object

# %%
sleep.describe()
# Out:
#                ID         Age  Sleep_duration  Sleep_efficiency  \
# count  452.000000  452.000000      452.000000        452.000000
# mean   226.500000   40.285398        7.465708          0.788916
# std    130.625419   13.172250        0.866625          0.135237
# min      1.000000    9.000000        5.000000          0.500000
# 25%    113.750000   29.000000        7.000000          0.697500
# 50%    226.500000   40.000000        7.500000          0.820000
# 75%    339.250000   52.000000        8.000000          0.900000
# max    452.000000   69.000000       10.000000          0.990000
#
#        REM_sleep_percentage  Deep_sleep_percentage  Light_sleep_percentage  \
# count            452.000000             452.000000              452.000000
# mean              22.615044              52.823009               24.561947
# std                3.525963              15.654235               15.313665
# min               15.000000              18.000000                7.000000
# ...

# %%
sleep.describe().transpose()
# Out:
#                         count        mean         std   min       25%  \
# ID                      452.0  226.500000  130.625419   1.0  113.7500
# Age                     452.0   40.285398   13.172250   9.0   29.0000
# Sleep_duration          452.0    7.465708    0.866625   5.0    7.0000
# Sleep_efficiency        452.0    0.788916    0.135237   0.5    0.6975
# REM_sleep_percentage    452.0   22.615044    3.525963  15.0   20.0000
# Deep_sleep_percentage   452.0   52.823009   15.654235  18.0   48.2500
# Light_sleep_percentage  452.0   24.561947   15.313665   7.0   15.0000
# Awakenings              452.0    1.641204    1.326338   0.0    1.0000
# Caffeine_consumption    452.0   23.653396   29.353745   0.0    0.0000
# Alcohol_consumption     452.0    1.173516    1.596013   0.0    0.0000
# Exercise_frequency      446.0    1.791480    1.428134   0.0    0.0000
#
#                                50%     75%     max
# ID                      226.500000  339.25  452.00
# ...

# %%
sleep.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup_time  Sleep_duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep_efficiency  REM_sleep_percentage  Deep_sleep_percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light_sleep_percentage  Awakenings  Caffeine_consumption  \
# ...

# %%
sleep.tail()
# Out:
#       ID  Age  Gender              Bedtime          Wakeup_time  \
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep_duration  Sleep_efficiency  REM_sleep_percentage  \
# 447             7.5              0.91                    22
# 448             6.0              0.74                    28
# 449             8.5              0.55                    20
# 450             7.0              0.76                    18
# 451             7.5              0.63                    22
#
#      Deep_sleep_percentage  Light_sleep_percentage  Awakenings  \
# 447                     57                      21         0.0
# 448                     57                      15         4.0
# ...

# %%
sns.distplot(sleep.Age,color='b',bins=20)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(sleep.Sleep_duration,color='r',bins=20)
# Out:
# <Axes: xlabel='Sleep_duration', ylabel='Density'>

# %%
sns.distplot(sleep.Sleep_duration,color='g',bins=20)
# Out:
# <Axes: xlabel='Sleep_duration', ylabel='Density'>

# %%
sns.distplot(sleep.Sleep_efficiency,color='k',bins=20)
# Out:
# <Axes: xlabel='Sleep_efficiency', ylabel='Density'>

# %%
sns.distplot(sleep.REM_sleep_percentage,color='c',bins=20)
# Out:
# <Axes: xlabel='REM_sleep_percentage', ylabel='Density'>

# %%
sns.distplot(sleep.Deep_sleep_percentage,color='y',bins=20)
# Out:
# <Axes: xlabel='Deep_sleep_percentage', ylabel='Density'>

# %%
sns.distplot(sleep.Awakenings,color='purple',bins=20)
# Out:
# <Axes: xlabel='Awakenings', ylabel='Density'>

# %%
sns.distplot(sleep.Caffeine_consumption,color='g',bins=20)
# Out:
# <Axes: xlabel='Caffeine_consumption', ylabel='Density'>

# %%
sns.distplot(sleep.Light_sleep_percentage,color='orange',bins=20)
# Out:
# <Axes: xlabel='Light_sleep_percentage', ylabel='Density'>

# %%
sns.distplot(sleep.Exercise_frequency,color='r',bins=20)
# Out:
# <Axes: xlabel='Exercise_frequency', ylabel='Density'>

# %%
sleep.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup_time  Sleep_duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep_efficiency  REM_sleep_percentage  Deep_sleep_percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light_sleep_percentage  Awakenings  Caffeine_consumption  \
# ...

# %%
sns.countplot(data=sleep,x='Gender',palette='hls')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=sleep,x='Smoking_status',palette='rocket')
# Out:
# <Axes: xlabel='Smoking_status', ylabel='count'>

# %%
sns.countplot(data=sleep,x='Smoking_status',palette='magma',hue='Gender')
# Out:
# <Axes: xlabel='Smoking_status', ylabel='count'>

# %%
sns.countplot(data=sleep,x='Gender',palette='tab10',hue='Smoking_status')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sleep.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup_time  Sleep_duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep_efficiency  REM_sleep_percentage  Deep_sleep_percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light_sleep_percentage  Awakenings  Caffeine_consumption  \
# ...

# %%
sns.lmplot(data=sleep,x='Age',y='Sleep_duration',palette='deep',hue='Gender')

# %%
sns.lmplot(data=sleep,x='Age',y='Sleep_efficiency',palette='colorblind',hue='Gender')

# %%
sns.lmplot(data=sleep,x='Sleep_duration',y='Sleep_efficiency',palette='dark',hue='Smoking_status')

# %%
sns.lmplot(data=sleep,x='Age',y='Deep_sleep_percentage',palette='mako',hue='Smoking_status')

# %%
sns.lmplot(data=sleep,x='Deep_sleep_percentage',y='Light_sleep_percentage',palette='flare',hue='Gender')

# %%
sns.lmplot(data=sleep,x='Age',y='Caffeine_consumption',palette='viridis',hue='Smoking_status')

# %%
sns.lmplot(data=sleep,x='Awakenings',y='Deep_sleep_percentage',palette='plasma',hue='Gender')

# %%
sns.lmplot(data=sleep,x='Age',y='Exercise_frequency',palette='Dark2',hue='Smoking_status')

# %%
sns.jointplot(data=sleep,x='Age',y='Sleep_duration',palette='deep',hue='Gender')

# %%
sns.jointplot(data=sleep,x='Age',y='Sleep_efficiency',palette='colorblind',hue='Gender')

# %%
sns.jointplot(data=sleep,x='Sleep_duration',y='Sleep_efficiency',palette='dark',hue='Smoking_status')

# %%
sns.jointplot(data=sleep,x='Age',y='Deep_sleep_percentage',palette='mako',hue='Smoking_status')

# %%
sns.jointplot(data=sleep,x='Deep_sleep_percentage',y='Light_sleep_percentage',palette='flare',hue='Gender')

# %%
sns.jointplot(data=sleep,x='Age',y='Caffeine_consumption',palette='viridis',hue='Smoking_status')

# %%
sns.jointplot(data=sleep,x='Awakenings',y='Deep_sleep_percentage',palette='plasma',hue='Gender')

# %%
sns.jointplot(data=sleep,x='Age',y='Exercise_frequency',palette='Dark2',hue='Smoking_status')

# %%
sleep.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup_time  Sleep_duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep_efficiency  REM_sleep_percentage  Deep_sleep_percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light_sleep_percentage  Awakenings  Caffeine_consumption  \
# ...

# %%
sns.boxplot(data=sleep,x='Gender',y='Age',palette='Dark2')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(data=sleep,x='Smoking_status',y='Sleep_duration',palette='magma')
# Out:
# <Axes: xlabel='Smoking_status', ylabel='Sleep_duration'>

# %%
sns.boxplot(data=sleep,x='Gender',y='Sleep_efficiency',palette='deep')
# Out:
# <Axes: xlabel='Gender', ylabel='Sleep_efficiency'>

# %%
sns.boxplot(data=sleep,x='Smoking_status',y='Deep_sleep_percentage',palette='Set1')
# Out:
# <Axes: xlabel='Smoking_status', ylabel='Deep_sleep_percentage'>

# %%
sns.boxplot(data=sleep,x='Gender',y='Light_sleep_percentage',palette='dark')
# Out:
# <Axes: xlabel='Gender', ylabel='Light_sleep_percentage'>

# %%
sns.boxplot(data=sleep,x='Smoking_status',y='Awakenings',palette='hls')
# Out:
# <Axes: xlabel='Smoking_status', ylabel='Awakenings'>

# %%
sns.boxplot(data=sleep,x='Gender',y='Caffeine_consumption',palette='rocket')
# Out:
# <Axes: xlabel='Gender', ylabel='Caffeine_consumption'>

# %%
sns.boxplot(data=sleep,x='Smoking_status',y='Alcohol_consumption',palette='cividis')
# Out:
# <Axes: xlabel='Smoking_status', ylabel='Alcohol_consumption'>

# %%
sns.boxplot(data=sleep,x='Gender',y='Exercise_frequency',palette='mako')
# Out:
# <Axes: xlabel='Gender', ylabel='Exercise_frequency'>

# %%
sns.boxplot(data=sleep,x='Smoking_status',y='Exercise_frequency',palette='crest')
# Out:
# <Axes: xlabel='Smoking_status', ylabel='Exercise_frequency'>
