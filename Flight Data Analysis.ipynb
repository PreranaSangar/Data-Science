# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
airline=pd.read_csv(r'C:\Users\admin\Downloads\archive\Clean_Dataset.csv')

# %%
airline
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
airline.shape
# Out:
# (300153, 12)

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
airline.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
airline.dtypes
# Out:
# Unnamed: 0            int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
airline.describe()
# Out:
#           Unnamed: 0       duration      days_left          price
# count  300153.000000  300153.000000  300153.000000  300153.000000
# mean   150076.000000      12.221021      26.004751   20889.660523
# std     86646.852011       7.191997      13.561004   22697.767366
# min         0.000000       0.830000       1.000000    1105.000000
# 25%     75038.000000       6.830000      15.000000    4783.000000
# 50%    150076.000000      11.250000      26.000000    7425.000000
# 75%    225114.000000      16.170000      38.000000   42521.000000
# max    300152.000000      49.830000      49.000000  123071.000000

# %%
airline.describe().transpose()
# Out:
#                count           mean           std      min       25%  \
# Unnamed: 0  300153.0  150076.000000  86646.852011     0.00  75038.00
# duration    300153.0      12.221021      7.191997     0.83      6.83
# days_left   300153.0      26.004751     13.561004     1.00     15.00
# price       300153.0   20889.660523  22697.767366  1105.00   4783.00
#
#                   50%        75%        max
# Unnamed: 0  150076.00  225114.00  300152.00
# duration        11.25      16.17      49.83
# days_left       26.00      38.00      49.00
# price         7425.00   42521.00  123071.00

# %%
airline.drop(columns=['Unnamed: 0'], inplace=True)

# %%
airline
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
airline[['airline', 'flight']]
# Out:
#          airline   flight
# 0       SpiceJet  SG-8709
# 1       SpiceJet  SG-8157
# 2        AirAsia   I5-764
# 3        Vistara   UK-995
# 4        Vistara   UK-963
# ...          ...      ...
# 300148   Vistara   UK-822
# 300149   Vistara   UK-826
# 300150   Vistara   UK-832
# 300151   Vistara   UK-828
# 300152   Vistara   UK-822
#
# [300153 rows x 2 columns]

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.distplot(airline.duration,color='r',bins=20)
# Out:
# <Axes: xlabel='duration', ylabel='Density'>

# %%
sns.distplot(airline.days_left,color='m',bins=20)
# Out:
# <Axes: xlabel='days_left', ylabel='Density'>

# %%
sns.distplot(airline.price,color='g',bins=20)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.countplot(data=airline,x='airline',palette='dark')
# Out:
# <Axes: xlabel='airline', ylabel='count'>

# %%
sns.countplot(data=airline,x='source_city',palette='hls')
# Out:
# <Axes: xlabel='source_city', ylabel='count'>

# %%
sns.countplot(data=airline,x='departure_time',palette='mako')
# Out:
# <Axes: xlabel='departure_time', ylabel='count'>

# %%
sns.countplot(data=airline,x='stops',palette='tab20')
# Out:
# <Axes: xlabel='stops', ylabel='count'>

# %%
sns.countplot(data=airline,x='arrival_time',palette='rocket')
# Out:
# <Axes: xlabel='arrival_time', ylabel='count'>

# %%
sns.countplot(data=airline,x='destination_city',palette='Set2')
# Out:
# <Axes: xlabel='destination_city', ylabel='count'>

# %%
sns.countplot(data=airline,x='class',palette='ch:34')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.countplot(data=airline,x='airline',hue='source_city',palette='Dark2')
# Out:
# <Axes: xlabel='airline', ylabel='count'>

# %%
sns.countplot(data=airline,x='source_city',hue='departure_time',palette='tab20')
# Out:
# <Axes: xlabel='source_city', ylabel='count'>

# %%
sns.countplot(data=airline,x='stops',hue='arrival_time',palette='cividis')
# Out:
# <Axes: xlabel='stops', ylabel='count'>

# %%
sns.countplot(data=airline,x='departure_time',hue='stops',palette='Set2')
# Out:
# <Axes: xlabel='departure_time', ylabel='count'>

# %%
sns.countplot(data=airline,x='arrival_time',hue='destination_city',palette='rocket')
# Out:
# <Axes: xlabel='arrival_time', ylabel='count'>

# %%
sns.countplot(data=airline,x='destination_city',hue='class',palette='dark')
# Out:
# <Axes: xlabel='destination_city', ylabel='count'>

# %%
sns.countplot(data=airline,x='source_city',hue='destination_city',palette='colorblind')
# Out:
# <Axes: xlabel='source_city', ylabel='count'>

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.lmplot(data=airline,x='duration',y='price',palette='hls',hue='airline')

# %%
sns.lmplot(data=airline,x='duration',y='price',palette='dark',hue='source_city')

# %%
sns.lmplot(data=airline,x='duration',y='price',palette='mako',hue='departure_time')

# %%
sns.lmplot(data=airline,x='duration',y='price',palette='cividis',hue='stops')

# %%
sns.lmplot(data=airline,x='duration',y='price',palette='colorblind',hue='class')

# %%
sns.lmplot(data=airline,x='duration',y='price',palette='rocket',hue='arrival_time')

# %%
sns.lmplot(data=airline,x='duration',y='price',palette='Dark2',hue='destination_city')

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.jointplot(data=airline,x='duration',y='price',palette='hls',hue='airline')

# %%
sns.jointplot(data=airline,x='duration',y='price',palette='dark',hue='source_city')

# %%
sns.jointplot(data=airline,x='duration',y='price',palette='mako',hue='departure_time')

# %%
sns.jointplot(data=airline,x='duration',y='price',palette='cividis',hue='stops')

# %%
sns.jointplot(data=airline,x='duration',y='price',palette='colorblind',hue='class')

# %%
sns.jointplot(data=airline,x='duration',y='price',palette='rocket',hue='arrival_time')

# %%
sns.jointplot(data=airline,x='duration',y='price',palette='Dark2',hue='destination_city')

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.boxenplot(data=airline,x='airline',y='duration',palette='dark')
# Out:
# <Axes: xlabel='airline', ylabel='duration'>

# %%
sns.boxenplot(data=airline,x='source_city',y='price',palette='muted')
# Out:
# <Axes: xlabel='source_city', ylabel='price'>

# %%
sns.boxenplot(data=airline,x='departure_time',y='duration',palette='hls')
# Out:
# <Axes: xlabel='departure_time', ylabel='duration'>

# %%
sns.boxenplot(data=airline,x='stops',y='price',palette='mako')
# Out:
# <Axes: xlabel='stops', ylabel='price'>

# %%
sns.boxenplot(data=airline,x='arrival_time',y='duration',palette='Set1')
# Out:
# <Axes: xlabel='arrival_time', ylabel='duration'>

# %%
sns.boxenplot(data=airline,x='destination_city',y='price',palette='colorblind')
# Out:
# <Axes: xlabel='destination_city', ylabel='price'>

# %%
sns.boxenplot(data=airline,x='class',y='price',palette='Dark2')
# Out:
# <Axes: xlabel='class', ylabel='price'>

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.stripplot(data=airline,x='airline',y='price',palette='mako')
# Out:
# <Axes: xlabel='airline', ylabel='price'>

# %%
sns.stripplot(data=airline,x='source_city',y='price',palette='cividis')
# Out:
# <Axes: xlabel='source_city', ylabel='price'>

# %%
sns.stripplot(data=airline,x='departure_time',y='price',palette='dark')
# Out:
# <Axes: xlabel='departure_time', ylabel='price'>

# %%
sns.stripplot(data=airline,x='stops',y='price',palette='magma')
# Out:
# <Axes: xlabel='stops', ylabel='price'>

# %%
sns.stripplot(data=airline,x='arrival_time',y='price',palette='rocket')
# Out:
# <Axes: xlabel='arrival_time', ylabel='price'>

# %%
sns.stripplot(data=airline,x='destination_city',y='price',palette='deep')
# Out:
# <Axes: xlabel='destination_city', ylabel='price'>

# %%
sns.stripplot(data=airline,x='class',y='price',palette='colorblind')
# Out:
# <Axes: xlabel='class', ylabel='price'>

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.kdeplot(data=airline,x='price',hue='airline',palette='dark',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=airline,x='price',hue='source_city',palette='hls',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=airline,x='price',hue='arrival_time',palette='tab20',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=airline,x='price',hue='departure_time',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=airline,x='price',hue='stops',palette='deep',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=airline,x='price',hue='destination_city',palette='mako',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=airline,x='price',hue='class',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
airline.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns.pairplot(airline, hue="airline",palette='dark')

# %%
sns.pairplot(airline, hue="source_city",palette='tab20')

# %%
sns.pairplot(airline, hue="departure_time",palette='hls')

# %%
sns.pairplot(airline, hue="stops",palette='cividis')

# %%
sns.pairplot(airline, hue="arrival_time",palette='rocket')

# %%
sns.pairplot(airline, hue="destination_city",palette='Dark2')

# %%
sns.pairplot(airline, hue="class",palette='bright')
