# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
website=pd.read_csv(r'C:\Users\admin\Downloads\archive\final_website_stats.csv')

# %%
website
# Out:
#         id   timestamp   page_views    ad_spend  is_weekend day_of_week  \
# 0        0  01-01-2022  1165.962767  194.901425        True    Saturday
# 1        1  02-01-2022  1191.485835  175.852071        True      Sunday
# 2        2  03-01-2022  1266.928269  269.430656       False      Monday
# 3        3  04-01-2022  1364.193858  295.690896       False     Tuesday
# 4        4  05-01-2022  1013.282520  242.975399       False   Wednesday
# ...    ...         ...          ...         ...         ...         ...
# 1091  1091  27-12-2024  1870.700150  248.883333       False      Friday
# 1092  1092  28-12-2024  1977.793002  201.828886        True    Saturday
# 1093  1093  29-12-2024  2229.203908  181.558377        True      Sunday
# 1094  1094  30-12-2024  2286.211502  271.979202       False      Monday
# 1095  1095  31-12-2024  1992.601776  247.578503       False     Tuesday
#
#       is_holiday
# 0           True
# 1          False
# 2          False
# 3          False
# ...

# %%
website.shape
# Out:
# (1096, 7)

# %%
website.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1096 non-null   int64
#  1   timestamp    1096 non-null   object
#  2   page_views   1096 non-null   float64
#  3   ad_spend     1096 non-null   float64
#  4   is_weekend   1096 non-null   bool
#  5   day_of_week  1096 non-null   object
#  6   is_holiday   1096 non-null   bool
# dtypes: bool(2), float64(2), int64(1), object(2)
# memory usage: 45.1+ KB

# %%
website.isnull().sum()
# Out:
# id             0
# timestamp      0
# page_views     0
# ad_spend       0
# is_weekend     0
# day_of_week    0
# is_holiday     0
# dtype: int64

# %%
website.columns
# Out:
# Index(['id', 'timestamp', 'page_views', 'ad_spend', 'is_weekend',
#        'day_of_week', 'is_holiday'],
#       dtype='object')

# %%
len(website.columns)
# Out:
# 7

# %%
website.dtypes
# Out:
# id               int64
# timestamp       object
# page_views     float64
# ad_spend       float64
# is_weekend        bool
# day_of_week     object
# is_holiday        bool
# dtype: object

# %%
website.describe()
# Out:
#                 id   page_views     ad_spend
# count  1096.000000  1096.000000  1096.000000
# mean    547.500000  1553.196104   249.518466
# std     316.532252   277.144160    73.055129
# min       0.000000   867.718643   113.665941
# 25%     273.750000  1350.935728   206.832469
# 50%     547.500000  1562.069595   240.465752
# 75%     821.250000  1746.785819   269.795000
# max    1095.000000  2286.951163   679.515529

# %%
website.describe().transpose()
# Out:
#              count         mean         std         min          25%  \
# id          1096.0   547.500000  316.532252    0.000000   273.750000
# page_views  1096.0  1553.196104  277.144160  867.718643  1350.935728
# ad_spend    1096.0   249.518466   73.055129  113.665941   206.832469
#
#                     50%          75%          max
# id           547.500000   821.250000  1095.000000
# page_views  1562.069595  1746.785819  2286.951163
# ad_spend     240.465752   269.795000   679.515529

# %%
website.tail()
# Out:
#         id   timestamp   page_views    ad_spend  is_weekend day_of_week  \
# 1091  1091  27-12-2024  1870.700150  248.883333       False      Friday
# 1092  1092  28-12-2024  1977.793002  201.828886        True    Saturday
# 1093  1093  29-12-2024  2229.203908  181.558377        True      Sunday
# 1094  1094  30-12-2024  2286.211502  271.979202       False      Monday
# 1095  1095  31-12-2024  1992.601776  247.578503       False     Tuesday
#
#       is_holiday
# 1091       False
# 1092       False
# 1093       False
# 1094       False
# 1095       False

# %%
website.head()
# Out:
#    id   timestamp   page_views    ad_spend  is_weekend day_of_week  is_holiday
# 0   0  01-01-2022  1165.962767  194.901425        True    Saturday        True
# 1   1  02-01-2022  1191.485835  175.852071        True      Sunday       False
# 2   2  03-01-2022  1266.928269  269.430656       False      Monday       False
# 3   3  04-01-2022  1364.193858  295.690896       False     Tuesday       False
# 4   4  05-01-2022  1013.282520  242.975399       False   Wednesday       False

# %%
sns.distplot(website.page_views,color='c')
# Out:
# <Axes: xlabel='page_views', ylabel='Density'>

# %%
sns.distplot(website.ad_spend,color='k')
# Out:
# <Axes: xlabel='ad_spend', ylabel='Density'>

# %%
website.head()
# Out:
#    id   timestamp   page_views    ad_spend  is_weekend day_of_week  is_holiday
# 0   0  01-01-2022  1165.962767  194.901425        True    Saturday        True
# 1   1  02-01-2022  1191.485835  175.852071        True      Sunday       False
# 2   2  03-01-2022  1266.928269  269.430656       False      Monday       False
# 3   3  04-01-2022  1364.193858  295.690896       False     Tuesday       False
# 4   4  05-01-2022  1013.282520  242.975399       False   Wednesday       False

# %%
sns.countplot(data=website,x='is_weekend',palette='dark')
# Out:
# <Axes: xlabel='is_weekend', ylabel='count'>

# %%
sns.countplot(data=website,x='day_of_week',palette='mako')
# Out:
# <Axes: xlabel='day_of_week', ylabel='count'>

# %%
sns.countplot(data=website,x='is_holiday',palette='magma')
# Out:
# <Axes: xlabel='is_holiday', ylabel='count'>

# %%
sns.countplot(data=website,x='is_weekend',palette='hls',hue='day_of_week')
# Out:
# <Axes: xlabel='is_weekend', ylabel='count'>

# %%
sns.countplot(data=website,x='day_of_week',palette='deep',hue='is_holiday')
# Out:
# <Axes: xlabel='day_of_week', ylabel='count'>

# %%
sns.countplot(data=website,x='is_weekend',palette='bright',hue='is_holiday')
# Out:
# <Axes: xlabel='is_weekend', ylabel='count'>

# %%
website.head()
# Out:
#    id   timestamp   page_views    ad_spend  is_weekend day_of_week  is_holiday
# 0   0  01-01-2022  1165.962767  194.901425        True    Saturday        True
# 1   1  02-01-2022  1191.485835  175.852071        True      Sunday       False
# 2   2  03-01-2022  1266.928269  269.430656       False      Monday       False
# 3   3  04-01-2022  1364.193858  295.690896       False     Tuesday       False
# 4   4  05-01-2022  1013.282520  242.975399       False   Wednesday       False

# %%
sns.lmplot(data=website,x='page_views',y='ad_spend',palette='Dark2',hue='is_weekend')

# %%
sns.lmplot(data=website,x='page_views',y='ad_spend',palette='rocket',hue='day_of_week')

# %%
sns.lmplot(data=website,x='page_views',y='ad_spend',palette='colorblind',hue='is_holiday')

# %%
sns.jointplot(data=website,x='page_views',y='ad_spend',palette='rocket',hue='day_of_week')

# %%
sns.jointplot(data=website,x='page_views',y='ad_spend',palette='colorblind',hue='is_holiday')

# %%
sns.jointplot(data=website,x='page_views',y='ad_spend',palette='rocket',hue='day_of_week')

# %%
sns.jointplot(data=website,x='page_views',y='ad_spend',color='g',kind='hex')

# %%
sns.jointplot(data=website,x='page_views',y='ad_spend',color='Purple')

# %%
sns.jointplot(data=website,x='page_views',y='ad_spend',color='r',kind='reg')

# %%
website.head()
# Out:
#    id   timestamp   page_views    ad_spend  is_weekend day_of_week  is_holiday
# 0   0  01-01-2022  1165.962767  194.901425        True    Saturday        True
# 1   1  02-01-2022  1191.485835  175.852071        True      Sunday       False
# 2   2  03-01-2022  1266.928269  269.430656       False      Monday       False
# 3   3  04-01-2022  1364.193858  295.690896       False     Tuesday       False
# 4   4  05-01-2022  1013.282520  242.975399       False   Wednesday       False

# %%
sns.boxenplot(data=website,x='is_weekend',y='page_views',palette='hls')
# Out:
# <Axes: xlabel='is_weekend', ylabel='page_views'>

# %%
sns.boxenplot(data=website,x='day_of_week',y='ad_spend',palette='rocket')
# Out:
# <Axes: xlabel='day_of_week', ylabel='ad_spend'>

# %%
sns.boxenplot(data=website,x='is_holiday',y='page_views',palette='deep')
# Out:
# <Axes: xlabel='is_holiday', ylabel='page_views'>

# %%
sns.boxenplot(data=website,x='is_weekend',y='ad_spend',palette='magma')
# Out:
# <Axes: xlabel='is_weekend', ylabel='ad_spend'>

# %%
sns.boxenplot(data=website,x='day_of_week',y='page_views',palette='mako')
# Out:
# <Axes: xlabel='day_of_week', ylabel='page_views'>

# %%
sns.stripplot(data=website,x='is_weekend',y='page_views',palette='Dark2')
# Out:
# <Axes: xlabel='is_weekend', ylabel='page_views'>

# %%
sns.stripplot(data=website,x='day_of_week',y='ad_spend',palette='rocket')
# Out:
# <Axes: xlabel='day_of_week', ylabel='ad_spend'>

# %%
sns.stripplot(data=website,x='is_holiday',y='page_views',palette='bright')
# Out:
# <Axes: xlabel='is_holiday', ylabel='page_views'>

# %%
sns.stripplot(data=website,x='is_weekend',y='ad_spend',palette='magma')
# Out:
# <Axes: xlabel='is_weekend', ylabel='ad_spend'>

# %%
sns.stripplot(data=website,x='day_of_week',y='page_views',palette='mako')
# Out:
# <Axes: xlabel='day_of_week', ylabel='page_views'>

# %%
sns.swarmplot(data=website,x='is_weekend',y='page_views',palette='Dark2')
# Out:
# <Axes: xlabel='is_weekend', ylabel='page_views'>

# %%
website.head()
# Out:
#    id   timestamp   page_views    ad_spend  is_weekend day_of_week  is_holiday
# 0   0  01-01-2022  1165.962767  194.901425        True    Saturday        True
# 1   1  02-01-2022  1191.485835  175.852071        True      Sunday       False
# 2   2  03-01-2022  1266.928269  269.430656       False      Monday       False
# 3   3  04-01-2022  1364.193858  295.690896       False     Tuesday       False
# 4   4  05-01-2022  1013.282520  242.975399       False   Wednesday       False

# %%
sns.pairplot(website, hue="is_weekend",palette='colorblind')

# %%
sns.pairplot(website, hue="day_of_week",palette='tab20')

# %%
sns.pairplot(website, hue="is_holiday",palette='YlOrRd')

# %%
website.head()
# Out:
#    id   timestamp   page_views    ad_spend  is_weekend day_of_week  is_holiday
# 0   0  01-01-2022  1165.962767  194.901425        True    Saturday        True
# 1   1  02-01-2022  1191.485835  175.852071        True      Sunday       False
# 2   2  03-01-2022  1266.928269  269.430656       False      Monday       False
# 3   3  04-01-2022  1364.193858  295.690896       False     Tuesday       False
# 4   4  05-01-2022  1013.282520  242.975399       False   Wednesday       False

# %%
sns.boxplot(data=website,x='is_weekend',y='page_views',palette='hls')
# Out:
# <Axes: xlabel='is_weekend', ylabel='page_views'>

# %%
sns.boxplot(data=website,x='day_of_week',y='ad_spend',palette='rocket')
# Out:
# <Axes: xlabel='day_of_week', ylabel='ad_spend'>

# %%
sns.boxplot(data=website,x='is_holiday',y='page_views',palette='deep')
# Out:
# <Axes: xlabel='is_holiday', ylabel='page_views'>

# %%
sns.boxplot(data=website,x='is_weekend',y='ad_spend',palette='magma')
# Out:
# <Axes: xlabel='is_weekend', ylabel='ad_spend'>

# %%
sns.boxplot(data=website,x='day_of_week',y='page_views',palette='mako')
# Out:
# <Axes: xlabel='day_of_week', ylabel='page_views'>
