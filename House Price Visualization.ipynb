# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set_style('darkgrid')
plt.rcParams['figure.figsize']=10,5

# %%
house=pd.read_csv(r'C:\Users\admin\Downloads\archive (1)\Housing.csv')

# %%
house
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
house.shape
# Out:
# (545, 13)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
house.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
house.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
len(house.columns)
# Out:
# 13

# %%
house.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
house.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
house.describe().transpose()
# Out:
#            count          mean           std        min        25%        50%  \
# price      545.0  4.766729e+06  1.870440e+06  1750000.0  3430000.0  4340000.0
# area       545.0  5.150541e+03  2.170141e+03     1650.0     3600.0     4600.0
# bedrooms   545.0  2.965138e+00  7.380639e-01        1.0        2.0        3.0
# bathrooms  545.0  1.286239e+00  5.024696e-01        1.0        1.0        1.0
# stories    545.0  1.805505e+00  8.674925e-01        1.0        1.0        2.0
# parking    545.0  6.935780e-01  8.615858e-01        0.0        0.0        0.0
#
#                  75%         max
# price      5740000.0  13300000.0
# area          6360.0     16200.0
# bedrooms         3.0         6.0
# bathrooms        2.0         4.0
# stories          2.0         4.0
# parking          1.0         3.0

# %%
house.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
house.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.distplot(house.price,color='b')
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(house.area,color='k')
# Out:
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.distplot(house.bedrooms,color='c')
# Out:
# <Axes: xlabel='bedrooms', ylabel='Density'>

# %%
sns.distplot(house.bathrooms,color='r')
# Out:
# <Axes: xlabel='bathrooms', ylabel='Density'>

# %%
sns.distplot(house.stories,color='orange')
# Out:
# <Axes: xlabel='stories', ylabel='Density'>

# %%
sns.distplot(house.parking,color='g')
# Out:
# <Axes: xlabel='parking', ylabel='Density'>

# %%
house.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.countplot(data=house,x='mainroad',palette='Set1',fill=False)
# Out:
# <Axes: xlabel='mainroad', ylabel='count'>

# %%
sns.countplot(data=house,x='guestroom',palette='Set2')
# Out:
# <Axes: xlabel='guestroom', ylabel='count'>

# %%
sns.countplot(data=house,x='basement',palette='ch:45')
# Out:
# <Axes: xlabel='basement', ylabel='count'>

# %%
sns.countplot(data=house,x='hotwaterheating',palette='ch:67',fill=False)
# Out:
# <Axes: xlabel='hotwaterheating', ylabel='count'>

# %%
sns.countplot(data=house,x='airconditioning',palette='ch:89',fill=True)
# Out:
# <Axes: xlabel='airconditioning', ylabel='count'>

# %%
sns.countplot(data=house,x='prefarea',palette='ch:4',fill=True)
# Out:
# <Axes: xlabel='prefarea', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='ch:54',fill=True)
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
house.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.countplot(data=house,x='furnishingstatus',palette='dark',fill=True,hue='bedrooms')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='bedrooms',palette='rocket',fill=True,hue='bathrooms')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
sns.countplot(data=house,x='bedrooms',palette='BuGn',fill=True,hue='mainroad')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
sns.countplot(data=house,x='basement',palette='tab10',fill=True,hue='mainroad')
# Out:
# <Axes: xlabel='basement', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='cividis',fill=True,hue='mainroad')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='mako',fill=True,hue='bedrooms')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='coolwarm',fill=True,hue='bathrooms')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='YlGnBu',fill=True,hue='mainroad')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='dark',fill=True,hue='guestroom')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='husl',fill=True,hue='hotwaterheating')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='Dark2',fill=True,hue='airconditioning')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='crest',fill=True,hue='parking')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.countplot(data=house,x='furnishingstatus',palette='magma',fill=True,hue='prefarea')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
house.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.jointplot(data=house,x='area',y='price',kind='hex',color='b')

# %%
sns.jointplot(data=house,x='bedrooms',y='price',kind='scatter',color='y')

# %%
sns.jointplot(data=house,x='bathrooms',y='price',kind='hex',color='Purple')

# %%
sns.jointplot(data=house,x='parking',y='price',kind='hex',color='c')

# %%
sns.jointplot(data=house,x='parking',y='area',kind='hex',color='g')

# %%
house.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.lmplot(data=house,x='area',y='price',palette='Set1',hue='bedrooms')

# %%
sns.lmplot(data=house,x='area',y='price',palette='Set1',hue='bathrooms')

# %%
sns.lmplot(data=house,x='area',y='price',palette='Set2',hue='mainroad')

# %%
sns.lmplot(data=house,x='area',y='price',palette='dark',hue='guestroom')

# %%
sns.lmplot(data=house,x='area',y='price',palette='BuPu',hue='basement')

# %%
sns.lmplot(data=house,x='area',y='price',palette='magma',hue='parking')

# %%
sns.lmplot(data=house,x='area',y='price',palette='cubehelix',hue='furnishingstatus')

# %%
house.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.boxplot(data=house,x='mainroad',y='price',palette='cubehelix')
# Out:
# <Axes: xlabel='mainroad', ylabel='price'>

# %%
sns.boxplot(data=house,x='guestroom',y='price',palette='plasma')
# Out:
# <Axes: xlabel='guestroom', ylabel='price'>

# %%
sns.boxplot(data=house,x='basement',y='price',palette='rocket',fill=False)
# Out:
# <Axes: xlabel='basement', ylabel='price'>

# %%
sns.boxplot(data=house,x='airconditioning',y='price',palette='viridis')
# Out:
# <Axes: xlabel='airconditioning', ylabel='price'>

# %%
sns.boxplot(data=house,x='furnishingstatus',y='price',palette='YlOrRd')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='price'>

# %%
sns.violinplot(data=house,x='mainroad',y='price',palette='ch:34')
# Out:
# <Axes: xlabel='mainroad', ylabel='price'>

# %%
sns.violinplot(data=house,x='furnishingstatus',y='area',palette='YlOrRd')
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='area'>

# %%
sns.violinplot(data=house,x='basement',y='price',palette='Set2',)
# Out:
# <Axes: xlabel='basement', ylabel='price'>

# %%
sns.violinplot(data=house,x='guestroom',y='area',palette='plasma')
# Out:
# <Axes: xlabel='guestroom', ylabel='area'>

# %%
house.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.kdeplot(data=house,x='price',color='g',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=house,x='area',color='r',fill=True)
# Out:
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.kdeplot(data=house,x='bedrooms',color='b',fill=True)
# Out:
# <Axes: xlabel='bedrooms', ylabel='Density'>

# %%
sns.kdeplot(data=house,x='stories',color='k',fill=True)
# Out:
# <Axes: xlabel='stories', ylabel='Density'>

# %%
sns.kdeplot(data=house,x='parking',color='c',fill=True)
# Out:
# <Axes: xlabel='parking', ylabel='Density'>
