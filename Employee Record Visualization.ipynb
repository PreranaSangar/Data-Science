# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=10,5
sns.set_style('darkgrid')

# %%
emp=pd.read_csv(r'C:\Users\admin\Downloads\archive\employee_records.csv')

# %%
emp
# Out:
#        Employee_ID    Employee_Name  Age    Country   Department    Position  \
# 0                1    Daniel Taylor   25         UK           HR     Analyst
# 1                2      Ethan Brown   44      India    Marketing   Executive
# 2                3  Sophia Martinez   51      Japan      Finance   Developer
# 3                4   Ethan Martinez   47    Germany      Support     Analyst
# 4                5        Mia Brown   32  Australia      Support  Consultant
# ...            ...              ...  ...        ...          ...         ...
# 29995        29996        Mia Brown   42  Australia      Support     Manager
# 29996        29997     Mason Thomas   41     Mexico  Engineering   Assistant
# 29997        29998    Lily Anderson   44      India    Marketing   Developer
# 29998        29999     Mason Taylor   46     Brazil      Finance   Assistant
# 29999        30000    Lucas Jackson   30     Mexico      Finance   Developer
#
#           Salary Joining_Date
# ...

# %%
emp.shape
# Out:
# (30000, 8)

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee_ID    30000 non-null  int64
#  1   Employee_Name  30000 non-null  object
#  2   Age            30000 non-null  int64
#  3   Country        30000 non-null  object
#  4   Department     30000 non-null  object
#  5   Position       30000 non-null  object
#  6   Salary         30000 non-null  float64
#  7   Joining_Date   30000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.8+ MB

# %%
emp.isnull().sum()
# Out:
# Employee_ID      0
# Employee_Name    0
# Age              0
# Country          0
# Department       0
# Position         0
# Salary           0
# Joining_Date     0
# dtype: int64

# %%
emp.dtypes
# Out:
# Employee_ID        int64
# Employee_Name     object
# Age                int64
# Country           object
# Department        object
# Position          object
# Salary           float64
# Joining_Date      object
# dtype: object

# %%
emp.columns
# Out:
# Index(['Employee_ID', 'Employee_Name', 'Age', 'Country', 'Department',
#        'Position', 'Salary', 'Joining_Date'],
#       dtype='object')

# %%
len(emp.columns)
# Out:
# 8

# %%
emp.describe()
# Out:
#         Employee_ID           Age         Salary
# count  30000.000000  30000.000000   30000.000000
# mean   15000.500000     40.978067   89826.142610
# std     8660.398374     11.234432   34625.270533
# min        1.000000     22.000000   30004.780000
# 25%     7500.750000     31.000000   59546.715000
# 50%    15000.500000     41.000000   89544.810000
# 75%    22500.250000     51.000000  119836.545000
# max    30000.000000     60.000000  149996.390000

# %%
emp.describe().transpose()
# Out:
#                count          mean           std       min        25%  \
# Employee_ID  30000.0  15000.500000   8660.398374      1.00   7500.750
# Age          30000.0     40.978067     11.234432     22.00     31.000
# Salary       30000.0  89826.142610  34625.270533  30004.78  59546.715
#
#                   50%         75%        max
# Employee_ID  15000.50   22500.250   30000.00
# Age             41.00      51.000      60.00
# Salary       89544.81  119836.545  149996.39

# %%
emp.tail()
# Out:
#        Employee_ID  Employee_Name  Age    Country   Department   Position  \
# 29995        29996      Mia Brown   42  Australia      Support    Manager
# 29996        29997   Mason Thomas   41     Mexico  Engineering  Assistant
# 29997        29998  Lily Anderson   44      India    Marketing  Developer
# 29998        29999   Mason Taylor   46     Brazil      Finance  Assistant
# 29999        30000  Lucas Jackson   30     Mexico      Finance  Developer
#
#           Salary Joining_Date
# 29995  133474.82   2015-07-03
# 29996  140793.59   2023-10-12
# 29997   68464.72   2021-06-28
# 29998  148323.28   2017-11-11
# 29999   93451.72   2017-03-17

# %%
emp.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#       Salary Joining_Date
# 0  142278.32   2023-06-04
# 1   98549.20   2018-01-13
# 2   85565.84   2015-04-30
# 3   34513.67   2015-06-17
# 4   45339.72   2019-02-22

# %%
sns.distplot(emp.Age,color='k')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(emp.Salary,color='b')
# Out:
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
sns.displot(emp.Age)

# %%
sns.displot(emp.Salary,color='y')

# %%
emp.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#       Salary Joining_Date
# 0  142278.32   2023-06-04
# 1   98549.20   2018-01-13
# 2   85565.84   2015-04-30
# 3   34513.67   2015-06-17
# 4   45339.72   2019-02-22

# %%
sns.countplot(data=emp,x='Department',palette='Set1')
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
sns.countplot(data=emp,x='Position',palette='Set3')
# Out:
# <Axes: xlabel='Position', ylabel='count'>

# %%
sns.countplot(data=emp,x='Country',palette='ch:56')
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data=emp,x='Country',palette='Set1',hue='Department')
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data=emp,x='Department',palette='ch:34',hue='Position')
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
emp.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#       Salary Joining_Date
# 0  142278.32   2023-06-04
# 1   98549.20   2018-01-13
# 2   85565.84   2015-04-30
# 3   34513.67   2015-06-17
# 4   45339.72   2019-02-22

# %%
sns.boxplot(data=emp,x='Country',y='Age',palette='ch:56',)
# Out:
# <Axes: xlabel='Country', ylabel='Age'>

# %%
sns.boxplot(data=emp,x='Department',y='Age',palette='Set2',)
# Out:
# <Axes: xlabel='Department', ylabel='Age'>

# %%
sns.boxplot(data=emp,x='Position',y='Age',palette='Set3',)
# Out:
# <Axes: xlabel='Position', ylabel='Age'>

# %%
sns.boxplot(data=emp,x='Country',y='Salary',palette='ch:45')
# Out:
# <Axes: xlabel='Country', ylabel='Salary'>

# %%
sns.boxplot(data=emp,x='Department',y='Salary',palette='Set1')
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.boxplot(data=emp,x='Position',y='Salary',color='c')
# Out:
# <Axes: xlabel='Position', ylabel='Salary'>

# %%
emp.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#       Salary Joining_Date
# 0  142278.32   2023-06-04
# 1   98549.20   2018-01-13
# 2   85565.84   2015-04-30
# 3   34513.67   2015-06-17
# 4   45339.72   2019-02-22

# %%
sns.violinplot(data=emp,x='Country',y='Age',palette='ch:44',fill=False)
# Out:
# <Axes: xlabel='Country', ylabel='Age'>

# %%
sns.violinplot(data=emp,x='Position',y='Age',palette='Set3',)
# Out:
# <Axes: xlabel='Position', ylabel='Age'>

# %%
sns.violinplot(data=emp,x='Department',y='Age',palette='Set2',fill=False)
# Out:
# <Axes: xlabel='Department', ylabel='Age'>

# %%
sns.violinplot(data=emp,x='Country',y='Salary',palette='ch:45')
# Out:
# <Axes: xlabel='Country', ylabel='Salary'>

# %%
sns.violinplot(data=emp,x='Department',y='Salary',palette='Set1')
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
sns.violinplot(data=emp,x='Position',y='Salary',color='b',fill=False)
# Out:
# <Axes: xlabel='Position', ylabel='Salary'>

# %%
emp.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#       Salary Joining_Date
# 0  142278.32   2023-06-04
# 1   98549.20   2018-01-13
# 2   85565.84   2015-04-30
# 3   34513.67   2015-06-17
# 4   45339.72   2019-02-22

# %%
sns.lmplot(data=emp,x='Age',y='Salary',hue='Country')

# %%
sns.lmplot(data=emp,x='Age',y='Salary',hue='Department')

# %%
sns.lmplot(data=emp,x='Age',y='Salary',hue='Position')

# %%
emp.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#       Salary Joining_Date
# 0  142278.32   2023-06-04
# 1   98549.20   2018-01-13
# 2   85565.84   2015-04-30
# 3   34513.67   2015-06-17
# 4   45339.72   2019-02-22

# %%
sns.jointplot(data=emp,x='Age',y='Salary',kind='hex',color='r')

# %%
sns.jointplot(data=emp,x='Age',y='Salary',hue='Country')

# %%
sns.jointplot(data=emp,x='Age',y='Salary',hue='Department')

# %%
sns.jointplot(data=emp,x='Age',y='Salary',hue='Position')

# %%
emp.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#       Salary Joining_Date
# 0  142278.32   2023-06-04
# 1   98549.20   2018-01-13
# 2   85565.84   2015-04-30
# 3   34513.67   2015-06-17
# 4   45339.72   2019-02-22

# %%
sns.histplot(emp.Age,color='m')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(emp.Salary,color='y')
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.kdeplot(emp.Salary,color='k',fill=True)
# Out:
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
sns.kdeplot(emp.Age,color='g',fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>
