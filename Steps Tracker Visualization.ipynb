# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=10,5
sns.set_style('darkgrid')

# %%
steps=pd.read_csv(r'C:\Users\admin\Downloads\archive\steps_tracker_dataset.csv')

# %%
steps
# Out:
#            date  steps  distance_km  calories_burned  active_minutes  \
# 0    08/10/2022   4147         3.11           124.41              41
# 1    11/06/2022    323         0.24             9.69               3
# 2    28/01/2022   6622         4.97           198.66              66
# 3    23/03/2022  11136         8.35           334.08             111
# 4    20/05/2022   2718         2.04            81.54              27
# ..          ...    ...          ...              ...             ...
# 495  04/05/2022  17376        13.03           521.28             174
# 496  16/04/2022   6917         5.19           207.51              69
# 497  08/01/2022  12247         9.19           367.41             122
# 498  01/03/2022   8295         6.22           248.85              83
# 499  18/08/2022   5254         3.94           157.62              53
#
#      sleep_hours  water_intake_liters       mood
# 0           10.5                 3.77   stressed
# ...

# %%
steps.shape
# Out:
# (500, 8)

# %%
steps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 500 non-null    object
#  1   steps                500 non-null    int64
#  2   distance_km          500 non-null    float64
#  3   calories_burned      500 non-null    float64
#  4   active_minutes       500 non-null    int64
#  5   sleep_hours          500 non-null    float64
#  6   water_intake_liters  500 non-null    float64
#  7   mood                 500 non-null    object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 31.4+ KB

# %%
steps.tail()
# Out:
#            date  steps  distance_km  calories_burned  active_minutes  \
# 495  04/05/2022  17376        13.03           521.28             174
# 496  16/04/2022   6917         5.19           207.51              69
# 497  08/01/2022  12247         9.19           367.41             122
# 498  01/03/2022   8295         6.22           248.85              83
# 499  18/08/2022   5254         3.94           157.62              53
#
#      sleep_hours  water_intake_liters       mood
# 495          8.0                 2.86  energetic
# 496          4.7                 0.49        sad
# 497          9.0                 0.15      happy
# 498          4.8                 2.39   stressed
# 499          3.3                 2.15        sad

# %%
steps.columns
# Out:
# Index(['date', 'steps', 'distance_km', 'calories_burned', 'active_minutes',
#        'sleep_hours', 'water_intake_liters', 'mood'],
#       dtype='object')

# %%
len(steps.columns)
# Out:
# 8

# %%
steps.dtypes
# Out:
# date                    object
# steps                    int64
# distance_km            float64
# calories_burned        float64
# active_minutes           int64
# sleep_hours            float64
# water_intake_liters    float64
# mood                    object
# dtype: object

# %%
steps.describe()
# Out:
#               steps  distance_km  calories_burned  active_minutes  \
# count    500.000000   500.000000       500.000000       500.00000
# mean   10238.572000     7.678800       307.157160       102.40800
# std     5829.268207     4.371964       174.878046        58.29293
# min       26.000000     0.020000         0.780000         0.00000
# 25%     5313.250000     3.985000       159.397500        53.00000
# 50%    10699.000000     8.025000       320.970000       107.00000
# 75%    15317.500000    11.490000       459.525000       153.00000
# max    19979.000000    14.980000       599.370000       200.00000
#
#        sleep_hours  water_intake_liters
# count   500.000000           500.000000
# mean      7.292400             2.506580
# std       1.814046             1.426296
# min       3.100000             0.040000
# 25%       6.000000             1.300000
# 50%       7.000000             2.495000
# 75%       8.225000             3.785000
# max      12.000000             5.000000

# %%
steps.describe().transpose()
# Out:
#                      count         mean          std    min        25%  \
# steps                500.0  10238.57200  5829.268207  26.00  5313.2500
# distance_km          500.0      7.67880     4.371964   0.02     3.9850
# calories_burned      500.0    307.15716   174.878046   0.78   159.3975
# active_minutes       500.0    102.40800    58.292930   0.00    53.0000
# sleep_hours          500.0      7.29240     1.814046   3.10     6.0000
# water_intake_liters  500.0      2.50658     1.426296   0.04     1.3000
#
#                            50%        75%       max
# steps                10699.000  15317.500  19979.00
# distance_km              8.025     11.490     14.98
# calories_burned        320.970    459.525    599.37
# active_minutes         107.000    153.000    200.00
# sleep_hours              7.000      8.225     12.00
# water_intake_liters      2.495      3.785      5.00

# %%
steps.head()
# Out:
#          date  steps  distance_km  calories_burned  active_minutes  \
# 0  08/10/2022   4147         3.11           124.41              41
# 1  11/06/2022    323         0.24             9.69               3
# 2  28/01/2022   6622         4.97           198.66              66
# 3  23/03/2022  11136         8.35           334.08             111
# 4  20/05/2022   2718         2.04            81.54              27
#
#    sleep_hours  water_intake_liters      mood
# 0         10.5                 3.77  stressed
# 1          6.0                 1.90       sad
# 2          6.0                 4.48       sad
# 3          8.0                 1.08     tired
# 4          4.9                 1.00     tired

# %%
sns.distplot(steps.steps,color='b',bins=25)
# Out:
# <Axes: xlabel='steps', ylabel='Density'>

# %%
sns.distplot(steps.distance_km,color='m',bins=10)
# Out:
# <Axes: xlabel='distance_km', ylabel='Density'>

# %%
sns.displot(steps.calories_burned,color='k')

# %%
sns.distplot(steps.active_minutes,color='y',bins=15)
# Out:
# <Axes: xlabel='active_minutes', ylabel='Density'>

# %%
sns.distplot(steps.sleep_hours,color='c')
# Out:
# <Axes: xlabel='sleep_hours', ylabel='Density'>

# %%
sns.distplot(steps.water_intake_liters,color='g',bins=20)
# Out:
# <Axes: xlabel='water_intake_liters', ylabel='Density'>

# %%
steps.head()
# Out:
#          date  steps  distance_km  calories_burned  active_minutes  \
# 0  08/10/2022   4147         3.11           124.41              41
# 1  11/06/2022    323         0.24             9.69               3
# 2  28/01/2022   6622         4.97           198.66              66
# 3  23/03/2022  11136         8.35           334.08             111
# 4  20/05/2022   2718         2.04            81.54              27
#
#    sleep_hours  water_intake_liters      mood
# 0         10.5                 3.77  stressed
# 1          6.0                 1.90       sad
# 2          6.0                 4.48       sad
# 3          8.0                 1.08     tired
# 4          4.9                 1.00     tired

# %%
sns.lmplot(data=steps,x='active_minutes',y='sleep_hours',hue='mood')

# %%
sns.lmplot(data=steps,x='steps',y='water_intake_liters',hue='mood')

# %%
sns.lmplot(data=steps,x='calories_burned',y='distance_km',hue='mood')

# %%
sns.lmplot(data=steps,x='water_intake_liters',y='sleep_hours',hue='mood',fit_reg=False)

# %%
steps.head()
# Out:
#          date  steps  distance_km  calories_burned  active_minutes  \
# 0  08/10/2022   4147         3.11           124.41              41
# 1  11/06/2022    323         0.24             9.69               3
# 2  28/01/2022   6622         4.97           198.66              66
# 3  23/03/2022  11136         8.35           334.08             111
# 4  20/05/2022   2718         2.04            81.54              27
#
#    sleep_hours  water_intake_liters      mood
# 0         10.5                 3.77  stressed
# 1          6.0                 1.90       sad
# 2          6.0                 4.48       sad
# 3          8.0                 1.08     tired
# 4          4.9                 1.00     tired

# %%
sns.countplot(data=steps,x='mood',palette='ch:24')
# Out:
# <Axes: xlabel='mood', ylabel='count'>

# %%
sns.histplot(data=steps,x='mood',color='m')
# Out:
# <Axes: xlabel='mood', ylabel='Count'>

# %%
sns.boxplot(data=steps,x='mood',y='steps',color='y',fill=False)
# Out:
# <Axes: xlabel='mood', ylabel='steps'>

# %%
sns.boxplot(data=steps,x='mood',y='sleep_hours',color='k',fill=False)
# Out:
# <Axes: xlabel='mood', ylabel='sleep_hours'>

# %%
sns.boxplot(data=steps,x='mood',y='steps',color='b',fill=False)
# Out:
# <Axes: xlabel='mood', ylabel='steps'>

# %%
sns.boxplot(data=steps,x='mood',y='calories_burned',color='g',fill=True)
# Out:
# <Axes: xlabel='mood', ylabel='calories_burned'>

# %%
sns.boxplot(data=steps,x='mood',y='water_intake_liters',color='r',fill=False)
# Out:
# <Axes: xlabel='mood', ylabel='water_intake_liters'>

# %%
steps.head()
# Out:
#          date  steps  distance_km  calories_burned  active_minutes  \
# 0  08/10/2022   4147         3.11           124.41              41
# 1  11/06/2022    323         0.24             9.69               3
# 2  28/01/2022   6622         4.97           198.66              66
# 3  23/03/2022  11136         8.35           334.08             111
# 4  20/05/2022   2718         2.04            81.54              27
#
#    sleep_hours  water_intake_liters      mood
# 0         10.5                 3.77  stressed
# 1          6.0                 1.90       sad
# 2          6.0                 4.48       sad
# 3          8.0                 1.08     tired
# 4          4.9                 1.00     tired

# %%
sns.violinplot(data=steps,x='mood',y='steps',color='k',fill=False)
# Out:
# <Axes: xlabel='mood', ylabel='steps'>

# %%
sns.violinplot(data=steps,x='mood',y='water_intake_liters',color='c',fill=False)
# Out:
# <Axes: xlabel='mood', ylabel='water_intake_liters'>

# %%
sns.violinplot(data=steps,x='mood',y='sleep_hours',color='y',fill=True)
# Out:
# <Axes: xlabel='mood', ylabel='sleep_hours'>

# %%
steps.head()
# Out:
#          date  steps  distance_km  calories_burned  active_minutes  \
# 0  08/10/2022   4147         3.11           124.41              41
# 1  11/06/2022    323         0.24             9.69               3
# 2  28/01/2022   6622         4.97           198.66              66
# 3  23/03/2022  11136         8.35           334.08             111
# 4  20/05/2022   2718         2.04            81.54              27
#
#    sleep_hours  water_intake_liters      mood
# 0         10.5                 3.77  stressed
# 1          6.0                 1.90       sad
# 2          6.0                 4.48       sad
# 3          8.0                 1.08     tired
# 4          4.9                 1.00     tired

# %%
sns.jointplot(data=steps,x='steps',y='water_intake_liters',color='k',kind='hex')

# %%
sns.jointplot(data=steps,x='distance_km',y='steps',color='m',kind='hist')

# %%
sns.jointplot(data=steps,x='calories_burned',y='steps',color='b',kind='scatter')

# %%
sns.jointplot(data=steps,x='water_intake_liters',y='steps',color='c',kind='resid')

# %%
sns.jointplot(data=steps,x='sleep_hours',y='steps',color='r',kind='reg')

# %%
steps.head()
# Out:
#          date  steps  distance_km  calories_burned  active_minutes  \
# 0  08/10/2022   4147         3.11           124.41              41
# 1  11/06/2022    323         0.24             9.69               3
# 2  28/01/2022   6622         4.97           198.66              66
# 3  23/03/2022  11136         8.35           334.08             111
# 4  20/05/2022   2718         2.04            81.54              27
#
#    sleep_hours  water_intake_liters      mood
# 0         10.5                 3.77  stressed
# 1          6.0                 1.90       sad
# 2          6.0                 4.48       sad
# 3          8.0                 1.08     tired
# 4          4.9                 1.00     tired

# %%
sns.kdeplot(data=steps, x='water_intake_liters',y='steps',shade = True,color='r')
# Out:
# <Axes: xlabel='water_intake_liters', ylabel='steps'>

# %%
sns.kdeplot(data=steps, x='water_intake_liters',y='sleep_hours',shade = True,color='y')
# Out:
# <Axes: xlabel='water_intake_liters', ylabel='sleep_hours'>

# %%
sns.catplot(data=steps,x='mood',y='water_intake_liters',color='c')

# %%
sns.catplot(data=steps,x='mood',y='steps',color='k')

# %%
sns.catplot(data=steps,x='mood',y='active_minutes',color='y')

# %%
sns.catplot(data=steps,x='mood',y='sleep_hours',color='r')
