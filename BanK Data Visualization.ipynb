# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=9,5
sns.set_style('darkgrid')

# %%
bank=pd.read_csv(r'C:\Users\admin\Downloads\archive\bank.csv')

# %%
bank
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
bank.shape
# Out:
# (11162, 17)

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
bank.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
len(bank.columns)
# Out:
# 17

# %%
bank.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
bank.describe().transpose()
# Out:
#             count         mean          std     min    25%    50%      75%  \
# age       11162.0    41.231948    11.913369    18.0   32.0   39.0    49.00
# balance   11162.0  1528.538524  3225.413326 -6847.0  122.0  550.0  1708.00
# day       11162.0    15.658036     8.420740     1.0    8.0   15.0    22.00
# duration  11162.0   371.993818   347.128386     2.0  138.0  255.0   496.00
# campaign  11162.0     2.508421     2.722077     1.0    1.0    2.0     3.00
# pdays     11162.0    51.330407   108.758282    -1.0   -1.0   -1.0    20.75
# previous  11162.0     0.832557     2.292007     0.0    0.0    0.0     1.00
#
#               max
# age          95.0
# balance   81204.0
# day          31.0
# duration   3881.0
# campaign     63.0
# pdays       854.0
# previous     58.0

# %%
bank.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
sns.distplot(bank.age,color='b')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(bank.balance,color='g')
# Out:
# <Axes: xlabel='balance', ylabel='Density'>

# %%
sns.distplot(bank.day,color='r')
# Out:
# <Axes: xlabel='day', ylabel='Density'>

# %%
sns.distplot(bank.duration,color='k')
# Out:
# <Axes: xlabel='duration', ylabel='Density'>

# %%
sns.distplot(bank.campaign,color='y')
# Out:
# <Axes: xlabel='campaign', ylabel='Density'>

# %%
sns.distplot(bank.pdays,color='Purple')
# Out:
# <Axes: xlabel='pdays', ylabel='Density'>

# %%
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
sns.countplot(data=bank,x='job',palette='Dark2')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
sns.countplot(data=bank,x='marital',palette='dark')
# Out:
# <Axes: xlabel='marital', ylabel='count'>

# %%
sns.countplot(data=bank,x='education',palette='Set2')
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
sns.countplot(data=bank,x='default',palette='hls')
# Out:
# <Axes: xlabel='default', ylabel='count'>

# %%
sns.countplot(data=bank,x='loan',palette='magma')
# Out:
# <Axes: xlabel='loan', ylabel='count'>

# %%
sns.countplot(data=bank,x='contact',palette='magma')
# Out:
# <Axes: xlabel='contact', ylabel='count'>

# %%
sns.countplot(data=bank,x='month',palette='plasma')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
sns.countplot(data=bank,x='poutcome',palette='deep')
# Out:
# <Axes: xlabel='poutcome', ylabel='count'>

# %%
sns.countplot(data=bank,x='deposit',palette='bright')
# Out:
# <Axes: xlabel='deposit', ylabel='count'>

# %%
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
sns.countplot(data=bank,x='job',palette='Dark2',hue='marital')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
sns.countplot(data=bank,x='job',palette='deep',hue='education')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
sns.countplot(data=bank,x='marital',palette='bright',hue='education')
# Out:
# <Axes: xlabel='marital', ylabel='count'>

# %%
sns.countplot(data=bank,x='housing',palette='hls',hue='default')
# Out:
# <Axes: xlabel='housing', ylabel='count'>

# %%
sns.countplot(data=bank,x='job',palette='Set1',hue='loan')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
sns.countplot(data=bank,x='contact',palette='tab10',hue='loan')
# Out:
# <Axes: xlabel='contact', ylabel='count'>

# %%
sns.countplot(data=bank,x='month',palette='magma',hue='loan')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
sns.countplot(data=bank,x='month',palette='plasma',hue='poutcome')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
sns.countplot(data=bank,x='month',palette='mako',hue='deposit')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
sns.countplot(data=bank,x='job',palette='cividis',hue='deposit')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
sns.lmplot(data=bank,x='age',y='balance',palette='dark',hue='deposit')

# %%
sns.lmplot(data=bank,x='age',y='day',palette='Dark2',hue='education')

# %%
sns.lmplot(data=bank,x='age',y='duration',palette='ch:78',hue='marital')

# %%
sns.lmplot(data=bank,x='age',y='campaign',palette='hls',hue='month')

# %%
sns.lmplot(data=bank,x='age',y='pdays',palette='magma',hue='housing')

# %%
sns.lmplot(data=bank,x='age',y='balance',palette='bright',hue='marital')

# %%
sns.lmplot(data=bank,x='age',y='balance',palette='Set2',hue='loan')

# %%
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
sns.boxplot(data=bank,x='job',y='balance',palette='magma')
# Out:
# <Axes: xlabel='job', ylabel='balance'>

# %%
sns.boxplot(data=bank,x='marital',y='age',palette='Set2')
# Out:
# <Axes: xlabel='marital', ylabel='age'>

# %%
sns.boxplot(data=bank,x='education',y='duration',palette='ch:87')
# Out:
# <Axes: xlabel='education', ylabel='duration'>

# %%
sns.boxplot(data=bank,x='housing',y='balance',palette='Dark2')
# Out:
# <Axes: xlabel='housing', ylabel='balance'>

# %%
sns.boxplot(data=bank,x='deposit',y='age',palette='hls')
# Out:
# <Axes: xlabel='deposit', ylabel='age'>

# %%
sns.boxplot(data=bank,x='job',y='age',palette='Set2')
# Out:
# <Axes: xlabel='job', ylabel='age'>

# %%
sns.boxplot(data=bank,x='loan',y='duration',palette='dark')
# Out:
# <Axes: xlabel='loan', ylabel='duration'>

# %%
sns.boxplot(data=bank,x='month',y='duration',palette='bright')
# Out:
# <Axes: xlabel='month', ylabel='duration'>

# %%
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
sns.jointplot(data=bank,x='age',y='balance',palette='dark',hue='deposit')

# %%
sns.jointplot(data=bank,x='age',y='day',palette='Dark2',hue='education')

# %%
sns.jointplot(data=bank,x='age',y='duration',palette='ch:78',hue='marital')

# %%
sns.jointplot(data=bank,x='age',y='campaign',palette='hls',hue='month')

# %%
sns.jointplot(data=bank,x='age',y='pdays',palette='magma',hue='housing')

# %%
sns.jointplot(data=bank,x='age',y='balance',palette='bright',hue='marital')

# %%
sns.jointplot(data=bank,x='age',y='balance',palette='Set2',hue='loan')
