# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
swiggy=pd.read_csv(r'C:\Users\admin\Downloads\archive\swiggy.csv')

# %%
swiggy
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
swiggy.shape
# Out:
# (8680, 10)

# %%
swiggy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB

# %%
swiggy.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
swiggy.columns
# Out:
# Index(['ID', 'Area', 'City', 'Restaurant', 'Price', 'Avg ratings',
#        'Total ratings', 'Food type', 'Address', 'Delivery time'],
#       dtype='object')

# %%
len(swiggy.columns)
# Out:
# 10

# %%
swiggy.dtypes
# Out:
# ID                 int64
# Area              object
# City              object
# Restaurant        object
# Price            float64
# Avg ratings      float64
# Total ratings      int64
# Food type         object
# Address           object
# Delivery time      int64
# dtype: object

# %%
swiggy.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8680.000000  8680.000000  8680.000000    8680.000000    8680.000000
# mean   244812.071429   348.444470     3.655104     156.634793      53.967051
# std    158671.617188   230.940074     0.647629     391.448014      14.292335
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72664.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283442.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393425.250000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %%
swiggy.describe().transpose()
# Out:
#                 count           mean            std    min      25%       50%  \
# ID             8680.0  244812.071429  158671.617188  211.0  72664.0  283442.0
# Price          8680.0     348.444470     230.940074    0.0    200.0     300.0
# Avg ratings    8680.0       3.655104       0.647629    2.0      2.9       3.9
# Total ratings  8680.0     156.634793     391.448014   20.0     50.0      80.0
# Delivery time  8680.0      53.967051      14.292335   20.0     44.0      53.0
#
#                      75%       max
# ID             393425.25  466928.0
# Price             400.00    2500.0
# Avg ratings         4.20       5.0
# Total ratings     100.00   10000.0
# Delivery time      64.00     109.0

# %%
swiggy.tail()
# Out:
#           ID                    Area       City                Restaurant  \
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings                   Food type  \
# 8675  500.0          2.9             80                      Pizzas
# 8676  200.0          2.9             80                South Indian
# 8677  150.0          2.9             80      Chinese,Snacks,Tandoor
# 8678  150.0          2.9             80  North Indian,Indian,Snacks
# 8679  250.0          2.9             80        Chaat,Snacks,Chinese
#
#           Address  Delivery time
# 8675  Navrangpura             40
# 8676       Rohini             28
# ...

# %%
swiggy.columns=['ID', 'Area', 'City', 'Restaurant', 'Price', 'Avg_ratings',
       'Total_ratings', 'Food_type', 'Address', 'Delivery_time']

# %%
swiggy.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg_ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total_ratings                                          Food_type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery_time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
sns.distplot(swiggy.ID,color='c')
# Out:
# <Axes: xlabel='ID', ylabel='Density'>

# %%
sns.distplot(swiggy.Price,color='r')
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(swiggy.Avg_ratings,color='g')
# Out:
# <Axes: xlabel='Avg_ratings', ylabel='Density'>

# %%
sns.distplot(swiggy.Total_ratings,color='purple')
# Out:
# <Axes: xlabel='Total_ratings', ylabel='Density'>

# %%
sns.distplot(swiggy.Delivery_time,color='k')
# Out:
# <Axes: xlabel='Delivery_time', ylabel='Density'>

# %%
swiggy.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg_ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total_ratings                                          Food_type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery_time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
sns.countplot(data=swiggy,x='City',palette='colorblind')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
sns.boxplot(data=swiggy,y='ID',palette='dark',x='City')
# Out:
# <Axes: xlabel='City', ylabel='ID'>

# %%
sns.boxplot(data=swiggy,y='Price',palette='deep',x='City')
# Out:
# <Axes: xlabel='City', ylabel='Price'>

# %%
sns.boxplot(data=swiggy,y='Avg_ratings',palette='hls',x='City')
# Out:
# <Axes: xlabel='City', ylabel='Avg_ratings'>

# %%
sns.boxplot(data=swiggy,y='Delivery_time',palette='Dark2',x='City')
# Out:
# <Axes: xlabel='City', ylabel='Delivery_time'>

# %%
sns.boxenplot(data=swiggy,y='ID',palette='muted',x='City')
# Out:
# <Axes: xlabel='City', ylabel='ID'>

# %%
sns.boxenplot(data=swiggy,y='Price',palette='Set2',x='City')
# Out:
# <Axes: xlabel='City', ylabel='Price'>

# %%
sns.boxenplot(data=swiggy,y='Avg_ratings',palette='tab20',x='City')
# Out:
# <Axes: xlabel='City', ylabel='Avg_ratings'>

# %%
sns.boxenplot(data=swiggy,y='Delivery_time',palette='mako',x='City')
# Out:
# <Axes: xlabel='City', ylabel='Delivery_time'>

# %%
swiggy.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg_ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total_ratings                                          Food_type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery_time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
sns.lmplot(data=swiggy,x='ID',y='Price',palette='bright',hue='City')

# %%
sns.lmplot(data=swiggy,x='Avg_ratings',y='Total_ratings',palette='colorblind',hue='City')

# %%
sns.lmplot(data=swiggy,x='Price',y='Avg_ratings',palette='Accent',hue='City')

# %%
sns.lmplot(data=swiggy,x='ID',y='Delivery_time',palette='viridis',hue='City')

# %%
sns.lmplot(data=swiggy,x='Total_ratings',y='Delivery_time',palette='cividis',hue='City')

# %%
sns.lmplot(data=swiggy,x='Avg_ratings',y='Delivery_time',palette='magma',hue='City')

# %%
sns.lmplot(data=swiggy,x='Price',y='Total_ratings',palette='PuBuGn',hue='City')

# %%
swiggy.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg_ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total_ratings                                          Food_type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery_time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
sns.jointplot(data=swiggy,x='Price',y='Avg_ratings',color='b',kind='hex')

# %%
sns.jointplot(data=swiggy,x='Avg_ratings',y='Total_ratings',color='k',kind='hex')

# %%
sns.jointplot(data=swiggy,x='Total_ratings',y='Delivery_time',color='g',kind='hex')

# %%
sns.jointplot(data=swiggy,x='Delivery_time',y='Price',color='purple',kind='hex')

# %%
sns.jointplot(data=swiggy,x='Avg_ratings',y='Delivery_time',color='c',kind='hex')

# %%
swiggy.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg_ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total_ratings                                          Food_type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery_time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
sns.kdeplot(data=swiggy,x='Price',hue='City',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(data=swiggy,x='Total_ratings',hue='City',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Total_ratings', ylabel='Density'>

# %%
sns.kdeplot(data=swiggy,x='Avg_ratings',hue='City',palette='cubehelix',fill=True)
# Out:
# <Axes: xlabel='Avg_ratings', ylabel='Density'>

# %%
sns.kdeplot(data=swiggy,x='Delivery_time',hue='City',palette='YlOrBr',fill=True)
# Out:
# <Axes: xlabel='Delivery_time', ylabel='Density'>

# %%
swiggy.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg_ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total_ratings                                          Food_type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery_time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
sns.stripplot(data=swiggy,x='City',y='ID',palette='deep')
# Out:
# <Axes: xlabel='City', ylabel='ID'>

# %%
sns.stripplot(data=swiggy,x='City',y='Price',palette='mako')
# Out:
# <Axes: xlabel='City', ylabel='Price'>

# %%
sns.stripplot(data=swiggy,x='City',y='Total_ratings',palette='cividis')
# Out:
# <Axes: xlabel='City', ylabel='Total_ratings'>

# %%
sns.stripplot(data=swiggy,x='City',y='Avg_ratings',palette='YlGnBu')
# Out:
# <Axes: xlabel='City', ylabel='Avg_ratings'>

# %%
sns.stripplot(data=swiggy,x='City',y='Delivery_time',palette='bright')
# Out:
# <Axes: xlabel='City', ylabel='Delivery_time'>

# %%
sns.pairplot(swiggy, hue="City",palette='dark')
