# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data={'Car':['Audi','BMW','mercedes'],
      'Frequency':[124,98,113],
      'Relative_Frequency':['37.01%', '29.25%', '33.73%']
     }
pd.DataFrame(data)
# Out:
#         Car  Frequency Relative_Frequency
# 0      Audi        124             37.01%
# 1       BMW         98             29.25%
# 2  mercedes        113             33.73%

# %%
plt.bar(data['Car'],data['Frequency'], color=['r','g','y'])
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(relative_frequencies, labels=brands, autopct='%1.1f%%', colors=['blue', 'red', 'green'])
plt.show()
