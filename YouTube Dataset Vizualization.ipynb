# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=10,5
sns.set_style('darkgrid')

# %%
yt=pd.read_csv(r'C:\Users\admin\Downloads\archive\youtube_2025_dataset.csv')

# %%
yt
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
yt.shape
# Out:
# (5000, 14)

# %%
yt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Channel Name                 5000 non-null   object
#  1   Youtuber Name                5000 non-null   object
#  2   Total Videos                 5000 non-null   int64
#  3   Best Video                   5000 non-null   object
#  4   Avg Video Length (min)       5000 non-null   float64
#  5   Total Subscribers            5000 non-null   int64
#  6   Members Count                5000 non-null   int64
#  7   AI Generated Content (%)     5000 non-null   int64
#  8   Neural Interface Compatible  5000 non-null   bool
#  9   Metaverse Integration Level  3718 non-null   object
#  10  Quantum Computing Topics     5000 non-null   int64
#  11  Holographic Content Rating   5000 non-null   object
#  12  Engagement Score             5000 non-null   float64
# ...

# %%
yt.isnull().sum()
# Out:
# Channel Name                      0
# Youtuber Name                     0
# Total Videos                      0
# Best Video                        0
# Avg Video Length (min)            0
# Total Subscribers                 0
# Members Count                     0
# AI Generated Content (%)          0
# Neural Interface Compatible       0
# Metaverse Integration Level    1282
# Quantum Computing Topics          0
# Holographic Content Rating        0
# Engagement Score                  0
# Content Value Index               0
# dtype: int64

# %%
yt.columns
# Out:
# Index(['Channel Name', 'Youtuber Name', 'Total Videos', 'Best Video',
#        'Avg Video Length (min)', 'Total Subscribers', 'Members Count',
#        'AI Generated Content (%)', 'Neural Interface Compatible',
#        'Metaverse Integration Level', 'Quantum Computing Topics',
#        'Holographic Content Rating', 'Engagement Score',
#        'Content Value Index'],
#       dtype='object')

# %%
len(yt.columns)
# Out:
# 14

# %%
yt.dtypes
# Out:
# Channel Name                    object
# Youtuber Name                   object
# Total Videos                     int64
# Best Video                      object
# Avg Video Length (min)         float64
# Total Subscribers                int64
# Members Count                    int64
# AI Generated Content (%)         int64
# Neural Interface Compatible       bool
# Metaverse Integration Level     object
# Quantum Computing Topics         int64
# Holographic Content Rating      object
# Engagement Score               float64
# Content Value Index            float64
# dtype: object

# %%
yt.describe()
# Out:
#        Total Videos  Avg Video Length (min)  Total Subscribers  Members Count  \
# count    5000.00000             5000.000000       5.000000e+03     5000.00000
# mean      274.43340               24.004540       5.058482e+06   249082.01980
# std       131.71675                0.874555       2.890895e+06   143555.47327
# min        50.00000               19.100000       1.755000e+03      143.00000
# 25%       159.00000               23.500000       2.547991e+06   127000.75000
# 50%       274.00000               24.000000       5.105967e+06   252320.50000
# 75%       389.00000               24.500000       7.541903e+06   371419.25000
# max       500.00000               28.900000       9.999975e+06   499991.00000
#
#        AI Generated Content (%)  Quantum Computing Topics  Engagement Score  \
# count               5000.000000               5000.000000       5000.000000
# mean                  49.328600                 10.061400      79974.100470
# ...

# %%
yt.describe().transpose()
# Out:
#                            count          mean           std      min  \
# Total Videos              5000.0  2.744334e+02  1.317167e+02    50.00
# Avg Video Length (min)    5000.0  2.400454e+01  8.745549e-01    19.10
# Total Subscribers         5000.0  5.058482e+06  2.890895e+06  1755.00
# Members Count             5000.0  2.490820e+05  1.435555e+05   143.00
# AI Generated Content (%)  5000.0  4.932860e+01  2.944425e+01     0.00
# Quantum Computing Topics  5000.0  1.006140e+01  6.093953e+00     0.00
# Engagement Score          5000.0  7.997410e+04  4.570477e+04    27.75
# Content Value Index       5000.0  2.184156e+01  9.863744e+00     0.00
#
#                                  25%         50%           75%         max
# Total Videos                  159.00      274.00  3.890000e+02      500.00
# Avg Video Length (min)         23.50       24.00  2.450000e+01       28.90
# Total Subscribers         2547991.25  5105967.00  7.541903e+06  9999975.00
# ...

# %%
yt.tail()
# Out:
#                   Channel Name   Youtuber Name  Total Videos  \
# 4995     Flores-Daniel Studios   Jasmine Smith           106
# 4996  Spencer and Sons Studios  John Rasmussen           130
# 4997    Obrien-Roberts Studios      Lisa Burke           179
# 4998              King Ltd Hub      Steve Diaz           182
# 4999         Henry Ltd Studios     Austin Tate            92
#
#                          Best Video  Avg Video Length (min)  \
# 4995  AI Challenge: Experience 2023                    22.0
# 4996    VR Challenge: Analysis 2023                    26.3
# 4997  AI Challenge: Experience 2023                    25.2
# 4998    VR Synthesis: Showcase 2023                    24.5
# 4999   AI Simulation: Showcase 2025                    25.2
#
#       Total Subscribers  Members Count  AI Generated Content (%)  \
# 4995            2665835         267828                        19
# 4996             136992          20019                        67
# ...

# %%
yt.columns=['Channel_Name', 'Youtuber_Name', 'Total_Videos', 'Best_Video','Av_Video_Length', 'Total_Subscribers', 'Members_Count','AI_Generated_Content', 'Neural_Interface_Compatible','Metaverse_Integration_Level', 'Quantum_Computing_Topics','Holographic_Content_Rating', 'Engagement_Score','Content_Value_Index']

# %%
yt.isnull().sum()
# Out:
# Channel_Name                      0
# Youtuber_Name                     0
# Total_Videos                      0
# Best_Video                        0
# Av_Video_Length                   0
# Total_Subscribers                 0
# Members_Count                     0
# AI_Generated_Content              0
# Neural_Interface_Compatible       0
# Metaverse_Integration_Level    1282
# Quantum_Computing_Topics          0
# Holographic_Content_Rating        0
# Engagement_Score                  0
# Content_Value_Index               0
# dtype: int64

# %%
yt['Metaverse_Integration_Level']=yt['Metaverse_Integration_Level'].fillna(yt['Metaverse_Integration_Level'].mode()[0])

# %%
yt.isnull().sum()
# Out:
# Channel_Name                   0
# Youtuber_Name                  0
# Total_Videos                   0
# Best_Video                     0
# Av_Video_Length                0
# Total_Subscribers              0
# Members_Count                  0
# AI_Generated_Content           0
# Neural_Interface_Compatible    0
# Metaverse_Integration_Level    0
# Quantum_Computing_Topics       0
# Holographic_Content_Rating     0
# Engagement_Score               0
# Content_Value_Index            0
# dtype: int64

# %%
yt.head()
# Out:
#                   Channel_Name       Youtuber_Name  Total_Videos  \
# 0              Smith-Ross Labs          Eric Patel            68
# 1             Sandoval PLC Hub  Cynthia Harrington           128
# 2  Jones, Moore and Ho Network       Amanda Walker           282
# 3         Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4           Wilson LLC Studios     Matthew Sherman           129
#
#                            Best_Video  Av_Video_Length  Total_Subscribers  \
# 0           VR Challenge: Review 2023             24.8            8264152
# 1  Nanotech Simulation: Analysis 2024             22.9            8768222
# 2  Metaverse Interface: Analysis 2024             24.0            6163386
# 3            VR Protocol: Review 2023             24.6            4712268
# 4    Nanotech Simulation: Review 2024             24.6            9592017
#
#    Members_Count  AI_Generated_Content  Neural_Interface_Compatible  \
# ...

# %%
sns.distplot(yt.Total_Videos,color='orange')
# Out:
# <Axes: xlabel='Total_Videos', ylabel='Density'>

# %%
sns.distplot(yt.Av_Video_Length,color='b')
# Out:
# <Axes: xlabel='Av_Video_Length', ylabel='Density'>

# %%
sns.distplot(yt.Total_Subscribers,color='g',bins=20)
# Out:
# <Axes: xlabel='Total_Subscribers', ylabel='Density'>

# %%
sns.distplot(yt.AI_Generated_Content,color='y',bins=5)
# Out:
# <Axes: xlabel='AI_Generated_Content', ylabel='Density'>

# %%
sns.distplot(yt.Members_Count,color='k',bins=15)
# Out:
# <Axes: xlabel='Members_Count', ylabel='Density'>

# %%
yt.head()
# Out:
#                   Channel_Name       Youtuber_Name  Total_Videos  \
# 0              Smith-Ross Labs          Eric Patel            68
# 1             Sandoval PLC Hub  Cynthia Harrington           128
# 2  Jones, Moore and Ho Network       Amanda Walker           282
# 3         Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4           Wilson LLC Studios     Matthew Sherman           129
#
#                            Best_Video  Av_Video_Length  Total_Subscribers  \
# 0           VR Challenge: Review 2023             24.8            8264152
# 1  Nanotech Simulation: Analysis 2024             22.9            8768222
# 2  Metaverse Interface: Analysis 2024             24.0            6163386
# 3            VR Protocol: Review 2023             24.6            4712268
# 4    Nanotech Simulation: Review 2024             24.6            9592017
#
#    Members_Count  AI_Generated_Content  Neural_Interface_Compatible  \
# ...

# %%
sns.countplot(data=yt,x='Neural_Interface_Compatible',palette='Set1',fill=False)
# Out:
# <Axes: xlabel='Neural_Interface_Compatible', ylabel='count'>

# %%
sns.countplot(data=yt,x='Metaverse_Integration_Level',palette='ch:45')
# Out:
# <Axes: xlabel='Metaverse_Integration_Level', ylabel='count'>

# %%
sns.countplot(data=yt,x='Holographic_Content_Rating',palette='ch:2')
# Out:
# <Axes: xlabel='Holographic_Content_Rating', ylabel='count'>

# %%
sns.countplot(data=yt,x='Neural_Interface_Compatible',palette='Set1',fill=True,hue='Metaverse_Integration_Level')
# Out:
# <Axes: xlabel='Neural_Interface_Compatible', ylabel='count'>

# %%
sns.countplot(data=yt,x='Neural_Interface_Compatible',palette='Set3',fill=True,hue='Holographic_Content_Rating')
# Out:
# <Axes: xlabel='Neural_Interface_Compatible', ylabel='count'>

# %%
sns.countplot(data=yt,x='Metaverse_Integration_Level',palette='ch:99',fill=True,hue='Holographic_Content_Rating')
# Out:
# <Axes: xlabel='Metaverse_Integration_Level', ylabel='count'>

# %%
yt.head()
# Out:
#                   Channel_Name       Youtuber_Name  Total_Videos  \
# 0              Smith-Ross Labs          Eric Patel            68
# 1             Sandoval PLC Hub  Cynthia Harrington           128
# 2  Jones, Moore and Ho Network       Amanda Walker           282
# 3         Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4           Wilson LLC Studios     Matthew Sherman           129
#
#                            Best_Video  Av_Video_Length  Total_Subscribers  \
# 0           VR Challenge: Review 2023             24.8            8264152
# 1  Nanotech Simulation: Analysis 2024             22.9            8768222
# 2  Metaverse Interface: Analysis 2024             24.0            6163386
# 3            VR Protocol: Review 2023             24.6            4712268
# 4    Nanotech Simulation: Review 2024             24.6            9592017
#
#    Members_Count  AI_Generated_Content  Neural_Interface_Compatible  \
# ...

# %%
sns.lmplot(data=yt,x='Total_Videos',y='Av_Video_Length',hue='Neural_Interface_Compatible')

# %%
sns.lmplot(data=yt,x='Total_Videos',y='Total_Subscribers',hue='Metaverse_Integration_Level')

# %%
sns.lmplot(data=yt,x='Total_Videos',y='Members_Count',hue='Holographic_Content_Rating',palette='Set1')

# %%
sns.lmplot(data=yt,x='AI_Generated_Content',y='Quantum_Computing_Topics',hue='Holographic_Content_Rating',palette='ch:45')

# %%
sns.lmplot(data=yt,x='Total_Videos',y='Content_Value_Index',hue='Holographic_Content_Rating',palette='Set2')

# %%
yt.head()
# Out:
#                   Channel_Name       Youtuber_Name  Total_Videos  \
# 0              Smith-Ross Labs          Eric Patel            68
# 1             Sandoval PLC Hub  Cynthia Harrington           128
# 2  Jones, Moore and Ho Network       Amanda Walker           282
# 3         Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4           Wilson LLC Studios     Matthew Sherman           129
#
#                            Best_Video  Av_Video_Length  Total_Subscribers  \
# 0           VR Challenge: Review 2023             24.8            8264152
# 1  Nanotech Simulation: Analysis 2024             22.9            8768222
# 2  Metaverse Interface: Analysis 2024             24.0            6163386
# 3            VR Protocol: Review 2023             24.6            4712268
# 4    Nanotech Simulation: Review 2024             24.6            9592017
#
#    Members_Count  AI_Generated_Content  Neural_Interface_Compatible  \
# ...

# %%
sns.boxplot(data=yt,x='Neural_Interface_Compatible',y='Total_Videos',palette='Set2')
# Out:
# <Axes: xlabel='Neural_Interface_Compatible', ylabel='Total_Videos'>

# %%
sns.boxplot(data=yt,x='Metaverse_Integration_Level',y='Members_Count',palette='ch:45',fill=False)
# Out:
# <Axes: xlabel='Metaverse_Integration_Level', ylabel='Members_Count'>

# %%
sns.boxplot(data=yt,x='Holographic_Content_Rating',y='Members_Count',palette='Set1',fill=False)
# Out:
# <Axes: xlabel='Holographic_Content_Rating', ylabel='Members_Count'>

# %%
sns.boxplot(data=yt,x='Holographic_Content_Rating',y='Engagement_Score',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='Holographic_Content_Rating', ylabel='Engagement_Score'>

# %%
sns.boxplot(data=yt,x='Neural_Interface_Compatible',y='AI_Generated_Content',palette='Set3')
# Out:
# <Axes: xlabel='Neural_Interface_Compatible', ylabel='AI_Generated_Content'>

# %%
sns.violinplot(data=yt,x='Neural_Interface_Compatible',y='Total_Videos',color='orange')
# Out:
# <Axes: xlabel='Neural_Interface_Compatible', ylabel='Total_Videos'>

# %%
sns.violinplot(data=yt,x='Metaverse_Integration_Level',y='Members_Count',color='b',fill=False)
# Out:
# <Axes: xlabel='Metaverse_Integration_Level', ylabel='Members_Count'>

# %%
sns.violinplot(data=yt,x='Holographic_Content_Rating',y='Members_Count',palette='Set1',fill=False)
# Out:
# <Axes: xlabel='Holographic_Content_Rating', ylabel='Members_Count'>

# %%
sns.violinplot(data=yt,x='Holographic_Content_Rating',y='Engagement_Score',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='Holographic_Content_Rating', ylabel='Engagement_Score'>

# %%
sns.violinplot(data=yt,x='Neural_Interface_Compatible',y='AI_Generated_Content',palette='Set3')
# Out:
# <Axes: xlabel='Neural_Interface_Compatible', ylabel='AI_Generated_Content'>

# %%
sns.jointplot(data=yt,x='Total_Videos',y='Av_Video_Length',kind='hex',color='Purple')

# %%
sns.jointplot(data=yt,x='Total_Videos',y='Total_Subscribers',color='g')

# %%
sns.jointplot(data=yt,x='Total_Videos',y='Members_Count',color='r',kind='reg')

# %%
sns.jointplot(data=yt,x='AI_Generated_Content',y='Quantum_Computing_Topics',kind='hist',color='c')

# %%
sns.jointplot(data=yt,x='Total_Videos',y='Content_Value_Index',kind='hex')

# %%
yt.head()
# Out:
#                   Channel_Name       Youtuber_Name  Total_Videos  \
# 0              Smith-Ross Labs          Eric Patel            68
# 1             Sandoval PLC Hub  Cynthia Harrington           128
# 2  Jones, Moore and Ho Network       Amanda Walker           282
# 3         Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4           Wilson LLC Studios     Matthew Sherman           129
#
#                            Best_Video  Av_Video_Length  Total_Subscribers  \
# 0           VR Challenge: Review 2023             24.8            8264152
# 1  Nanotech Simulation: Analysis 2024             22.9            8768222
# 2  Metaverse Interface: Analysis 2024             24.0            6163386
# 3            VR Protocol: Review 2023             24.6            4712268
# 4    Nanotech Simulation: Review 2024             24.6            9592017
#
#    Members_Count  AI_Generated_Content  Neural_Interface_Compatible  \
# ...

# %%
sns.kdeplot(data=yt,x='Total_Videos',color='k')
# Out:
# <Axes: xlabel='Total_Videos', ylabel='Density'>

# %%
sns.kdeplot(data=yt,x='Av_Video_Length',color='b',fill=True)
# Out:
# <Axes: xlabel='Av_Video_Length', ylabel='Density'>

# %%
sns.kdeplot(data=yt,x='Total_Subscribers',color='y',fill=True)
# Out:
# <Axes: xlabel='Total_Subscribers', ylabel='Density'>

# %%
sns.kdeplot(data=yt,x='Members_Count',color='g',fill=True)
# Out:
# <Axes: xlabel='Members_Count', ylabel='Density'>

# %%
sns.kdeplot(data=yt,x='Quantum_Computing_Topics',color='r',fill=True)
# Out:
# <Axes: xlabel='Quantum_Computing_Topics', ylabel='Density'>

# %%
sns.kdeplot(data=yt,x='Engagement_Score',color='k',fill=True)
# Out:
# <Axes: xlabel='Engagement_Score', ylabel='Density'>
