# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
zepto = pd.read_csv(r'C:\Users\admin\Downloads\archive\zepto_v2.csv', encoding='cp1252')

# %%
zepto
# Out:
#                  Category                                               name  \
# 0     Fruits & Vegetables                                              Onion
# 1     Fruits & Vegetables                                      Tomato Hybrid
# 2     Fruits & Vegetables                                     Tender Coconut
# 3     Fruits & Vegetables                                   Coriander Leaves
# 4     Fruits & Vegetables                                     Ladies Finger
# ...                   ...                                                ...
# 3727     Health & Hygiene  Stayfree Secure Dry Cover Extra Large Sanitary...
# 3728     Health & Hygiene  Dabur Honitus Herbal Cough Remedy Ayurvedic Syrup
# 3729     Health & Hygiene       Whisper Bindazzz Night Sanitary Pads XL Plus
# 3730     Health & Hygiene                             Fine Life Cotton Balls
# 3731     Health & Hygiene                           Dettol Antiseptic Liquid
#
# ...

# %%
zepto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3732 entries, 0 to 3731
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Category                3732 non-null   object
#  1   name                    3732 non-null   object
#  2   mrp                     3732 non-null   int64
#  3   discountPercent         3732 non-null   int64
#  4   availableQuantity       3732 non-null   int64
#  5   discountedSellingPrice  3732 non-null   int64
#  6   weightInGms             3732 non-null   int64
#  7   outOfStock              3732 non-null   bool
#  8   quantity                3732 non-null   int64
# dtypes: bool(1), int64(6), object(2)
# memory usage: 237.0+ KB

# %%
zepto.isnull().sum()
# Out:
# Category                  0
# name                      0
# mrp                       0
# discountPercent           0
# availableQuantity         0
# discountedSellingPrice    0
# weightInGms               0
# outOfStock                0
# quantity                  0
# dtype: int64

# %%
zepto.columns
# Out:
# Index(['Category', 'name', 'mrp', 'discountPercent', 'availableQuantity',
#        'discountedSellingPrice', 'weightInGms', 'outOfStock', 'quantity'],
#       dtype='object')

# %%
len(zepto.columns)
# Out:
# 9

# %%
zepto.describe()
# Out:
#                  mrp  discountPercent  availableQuantity  \
# count    3732.000000      3732.000000        3732.000000
# mean    15680.117899         7.617095           4.008574
# std     16088.807618         9.211733           2.203511
# min         0.000000         0.000000           0.000000
# 25%      6000.000000         0.000000           2.000000
# 50%     11000.000000         6.000000           5.000000
# 75%     20000.000000        10.000000           6.000000
# max    260000.000000        51.000000           6.000000
#
#        discountedSellingPrice   weightInGms     quantity
# count             3732.000000   3732.000000  3732.000000
# mean             14192.834941    387.843783   213.270900
# std              13850.726265    678.096509   194.730976
# min                  0.000000      0.000000     0.000000
# 25%               5500.000000    100.000000    50.000000
# 50%              10400.000000    225.000000   186.000000
# ...

# %%
zepto.describe().transpose()
# Out:
#                          count          mean           std  min     25%  \
# mrp                     3732.0  15680.117899  16088.807618  0.0  6000.0
# discountPercent         3732.0      7.617095      9.211733  0.0     0.0
# availableQuantity       3732.0      4.008574      2.203511  0.0     2.0
# discountedSellingPrice  3732.0  14192.834941  13850.726265  0.0  5500.0
# weightInGms             3732.0    387.843783    678.096509  0.0   100.0
# quantity                3732.0    213.270900    194.730976  0.0    50.0
#
#                             50%      75%       max
# mrp                     11000.0  20000.0  260000.0
# discountPercent             6.0     10.0      51.0
# availableQuantity           5.0      6.0       6.0
# discountedSellingPrice  10400.0  18400.0  139900.0
# weightInGms               225.0    450.0   10000.0
# quantity                  186.0    340.0    1500.0

# %%
zepto.head()
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# 2                  3                    4300           58       False
# 3                  3                    1700          100       False
# 4                  3                    1200          250       False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
sns.distplot(zepto.discountPercent,color='m',bins=10)
# Out:
# <Axes: xlabel='discountPercent', ylabel='Density'>

# %%
sns.distplot(zepto.availableQuantity,color='c',bins=10)
# Out:
# <Axes: xlabel='availableQuantity', ylabel='Density'>

# %%
sns.distplot(zepto.discountedSellingPrice,color='g',bins=10)
# Out:
# <Axes: xlabel='discountedSellingPrice', ylabel='Density'>

# %%
sns.distplot(zepto.weightInGms,color='k',bins=10)
# Out:
# <Axes: xlabel='weightInGms', ylabel='Density'>

# %%
sns.distplot(zepto.quantity,color='b',bins=10)
# Out:
# <Axes: xlabel='quantity', ylabel='Density'>

# %%
zepto.head()
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# 2                  3                    4300           58       False
# 3                  3                    1700          100       False
# 4                  3                    1200          250       False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
sns.countplot(data=zepto,x='Category',palette='dark')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(data=zepto,x='availableQuantity',palette='rocket')
# Out:
# <Axes: xlabel='availableQuantity', ylabel='count'>

# %%
sns.countplot(data=zepto,x='outOfStock',palette='mako')
# Out:
# <Axes: xlabel='outOfStock', ylabel='count'>

# %%
sns.countplot(data=zepto,x='outOfStock',palette='YlOrBr',hue='availableQuantity')
# Out:
# <Axes: xlabel='outOfStock', ylabel='count'>

# %%
zepto.head()
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# 2                  3                    4300           58       False
# 3                  3                    1700          100       False
# 4                  3                    1200          250       False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
sns.lmplot(data=zepto,x='discountPercent',y='availableQuantity',palette='dark',hue='outOfStock')

# %%
sns.lmplot(data=zepto,x='availableQuantity',y='discountedSellingPrice',palette='mako',hue='outOfStock')

# %%
sns.lmplot(data=zepto,x='discountedSellingPrice',y='weightInGms',palette='colorblind',hue='outOfStock')

# %%
sns.lmplot(data=zepto,x='weightInGms',y='quantity',palette='Set1',hue='outOfStock')

# %%
sns.lmplot(data=zepto,x='mrp',y='quantity',palette='Dark2',hue='outOfStock')

# %%
zepto.head()
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# 2                  3                    4300           58       False
# 3                  3                    1700          100       False
# 4                  3                    1200          250       False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
sns.boxenplot(data=zepto,x='outOfStock',y='mrp',palette='magma')
# Out:
# <Axes: xlabel='outOfStock', ylabel='mrp'>

# %%
sns.boxenplot(data=zepto,x='outOfStock',y='discountPercent',palette='mako')
# Out:
# <Axes: xlabel='outOfStock', ylabel='discountPercent'>

# %%
sns.boxplot(data=zepto,x='outOfStock',y='availableQuantity',palette='cividis')
# Out:
# <Axes: xlabel='outOfStock', ylabel='availableQuantity'>

# %%
sns.boxenplot(data=zepto,x='outOfStock',y='discountedSellingPrice',palette='dark')
# Out:
# <Axes: xlabel='outOfStock', ylabel='discountedSellingPrice'>

# %%
sns.boxenplot(data=zepto,x='outOfStock',y='weightInGms',palette='colorblind')
# Out:
# <Axes: xlabel='outOfStock', ylabel='weightInGms'>

# %%
sns.boxenplot(data=zepto,x='outOfStock',y='quantity',palette='Set1')
# Out:
# <Axes: xlabel='outOfStock', ylabel='quantity'>

# %%
zepto.head()
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# 2                  3                    4300           58       False
# 3                  3                    1700          100       False
# 4                  3                    1200          250       False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
sns.jointplot(data=zepto,x='mrp',y='discountPercent',color='m',kind='hex')

# %%
sns.jointplot(data=zepto,x='discountPercent',y='availableQuantity',color='g',kind='kde')

# %%
sns.jointplot(data=zepto,x='availableQuantity',y='discountedSellingPrice',color='c',kind='hex')

# %%
sns.jointplot(data=zepto,x='discountedSellingPrice',y='weightInGms',color='r',kind='kde')

# %%
sns.jointplot(data=zepto,x='weightInGms',y='quantity',color='k',kind='hex')

# %%
sns.jointplot(data=zepto,x='mrp',y='quantity',color='r',kind='hex')

# %%
zepto.head()
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# 2                  3                    4300           58       False
# 3                  3                    1700          100       False
# 4                  3                    1200          250       False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
sns.kdeplot(data=zepto,x='mrp',hue='outOfStock',palette='deep',fill=True)
# Out:
# <Axes: xlabel='mrp', ylabel='Density'>

# %%
sns.kdeplot(data=zepto,x='discountPercent',hue='outOfStock',palette='colorblind',fill=True)
# Out:
# <Axes: xlabel='discountPercent', ylabel='Density'>

# %%
sns.kdeplot(data=zepto,x='availableQuantity',hue='outOfStock',palette='cividis',fill=True)
# Out:
# <Axes: xlabel='availableQuantity', ylabel='Density'>

# %%
sns.kdeplot(data=zepto,x='discountedSellingPrice',hue='outOfStock',palette='dark',fill=True)
# Out:
# <Axes: xlabel='discountedSellingPrice', ylabel='Density'>

# %%
sns.kdeplot(data=zepto,x='weightInGms',hue='outOfStock',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='weightInGms', ylabel='Density'>

# %%
sns.kdeplot(data=zepto,x='quantity',hue='outOfStock',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='quantity', ylabel='Density'>

# %%
zepto.head()
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# 2                  3                    4300           58       False
# 3                  3                    1700          100       False
# 4                  3                    1200          250       False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
sns.stripplot(data=zepto,x='outOfStock',y='mrp',palette='dark')
# Out:
# <Axes: xlabel='outOfStock', ylabel='mrp'>

# %%
sns.stripplot(data=zepto,x='outOfStock',y='discountPercent',palette='cividis')
# Out:
# <Axes: xlabel='outOfStock', ylabel='discountPercent'>

# %%
sns.stripplot(data=zepto,x='outOfStock',y='availableQuantity',palette='magma')
# Out:
# <Axes: xlabel='outOfStock', ylabel='availableQuantity'>

# %%
sns.stripplot(data=zepto,x='outOfStock',y='discountedSellingPrice',palette='Dark2')
# Out:
# <Axes: xlabel='outOfStock', ylabel='discountedSellingPrice'>

# %%
sns.stripplot(data=zepto,x='outOfStock',y='weightInGms',palette='rocket')
# Out:
# <Axes: xlabel='outOfStock', ylabel='weightInGms'>

# %%
sns.stripplot(data=zepto,x='outOfStock',y='quantity',palette='mako')
# Out:
# <Axes: xlabel='outOfStock', ylabel='quantity'>

# %%
sns.pairplot(zepto, hue="outOfStock",palette='Dark2')
