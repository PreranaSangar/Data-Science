# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=8,4
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
transaction=pd.read_csv(r'C:\Users\admin\Downloads\archive (1)\ecommerce_transactions.csv')

# %%
transaction
# Out:
#        Transaction_ID           User_Name  Age    Country Product_Category  \
# 0                   1            Ava Hall   63     Mexico         Clothing
# 1                   2         Sophia Hall   59      India           Beauty
# 2                   3     Elijah Thompson   26     France            Books
# 3                   4        Elijah White   43     Mexico           Sports
# 4                   5          Ava Harris   48    Germany           Beauty
# ...               ...                 ...  ...        ...              ...
# 49995           49996  Isabella Rodriguez   53      India      Electronics
# 49996           49997           Emma Hall   30     France   Home & Kitchen
# 49997           49998      Isabella Allen   50  Australia           Beauty
# 49998           49999        Olivia Clark   48  Australia          Grocery
# 49999           50000       Olivia Harris   70     Canada           Sports
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
transaction.shape
# Out:
# (50000, 8)

# %%
transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    50000 non-null  int64
#  1   User_Name         50000 non-null  object
#  2   Age               50000 non-null  int64
#  3   Country           50000 non-null  object
#  4   Product_Category  50000 non-null  object
#  5   Purchase_Amount   50000 non-null  float64
#  6   Payment_Method    50000 non-null  object
#  7   Transaction_Date  50000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.1+ MB

# %%
transaction.columns
# Out:
# Index(['Transaction_ID', 'User_Name', 'Age', 'Country', 'Product_Category',
#        'Purchase_Amount', 'Payment_Method', 'Transaction_Date'],
#       dtype='object')

# %%
len(transaction.columns)
# Out:
# 8

# %%
transaction.dtypes
# Out:
# Transaction_ID        int64
# User_Name            object
# Age                   int64
# Country              object
# Product_Category     object
# Purchase_Amount     float64
# Payment_Method       object
# Transaction_Date     object
# dtype: object

# %%
transaction.tail()
# Out:
#        Transaction_ID           User_Name  Age    Country Product_Category  \
# 49995           49996  Isabella Rodriguez   53      India      Electronics
# 49996           49997           Emma Hall   30     France   Home & Kitchen
# 49997           49998      Isabella Allen   50  Australia           Beauty
# 49998           49999        Olivia Clark   48  Australia          Grocery
# 49999           50000       Olivia Harris   70     Canada           Sports
#
#        Purchase_Amount    Payment_Method Transaction_Date
# 49995           140.09               UPI       2024-08-07
# 49996           815.31  Cash on Delivery       2025-02-07
# 49997           535.77               UPI       2023-08-11
# 49998           370.99  Cash on Delivery       2025-01-02
# 49999           577.66       Credit Card       2024-06-03

# %%
transaction.describe()
# Out:
#        Transaction_ID           Age  Purchase_Amount
# count    50000.000000  50000.000000     50000.000000
# mean     25000.500000     43.968680       503.159793
# std      14433.901067     15.260578       286.563558
# min          1.000000     18.000000         5.040000
# 25%      12500.750000     31.000000       255.450000
# 50%      25000.500000     44.000000       503.110000
# 75%      37500.250000     57.000000       751.162500
# max      50000.000000     70.000000       999.980000

# %%
transaction.describe().transpose()
# Out:
#                    count          mean           std    min       25%  \
# Transaction_ID   50000.0  25000.500000  14433.901067   1.00  12500.75
# Age              50000.0     43.968680     15.260578  18.00     31.00
# Purchase_Amount  50000.0    503.159793    286.563558   5.04    255.45
#
#                       50%         75%       max
# Transaction_ID   25000.50  37500.2500  50000.00
# Age                 44.00     57.0000     70.00
# Purchase_Amount    503.11    751.1625    999.98

# %%
transaction.isnull().sum()
# Out:
# Transaction_ID      0
# User_Name           0
# Age                 0
# Country             0
# Product_Category    0
# Purchase_Amount     0
# Payment_Method      0
# Transaction_Date    0
# dtype: int64

# %%
transaction.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
sns.distplot(transaction.Age,color='c')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(transaction.Purchase_Amount,color='r')
# Out:
# <Axes: xlabel='Purchase_Amount', ylabel='Density'>

# %%
sns.displot(transaction.Age,color='y')

# %%
sns.displot(transaction.Purchase_Amount)

# %%
transaction.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
sns.lmplot(data=transaction,x='Age',y='Purchase_Amount',hue='Country')

# %%
sns.lmplot(data=transaction,x='Age',y='Purchase_Amount',hue='Product_Category')

# %%
sns.lmplot(data=transaction,x='Age',y='Purchase_Amount',hue='Payment_Method')

# %%
transaction.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
sns.countplot(data=transaction,x='Product_Category',palette='ch:44')
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
sns.countplot(data=transaction,x='Country',palette='Set1')
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data=transaction,x='Payment_Method',palette='ch:3')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='count'>

# %%
sns.countplot(data=transaction,x='Product_Category',palette='Set3',hue='Country')
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
sns.countplot(data=transaction,x='Product_Category',palette='Set1',hue='Payment_Method')
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
sns.countplot(data=transaction,x='Country',palette='ch:25',hue='Payment_Method')
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
transaction.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
sns.histplot(data=transaction,x='Country',color='k')
# Out:
# <Axes: xlabel='Country', ylabel='Count'>

# %%
sns.histplot(data=transaction,x='Product_Category',color='y')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Count'>

# %%
sns.histplot(data=transaction,x='Payment_Method',color='b')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Count'>

# %%
sns.boxplot(transaction.Age,color='r',fill=False)
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(transaction.Purchase_Amount,color='c',fill=True)
# Out:
# <Axes: ylabel='Purchase_Amount'>

# %%
transaction.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
sns.boxplot(data=transaction,x='Country',y='Age',fill=False)
# Out:
# <Axes: xlabel='Country', ylabel='Age'>

# %%
sns.boxplot(data=transaction,x='Product_Category',y='Age',fill=True,palette='Set1')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Age'>

# %%
sns.boxplot(data=transaction,x='Payment_Method',y='Age',fill=True,palette='Set2')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Age'>

# %%
sns.boxplot(data=transaction,x='Payment_Method',y='Purchase_Amount',fill=True,palette='ch:34')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Purchase_Amount'>

# %%
sns.boxplot(data=transaction,x='Product_Category',y='Purchase_Amount',fill=True,palette='ch:56')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Purchase_Amount'>

# %%
sns.boxplot(data=transaction,x='Country',y='Purchase_Amount',fill=False,palette='ch:78')
# Out:
# <Axes: xlabel='Country', ylabel='Purchase_Amount'>

# %%
sns.boxplot(data=transaction,x='Country',y='Product_Category',fill=False,palette='Set2')
# Out:
# <Axes: xlabel='Country', ylabel='Product_Category'>

# %%
sns.boxplot(data=transaction,x='Country',y='Payment_Method',fill=False,color='k')
# Out:
# <Axes: xlabel='Country', ylabel='Payment_Method'>

# %%
transaction.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
sns.violinplot(data=transaction,x='Country',y='Age',fill=True)
# Out:
# <Axes: xlabel='Country', ylabel='Age'>

# %%
sns.violinplot(data=transaction,x='Product_Category',y='Age',fill=True,palette='Set2')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Age'>

# %%
sns.violinplot(data=transaction,x='Payment_Method',y='Purchase_Amount',fill=True,palette='ch:34')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Purchase_Amount'>

# %%
sns.violinplot(data=transaction,x='Payment_Method',y='Age',fill=True,palette='Set2')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Age'>

# %%
sns.violinplot(data=transaction,x='Country',y='Purchase_Amount',fill=False,palette='ch:78')
# Out:
# <Axes: xlabel='Country', ylabel='Purchase_Amount'>

# %%
sns.violinplot(data=transaction,x='Country',y='Product_Category',fill=False,palette='Set2')
# Out:
# <Axes: xlabel='Country', ylabel='Product_Category'>

# %%
sns.violinplot(data=transaction,x='Product_Category',y='Purchase_Amount',fill=True,palette='ch:56')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Purchase_Amount'>

# %%
sns.violinplot(data=transaction,x='Country',y='Payment_Method',fill=False,color='y')
# Out:
# <Axes: xlabel='Country', ylabel='Payment_Method'>

# %%
Commerce = transaction.select_dtypes(include=['number'])

# Set figure size
fig = plt.figure(figsize=(10, 7))

# Plot heatmap
sns.heatmap(Commerce.corr(), annot=True, cmap='Purples', linewidths=1, 
            linecolor='k', square=True, vmin=-1, vmax=1, 
            cbar_kws={"orientation": "vertical"}, cbar=True)
# Out:
# <Axes: >

# %%
transaction.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
sns.kdeplot(transaction.Age,color='y')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(transaction.Purchase_Amount,color='c',fill=True)
# Out:
# <Axes: xlabel='Purchase_Amount', ylabel='Density'>

# %%
sns.barplot(data=transaction,x='Country',y='Age',fill=True)
# Out:
# <Axes: xlabel='Country', ylabel='Age'>

# %%
sns.barplot(data=transaction,x='Product_Category',y='Age',fill=True,palette='Set2')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Age'>

# %%
sns.barplot(data=transaction,x='Payment_Method',y='Purchase_Amount',fill=True,palette='ch:34')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Purchase_Amount'>

# %%
sns.barplot(data=transaction,x='Payment_Method',y='Age',fill=True,palette='Set2')
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Age'>

# %%
sns.barplot(data=transaction,x='Country',y='Purchase_Amount',fill=False,palette='ch:78')
# Out:
# <Axes: xlabel='Country', ylabel='Purchase_Amount'>
