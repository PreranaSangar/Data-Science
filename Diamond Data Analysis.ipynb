# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
diamond = pd.read_csv(r'C:\Users\admin\Downloads\archive\diamonds.csv')

# %%
diamond
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
diamond.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
diamond.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
len(diamond.columns)
# Out:
# 11

# %%
diamond.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
diamond.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
diamond.describe().transpose()
# Out:
#               count          mean           std    min       25%       50%  \
# Unnamed: 0  53940.0  26970.500000  15571.281097    1.0  13485.75  26970.50
# carat       53940.0      0.797940      0.474011    0.2      0.40      0.70
# depth       53940.0     61.749405      1.432621   43.0     61.00     61.80
# table       53940.0     57.457184      2.234491   43.0     56.00     57.00
# price       53940.0   3932.799722   3989.439738  326.0    950.00   2401.00
# x           53940.0      5.731157      1.121761    0.0      4.71      5.70
# y           53940.0      5.734526      1.142135    0.0      4.72      5.71
# z           53940.0      3.538734      0.705699    0.0      2.91      3.53
#
#                  75%       max
# Unnamed: 0  40455.25  53940.00
# carat           1.04      5.01
# depth          62.50     79.00
# table          59.00     95.00
# price        5324.25  18823.00
# x               6.54     10.74
# y               6.54     58.90
# z               4.04     31.80

# %%
diamond = diamond.drop('Unnamed: 0', axis=1)

# %%
diamond.columns=['carat', 'cut', 'color', 'clarity', 'depth', 'table','price', 'a', 'b', 'c']

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.distplot(diamond.carat,color='m',bins=10)
# Out:
# <Axes: xlabel='carat', ylabel='Density'>

# %%
sns.distplot(diamond.depth,color='g',bins=10)
# Out:
# <Axes: xlabel='depth', ylabel='Density'>

# %%
sns.distplot(diamond.price,color='r',bins=10)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(diamond.table,color='c',bins=10)
# Out:
# <Axes: xlabel='table', ylabel='Density'>

# %%
sns.distplot(diamond.a,color='y',bins=10)
# Out:
# <Axes: xlabel='a', ylabel='Density'>

# %%
sns.distplot(diamond.b,color='k',bins=10)
# Out:
# <Axes: xlabel='b', ylabel='Density'>

# %%
sns.distplot(diamond.c,color='b',bins=10)
# Out:
# <Axes: xlabel='c', ylabel='Density'>

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.countplot(data=diamond,x='cut',palette='dark')
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
sns.countplot(data=diamond,x='color',palette='rocket')
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
sns.countplot(data=diamond,x='clarity',palette='bright')
# Out:
# <Axes: xlabel='clarity', ylabel='count'>

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.countplot(data=diamond,x='cut',hue='color',palette='mako')
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
sns.countplot(data=diamond,x='cut',hue='clarity',palette='Set1')
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
sns.countplot(data=diamond,x='color',hue='clarity',palette='rocket')
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.lmplot(data=diamond,x='depth',y='table',palette='dark',hue='cut')

# %%
sns.lmplot(data=diamond,x='depth',y='price',palette='mako',hue='color')

# %%
sns.lmplot(data=diamond,x='price',y='a',palette='Set1',hue='cut')

# %%
sns.lmplot(data=diamond,x='price',y='b',palette='cividis',hue='clarity')

# %%
sns.lmplot(data=diamond,x='a',y='b',palette='colorblind',hue='clarity')

# %%
sns.lmplot(data=diamond,x='table',y='b',palette='rocket',hue='cut')

# %%
sns.lmplot(data=diamond,x='b',y='c',palette='Dark2',hue='color')

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.boxenplot(data=diamond,x='cut',y='price',palette='colorblind')
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.boxenplot(data=diamond,x='color',y='depth',palette='dark')
# Out:
# <Axes: xlabel='color', ylabel='depth'>

# %%
sns.boxenplot(data=diamond,x='clarity',y='depth',palette='rocket')
# Out:
# <Axes: xlabel='clarity', ylabel='depth'>

# %%
sns.boxenplot(data=diamond,x='cut',y='carat',palette='Set1')
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.stripplot(data=diamond,x='cut',y='depth',palette='dark')
# Out:
# <Axes: xlabel='cut', ylabel='depth'>

# %%
sns.stripplot(data=diamond,x='color',y='table',palette='tab20')
# Out:
# <Axes: xlabel='color', ylabel='table'>

# %%
sns.stripplot(data=diamond,x='clarity',y='price',palette='mako')
# Out:
# <Axes: xlabel='clarity', ylabel='price'>

# %%
sns.stripplot(data=diamond,x='cut',y='carat',palette='Set1')
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
sns.stripplot(data=diamond,x='color',y='a',palette='rocket')
# Out:
# <Axes: xlabel='color', ylabel='a'>

# %%
sns.stripplot(data=diamond,x='clarity',y='b',palette='cividis')
# Out:
# <Axes: xlabel='clarity', ylabel='b'>

# %%
sns.stripplot(data=diamond,x='cut',y='c',palette='colorblind')
# Out:
# <Axes: xlabel='cut', ylabel='c'>

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.jointplot(data=diamond,x='depth',y='carat',color='m',kind='resid')

# %%
sns.jointplot(data=diamond,x='price',y='carat',color='g',kind='resid')

# %%
sns.jointplot(data=diamond,x='depth',y='table',color='k',kind='resid')

# %%
sns.jointplot(data=diamond,x='table',y='price',color='r',kind='resid')

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.kdeplot(data=diamond,x='carat',hue='cut',palette='dark',fill=True)
# Out:
# <Axes: xlabel='carat', ylabel='Density'>

# %%
sns.kdeplot(data=diamond,x='depth',hue='color',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='depth', ylabel='Density'>

# %%
sns.kdeplot(data=diamond,x='table',hue='clarity',palette='cividis',fill=True)
# Out:
# <Axes: xlabel='table', ylabel='Density'>

# %%
sns.kdeplot(data=diamond,x='price',hue='cut',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=diamond,x='carat',hue='color',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='carat', ylabel='Density'>

# %%
sns.kdeplot(data=diamond,x='price',hue='clarity',palette='mako',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     a     b     c
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.pairplot(diamond, hue="cut",palette='magma')

# %%
sns.pairplot(diamond, hue="color",palette='dark')

# %%
sns.pairplot(diamond, hue="clarity",palette='rocket')
