# %% [markdown]
# # loc and iloc

# %% [raw]
# Loc and iloc(Feature Extarction)
# Loc: is label base
# iloc: is indexbase

# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\ExcelR Data Science\August\Aug 8\players_20.csv')
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
row1=df.loc[3]

# %%
row1
# Out:
# sofifa_id                                                200389
# player_url    https://sofifa.com/player/200389/jan-oblak/20/...
# short_name                                             J. Oblak
# long_name                                             Jan Oblak
# age                                                          26
#                                     ...
# lb                                                          NaN
# lcb                                                         NaN
# cb                                                          NaN
# rcb                                                         NaN
# rb                                                          NaN
# Name: 3, Length: 104, dtype: object

# %%
row2=df.iloc[3]

# %%
row2
# Out:
# sofifa_id                                                200389
# player_url    https://sofifa.com/player/200389/jan-oblak/20/...
# short_name                                             J. Oblak
# long_name                                             Jan Oblak
# age                                                          26
#                                     ...
# lb                                                          NaN
# lcb                                                         NaN
# cb                                                          NaN
# rcb                                                         NaN
# rb                                                          NaN
# Name: 3, Length: 104, dtype: object

# %%
row1==row2
# Out:
# sofifa_id      True
# player_url     True
# short_name     True
# long_name      True
# age            True
#               ...
# lb            False
# lcb           False
# cb            False
# rcb           False
# rb            False
# Name: 3, Length: 104, dtype: bool

# %%
df.loc[[2,4,3,8]]
# for selecting particular row
# Out:
#    sofifa_id                                         player_url short_name  \
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  Neymar Jr
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  E. Hazard
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...   J. Oblak
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...  L. Modrić
#
#                        long_name  age         dob  height_cm  weight_kg  \
# 2  Neymar da Silva Santos Junior   27  26-06-1987        175         68
# 4                    Eden Hazard   28  28-06-1987        175         74
# 3                      Jan Oblak   26  27-06-1987        188         87
# 8                    Luka Modrić   33  02-07-1987        172         66
#
#   nationality                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 2      Brazil  Paris Saint-Germain  ...  66+3  61+3  61+3  61+3  66+3  61+3
# ...

# %%
df.iloc[5:10]
# 10 th excluded
# Out:
#    sofifa_id                                         player_url  \
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 7     203376  https://sofifa.com/player/203376/virgil-van-di...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#       short_name              long_name  age         dob  height_cm  \
# 5   K. De Bruyne        Kevin De Bruyne   28  29-06-1987        181
# 6  M. ter Stegen  Marc-André ter Stegen   27  30-06-1987        187
# 7    V. van Dijk        Virgil van Dijk   27  01-07-1987        193
# 8      L. Modrić            Luka Modrić   33  02-07-1987        172
# 9       M. Salah   Mohamed  Salah Ghaly   27  03-07-1987        175
#
#    weight_kg  nationality             club  ...   lwb   ldm   cdm   rdm   rwb  \
# 5         70      Belgium  Manchester City  ...  77+3  77+3  77+3  77+3  77+3
# ...

# %%
df.loc[5:10]
# 10 th included
# Out:
#     sofifa_id                                         player_url  \
# 5      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...
# 10     231747  https://sofifa.com/player/231747/kylian-mbappe...
#
#        short_name              long_name  age         dob  height_cm  \
# 5    K. De Bruyne        Kevin De Bruyne   28  29-06-1987        181
# 6   M. ter Stegen  Marc-André ter Stegen   27  30-06-1987        187
# 7     V. van Dijk        Virgil van Dijk   27  01-07-1987        193
# 8       L. Modrić            Luka Modrić   33  02-07-1987        172
# 9        M. Salah   Mohamed  Salah Ghaly   27  03-07-1987        175
# 10      K. Mbappé          Kylian Mbappé   20  04-07-1987        178
#
# ...

# %%
df.iloc[:,2:7]
# Out:
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2              Neymar Jr        Neymar da Silva Santos Junior   27
# 3               J. Oblak                            Jan Oblak   26
# 4              E. Hazard                          Eden Hazard   28
# ...                  ...                                  ...  ...
# 18273         Shao Shuai                                   邵帅   22
# 18274       Xiao Mingjie                         Mingjie Xiao   22
# 18275          Zhang Wei                                   张威   19
# 18276       Wang Haijian                                  汪海健   18
# 18277         Pan Ximing                                  潘喜明   26
#
#               dob  height_cm
# 0      24-06-1987        170
# 1      25-06-1987        187
# 2      26-06-1987        175
# 3      27-06-1987        188
# ...

# %%
df.iloc[[2,5],2:7]
# Out:
#      short_name                      long_name  age         dob  height_cm
# 2     Neymar Jr  Neymar da Silva Santos Junior   27  26-06-1987        175
# 5  K. De Bruyne                Kevin De Bruyne   28  29-06-1987        181

# %%
df.loc[2:5,['sofifa_id', 'player_url', 'short_name']]
# Out:
#    sofifa_id                                         player_url    short_name
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...     Neymar Jr
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...      J. Oblak
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...     E. Hazard
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...  K. De Bruyne

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)
