# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
sns.set_style('darkgrid')
plt.rcParams['figure.figsize']=8,5

# %%
obesity=pd.read_csv(r'C:\Users\admin\Downloads\dataset\Obesity_DataSet.csv')

# %%
obesity
# Out:
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0     Female   21    1.62   64.00                            yes   no   2.0
# 1     Female   21    1.52   56.00                            yes   no   3.0
# 2       Male   23    1.80   77.00                            yes   no   2.0
# 3       Male   27    1.80   87.00                             no   no   3.0
# 4       Male   22    1.78   89.80                             no   no   2.0
# ...      ...  ...     ...     ...                            ...  ...   ...
# 2106  Female   21    1.71  131.41                            yes  yes   3.0
# 2107  Female   22    1.75  133.74                            yes  yes   3.0
# 2108  Female   23    1.75  133.69                            yes  yes   3.0
# 2109  Female   24    1.74  133.35                            yes  yes   3.0
# 2110  Female   24    1.74  133.47                            yes  yes   3.0
#
# ...

# %%
obesity.shape
# Out:
# (2111, 17)

# %%
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
obesity.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
len(obesity.columns)
# Out:
# 17

# %%
obesity.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
obesity.dtypes
# Out:
# Gender                             object
# Age                                 int64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
obesity.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.315964     1.701620    86.586035     2.418986     2.685651
# std       6.357078     0.093368    26.191163     0.533996     0.778079
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      20.000000     1.630000    65.470000     2.000000     2.660000
# 50%      23.000000     1.700000    83.000000     2.390000     3.000000
# 75%      26.000000     1.770000   107.430000     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008053     1.010313     0.657861
# std       0.612950     0.850613     0.608926
# min       1.000000     0.000000     0.000000
# 25%       1.585000     0.125000     0.000000
# 50%       2.000000     1.000000     0.625000
# ...

# %%
obesity.describe().transpose()
# Out:
#          count       mean        std    min     25%     50%     75%     max
# Age     2111.0  24.315964   6.357078  14.00  20.000  23.000   26.00   61.00
# Height  2111.0   1.701620   0.093368   1.45   1.630   1.700    1.77    1.98
# Weight  2111.0  86.586035  26.191163  39.00  65.470  83.000  107.43  173.00
# FCVC    2111.0   2.418986   0.533996   1.00   2.000   2.390    3.00    3.00
# NCP     2111.0   2.685651   0.778079   1.00   2.660   3.000    3.00    4.00
# CH2O    2111.0   2.008053   0.612950   1.00   1.585   2.000    2.48    3.00
# FAF     2111.0   1.010313   0.850613   0.00   0.125   1.000    1.67    3.00
# TUE     2111.0   0.657861   0.608926   0.00   0.000   0.625    1.00    2.00

# %%
obesity.tail()
# Out:
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female   21    1.71  131.41                            yes  yes   3.0
# 2107  Female   22    1.75  133.74                            yes  yes   3.0
# 2108  Female   23    1.75  133.69                            yes  yes   3.0
# 2109  Female   24    1.74  133.35                            yes  yes   3.0
# 2110  Female   24    1.74  133.47                            yes  yes   3.0
#
#       NCP       CAEC SMOKE  CH2O SCC   FAF    TUE       CALC  \
# 2106  3.0  Sometimes    no  1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes    no  2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes    no  2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes    no  2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes    no  2.86  no  1.03  0.714  Sometimes
#
#                      MTRANS        NObeyesdad
# 2106  Public_Transportation  Obesity_Type_III
# 2107  Public_Transportation  Obesity_Type_III
# ...

# %%
obesity.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
sns.distplot(obesity.Age,color='r')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(obesity.Height,color='b')
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(obesity.Weight,color='k')
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.distplot(obesity.FCVC,color='g')
# Out:
# <Axes: xlabel='FCVC', ylabel='Density'>

# %%
sns.distplot(obesity.NCP,color='Purple')
# Out:
# <Axes: xlabel='NCP', ylabel='Density'>

# %%
sns.distplot(obesity.CH2O,color='y')
# Out:
# <Axes: xlabel='CH2O', ylabel='Density'>

# %%
sns.distplot(obesity.TUE,color='c')
# Out:
# <Axes: xlabel='TUE', ylabel='Density'>

# %%
obesity.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
sns.countplot(data=obesity,x='Gender',palette='Dark2')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=obesity,x='family_history_with_overweight',palette='Paired')
# Out:
# <Axes: xlabel='family_history_with_overweight', ylabel='count'>

# %%
sns.countplot(data=obesity,x='FAVC',palette='dark')
# Out:
# <Axes: xlabel='FAVC', ylabel='count'>

# %%
sns.countplot(data=obesity,x='CAEC',palette='colorblind')
# Out:
# <Axes: xlabel='CAEC', ylabel='count'>

# %%
sns.countplot(data=obesity,x='SMOKE',palette='BrBG')
# Out:
# <Axes: xlabel='SMOKE', ylabel='count'>

# %%
sns.countplot(data=obesity,x='MTRANS',palette='bwr')
# Out:
# <Axes: xlabel='MTRANS', ylabel='count'>

# %%
sns.countplot(data=obesity,x='NObeyesdad',palette='Spectral')
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='count'>

# %%
obesity.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
sns.countplot(data=obesity,x='Gender',palette='cubehelix',hue='family_history_with_overweight')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=obesity,x='FAVC',palette='cubehelix',hue='CAEC')
# Out:
# <Axes: xlabel='FAVC', ylabel='count'>

# %%
sns.countplot(data=obesity,x='CAEC',palette='Reds',hue='SMOKE')
# Out:
# <Axes: xlabel='CAEC', ylabel='count'>

# %%
sns.countplot(data=obesity,x='SCC',palette='YlOrBr',hue='SMOKE')
# Out:
# <Axes: xlabel='SCC', ylabel='count'>

# %%
sns.countplot(data=obesity,x='Gender',palette='bright',hue='SMOKE')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=obesity,x='Gender',palette='dark',hue='NObeyesdad')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
obesity.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
sns.lmplot(data=obesity,x='Age',y='Height',hue='family_history_with_overweight',palette='dark',markers='*')

# %%
sns.lmplot(data=obesity,x='Age',y='FCVC',hue='FAVC',palette='Dark2',markers='D')

# %%
sns.lmplot(data=obesity,x='FAF',y='FCVC',hue='SMOKE',palette='cubehelix',markers='o')

# %%
sns.lmplot(data=obesity,x='FAF',y='Weight',hue='CALC',palette='muted',markers='s')

# %%
sns.lmplot(data=obesity,x='Age',y='Height',hue='NObeyesdad',palette='bright',markers='*')

# %%
obesity.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
sns.kdeplot(data=obesity,x='Age',color='b',fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=obesity,x='Height',color='k',fill=True)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(data=obesity,x='Weight',color='y',fill=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.kdeplot(data=obesity,x='FCVC',color='r',fill=True)
# Out:
# <Axes: xlabel='FCVC', ylabel='Density'>

# %%
sns.kdeplot(data=obesity,x='NCP',color='m',fill=True)
# Out:
# <Axes: xlabel='NCP', ylabel='Density'>

# %%
sns.kdeplot(data=obesity,x='CH2O',color='Orange',fill=True)
# Out:
# <Axes: xlabel='CH2O', ylabel='Density'>

# %%
obesity.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
sns.jointplot(data=obesity,x='Age',y='Weight',color='c',kind='hex')

# %%
sns.jointplot(data=obesity,x='Height',y='Weight',color='Purple',kind='reg')

# %%
sns.jointplot(data=obesity,x='CH2O',y='NCP',color='g',kind='scatter')

# %%
sns.jointplot(data=obesity,x='FCVC',y='FAF',color='k',kind='hex')

# %%
obesity.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
sns.boxplot(data=obesity,x='Gender',y='Age',palette='RdPu')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(data=obesity,x='family_history_with_overweight',y='Age',palette='seismic')
# Out:
# <Axes: xlabel='family_history_with_overweight', ylabel='Age'>

# %%
sns.boxplot(data=obesity,x='CAEC',y='FCVC',palette='dark')
# Out:
# <Axes: xlabel='CAEC', ylabel='FCVC'>

# %%
sns.boxplot(data=obesity,x='CALC',y='Weight',palette='Set1')
# Out:
# <Axes: xlabel='CALC', ylabel='Weight'>

# %%
sns.boxplot(data=obesity,x='NObeyesdad',y='Weight',palette='YlOrRd')
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='Weight'>

# %%
sns.boxplot(data=obesity,x='MTRANS',y='Age',palette='cubehelix')
# Out:
# <Axes: xlabel='MTRANS', ylabel='Age'>
