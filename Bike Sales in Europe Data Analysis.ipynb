# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
bike = pd.read_csv(r'C:\Users\admin\Downloads\archive\Sales.csv')

# %%
bike.shape
# Out:
# (113036, 18)

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
bike.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
bike.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
len(bike.columns)
# Out:
# 18

# %%
bike.dtypes
# Out:
# Date                object
# Day                  int64
# Month               object
# Year                 int64
# Customer_Age         int64
# Age_Group           object
# Customer_Gender     object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Order_Quantity       int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# dtype: object

# %%
bike.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
bike.describe().transpose()
# Out:
#                    count         mean          std     min     25%     50%  \
# Day             113036.0    15.665753     8.781567     1.0     8.0    16.0
# Year            113036.0  2014.401739     1.272510  2011.0  2013.0  2014.0
# Customer_Age    113036.0    35.919212    11.021936    17.0    28.0    35.0
# Order_Quantity  113036.0    11.901660     9.561857     1.0     2.0    10.0
# Unit_Cost       113036.0   267.296366   549.835483     1.0     2.0     9.0
# Unit_Price      113036.0   452.938427   922.071219     2.0     5.0    24.0
# Profit          113036.0   285.051665   453.887443   -30.0    29.0   101.0
# Cost            113036.0   469.318695   884.866118     1.0    28.0   108.0
# Revenue         113036.0   754.370360  1309.094674     2.0    63.0   223.0
#
#                    75%      max
# Day               23.0     31.0
# Year            2016.0   2016.0
# Customer_Age      43.0     87.0
# Order_Quantity    20.0     32.0
# Unit_Cost         42.0   2171.0
# ...

# %%
bike.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sns.distplot(bike.Day,color='g')
# Out:
# <Axes: xlabel='Day', ylabel='Density'>

# %%
sns.distplot(bike.Year,color='b')
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.distplot(bike.Customer_Age,color='m')
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Density'>

# %%
sns.distplot(bike.Order_Quantity,color='c')
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Density'>

# %%
sns.distplot(bike.Unit_Cost,color='y')
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Density'>

# %%
sns.distplot(bike.Unit_Price,color='k')
# Out:
# <Axes: xlabel='Unit_Price', ylabel='Density'>

# %%
sns.distplot(bike.Profit,color='r')
# Out:
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(bike.Cost,color='orange')
# Out:
# <Axes: xlabel='Cost', ylabel='Density'>

# %%
sns.distplot(bike.Revenue,color='purple')
# Out:
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
bike.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sns.countplot(data=bike,x='Month',palette='mako')
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
sns.countplot(data=bike,x='Age_Group',palette='hls')
# Out:
# <Axes: xlabel='Age_Group', ylabel='count'>

# %%
sns.countplot(data=bike,x='Age_Group',palette='tab20')
# Out:
# <Axes: xlabel='Age_Group', ylabel='count'>

# %%
sns.countplot(data=bike,x='Country',palette='colorblind')
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data=bike,x='Product_Category',palette='magma')
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
sns.countplot(data=bike,x='Sub_Category',palette='Dark2')
# Out:
# <Axes: xlabel='Sub_Category', ylabel='count'>

# %%
bike.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sns.countplot(data=bike,x='Month',hue='Age_Group',palette='deep')
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
sns.countplot(data=bike,x='Customer_Gender',hue='Country',palette='mako')
# Out:
# <Axes: xlabel='Customer_Gender', ylabel='count'>

# %%
sns.countplot(data=bike,x='Age_Group',hue='Customer_Gender',palette='hls')
# Out:
# <Axes: xlabel='Age_Group', ylabel='count'>

# %%
sns.countplot(data=bike,x='Country',hue='Product_Category',palette='dark')
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data=bike,x='Product_Category',hue='Sub_Category',palette='colorblind')
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
sns.countplot(data=bike,x='Age_Group',hue='Country',palette='bright')
# Out:
# <Axes: xlabel='Age_Group', ylabel='count'>

# %%
sns.countplot(data=bike,x='Product_Category',hue='Age_Group',palette='rocket')
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
bike.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sns.lmplot(data=bike,x='Day',y='Year',palette='muted',hue='Month')

# %%
sns.lmplot(data=bike,x='Customer_Age',y='Order_Quantity',palette='PuBuGn',hue='Age_Group')

# %%
sns.lmplot(data=bike,x='Unit_Cost',y='Unit_Price',palette='dark',hue='Customer_Gender')

# %%
sns.lmplot(data=bike,x='Profit',y='Cost',palette='rocket',hue='Country')

# %%
sns.lmplot(data=bike,x='Revenue',y='Year',palette='viridis',hue='Product_Category')

# %%
sns.lmplot(data=bike,x='Day',y='Customer_Age',palette='cubehelix',hue='Sub_Category')

# %%
sns.lmplot(data=bike,x='Year',y='Profit',palette='magma',hue='Customer_Gender')

# %%
sns.lmplot(data=bike,x='Year',y='Cost',palette='Dark2',hue='Country')

# %%
bike.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sns.boxplot(data=bike,x='Month',y='Day',palette='viridis')
# Out:
# <Axes: xlabel='Month', ylabel='Day'>

# %%
sns.boxplot(data=bike,x='Age_Group',y='Order_Quantity',palette='magma')
# Out:
# <Axes: xlabel='Age_Group', ylabel='Order_Quantity'>

# %%
sns.boxplot(data=bike,x='Country',y='Unit_Price',palette='colorblind')
# Out:
# <Axes: xlabel='Country', ylabel='Unit_Price'>

# %%
bike.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sns.kdeplot(data=bike,x='Day',hue='Month',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Day', ylabel='Density'>

# %%
sns.kdeplot(data=bike,x='Customer_Age',hue='Customer_Gender',palette='magma',fill=True)
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Density'>

# %%
sns.kdeplot(data=bike,x='Year',hue='Age_Group',palette='muted',fill=True)
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.kdeplot(data=bike,x='Order_Quantity',hue='Country',palette='cividis',fill=True)
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Density'>

# %%
sns.kdeplot(data=bike,x='Unit_Cost',hue='Product_Category',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Density'>

# %%
sns.kdeplot(data=bike,x='Unit_Price',hue='Sub_Category',palette='dark',fill=True)
# Out:
# <Axes: xlabel='Unit_Price', ylabel='Density'>

# %%
sns.kdeplot(data=bike,x='Profit',hue='Age_Group',palette='hls',fill=True)
# Out:
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
sns.kdeplot(data=bike,x='Cost',hue='Customer_Gender',palette='deep',fill=True)
# Out:
# <Axes: xlabel='Cost', ylabel='Density'>

# %%
sns.kdeplot(data=bike,x='Revenue',hue='Product_Category',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
bike.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sns.jointplot(data=bike,x='Day',y='Year',color='m',kind='reg')

# %%
sns.jointplot(data=bike,x='Customer_Age',y='Order_Quantity',color='c',kind='hex')

# %%
sns.jointplot(data=bike,x='Unit_Cost',y='Unit_Price',color='g',kind='scatter')

# %%
sns.jointplot(data=bike,x='Revenue',y='Customer_Age',color='k',kind='resid')

# %%
sns.jointplot(data=bike,x='Profit',y='Revenue',color='r',kind='hex')
