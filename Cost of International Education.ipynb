# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="mako")

# %%
cost=pd.read_csv(r'C:\Users\admin\Downloads\archive\International_Education_Costs.csv')

# %%
cost
# Out:
#           Country        City                      University  \
# 0             USA   Cambridge              Harvard University
# 1              UK      London         Imperial College London
# 2          Canada     Toronto           University of Toronto
# 3       Australia   Melbourne         University of Melbourne
# 4         Germany      Munich  Technical University of Munich
# ..            ...         ...                             ...
# 902        France  Strasbourg        University of Strasbourg
# 903      Malaysia       Nilai                            USIM
# 904  Saudi Arabia     Al-Ahsa          King Faisal University
# 905           USA     Seattle        University of Washington
# 906            UK  Nottingham        University of Nottingham
#
#                     Program     Level  Duration_Years  Tuition_USD  \
# 0          Computer Science    Master             2.0        55400
# 1              Data Science    Master             1.0        41200
# ...

# %%
cost.shape
# Out:
# (907, 12)

# %%
cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    object
#  1   City               907 non-null    object
#  2   University         907 non-null    object
#  3   Program            907 non-null    object
#  4   Level              907 non-null    object
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 85.2+ KB

# %%
cost.isnull().sum()
# Out:
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64

# %%
cost.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='object')

# %%
len(cost.columns)
# Out:
# 12

# %%
cost.dtypes
# Out:
# Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
cost.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# ...

# %%
cost.describe().transpose()
# Out:
#                    count          mean           std     min      25%  \
# Duration_Years     907.0      2.836825      0.945449    1.00     2.00
# Tuition_USD        907.0  16705.016538  16582.385275    0.00  2850.00
# Living_Cost_Index  907.0     64.437486     14.056333   27.80    56.30
# Rent_USD           907.0    969.206174    517.154752  150.00   545.00
# Visa_Fee_USD       907.0    211.396913    143.435740   40.00   100.00
# Insurance_USD      907.0    700.077178    320.374875  200.00   450.00
# Exchange_Rate      907.0    623.000695   3801.746134    0.15     0.92
#
#                        50%       75%      max
# Duration_Years        3.00      4.00      5.0
# Tuition_USD        7500.00  31100.00  62000.0
# Living_Cost_Index    67.50     72.20    122.4
# Rent_USD            900.00   1300.00   2500.0
# Visa_Fee_USD        160.00    240.00    490.0
# Insurance_USD       650.00    800.00   1500.0
# Exchange_Rate         1.35      7.15  42150.0

# %%
cost.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
sns.distplot(cost.Duration_Years,color='g',bins=15)
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Density'>

# %%
sns.distplot(cost.Tuition_USD,color='c',bins=15)
# Out:
# <Axes: xlabel='Tuition_USD', ylabel='Density'>

# %%
sns.distplot(cost.Rent_USD,color='m',bins=15)
# Out:
# <Axes: xlabel='Rent_USD', ylabel='Density'>

# %%
sns.distplot(cost.Visa_Fee_USD,color='k',bins=15)
# Out:
# <Axes: xlabel='Visa_Fee_USD', ylabel='Density'>

# %%
sns.distplot(cost.Insurance_USD,color='b',bins=15)
# Out:
# <Axes: xlabel='Insurance_USD', ylabel='Density'>

# %%
sns.distplot(cost.Exchange_Rate,color='y',bins=15)
# Out:
# <Axes: xlabel='Exchange_Rate', ylabel='Density'>

# %%
sns.distplot(cost.Living_Cost_Index,color='purple',bins=15)
# Out:
# <Axes: xlabel='Living_Cost_Index', ylabel='Density'>

# %%
sns.countplot(data=cost,x='Level',palette='magma')
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
cost.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
sns.lmplot(data=cost,x='Duration_Years',y='Tuition_USD',palette='dark',hue='Level')

# %%
sns.lmplot(data=cost,x='Tuition_USD',y='Living_Cost_Index',palette='hls',hue='Level')

# %%
sns.lmplot(data=cost,x='Living_Cost_Index',y='Rent_USD',palette='mako',hue='Level')

# %%
sns.lmplot(data=cost,x='Insurance_USD',y='Exchange_Rate',palette='rocket',hue='Level')

# %%
sns.lmplot(data=cost,x='Rent_USD',y='Visa_Fee_USD',palette='colorblind',hue='Level')

# %%
sns.lmplot(data=cost,x='Visa_Fee_USD',y='Insurance_USD',palette='deep',hue='Level')

# %%
sns.lmplot(data=cost,x='Exchange_Rate',y='Duration_Years',palette='Dark2',hue='Level')

# %%
sns.jointplot(data=cost,x='Duration_Years',y='Tuition_USD',palette='dark',hue='Level')

# %%
sns.jointplot(data=cost,x='Tuition_USD',y='Living_Cost_Index',palette='hls',hue='Level')

# %%
sns.jointplot(data=cost,x='Living_Cost_Index',y='Rent_USD',palette='mako',hue='Level')

# %%
sns.jointplot(data=cost,x='Rent_USD',y='Visa_Fee_USD',palette='colorblind',hue='Level')

# %%
sns.jointplot(data=cost,x='Visa_Fee_USD',y='Insurance_USD',palette='deep',hue='Level')

# %%
sns.jointplot(data=cost,x='Exchange_Rate',y='Duration_Years',palette='Dark2',hue='Level')

# %%
cost.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
sns.jointplot(data=cost,x='Duration_Years',y='Tuition_USD',color='c',kind='hex')

# %%
sns.jointplot(data=cost,x='Tuition_USD',y='Living_Cost_Index',color='m',kind='resid')

# %%
sns.jointplot(data=cost,x='Living_Cost_Index',y='Rent_USD',color='k',kind='scatter')

# %%
sns.jointplot(data=cost,x='Rent_USD',y='Visa_Fee_USD',color='orange',kind='hex')

# %%
sns.jointplot(data=cost,x='Visa_Fee_USD',y='Insurance_USD',color='b',kind='reg')

# %%
sns.jointplot(data=cost,x='Insurance_USD',y='Exchange_Rate',color='g',kind='kde')

# %%
sns.jointplot(data=cost,x='Exchange_Rate',y='Duration_Years',color='r',kind='hex')

# %%
cost.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
sns.boxplot(data=cost,x='Level',y='Duration_Years',palette='dark')
# Out:
# <Axes: xlabel='Level', ylabel='Duration_Years'>

# %%
sns.boxplot(data=cost,x='Level',y='Tuition_USD',palette='tab10')
# Out:
# <Axes: xlabel='Level', ylabel='Tuition_USD'>

# %%
sns.boxplot(data=cost,x='Level',y='Living_Cost_Index',palette='magma')
# Out:
# <Axes: xlabel='Level', ylabel='Living_Cost_Index'>

# %%
sns.boxplot(data=cost,x='Level',y='Rent_USD',palette='mako')
# Out:
# <Axes: xlabel='Level', ylabel='Rent_USD'>

# %%
sns.boxplot(data=cost,x='Level',y='Insurance_USD',palette='rocket')
# Out:
# <Axes: xlabel='Level', ylabel='Insurance_USD'>

# %%
sns.boxplot(data=cost,x='Level',y='Visa_Fee_USD',palette='colorblind')
# Out:
# <Axes: xlabel='Level', ylabel='Visa_Fee_USD'>

# %%
cost.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
sns.stripplot(data=cost,x='Level',y='Tuition_USD',palette='deep')
# Out:
# <Axes: xlabel='Level', ylabel='Tuition_USD'>

# %%
sns.stripplot(data=cost,x='Level',y='Duration_Years',palette='mako')
# Out:
# <Axes: xlabel='Level', ylabel='Duration_Years'>

# %%
sns.stripplot(data=cost,x='Level',y='Living_Cost_Index',palette='tab20')
# Out:
# <Axes: xlabel='Level', ylabel='Living_Cost_Index'>

# %%
sns.stripplot(data=cost,x='Level',y='Rent_USD',palette='Dark2')
# Out:
# <Axes: xlabel='Level', ylabel='Rent_USD'>

# %%
sns.stripplot(data=cost,x='Level',y='Insurance_USD',palette='rocket')
# Out:
# <Axes: xlabel='Level', ylabel='Insurance_USD'>

# %%
sns.stripplot(data=cost,x='Level',y='Visa_Fee_USD',palette='colorblind')
# Out:
# <Axes: xlabel='Level', ylabel='Visa_Fee_USD'>

# %%
sns.stripplot(data=cost,x='Level',y='Exchange_Rate',palette='magma')
# Out:
# <Axes: xlabel='Level', ylabel='Exchange_Rate'>

# %%
cost.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
sns.kdeplot(data=cost,x='Duration_Years',hue='Level',palette='mako',fill=True)
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Density'>

# %%
sns.kdeplot(data=cost,x='Living_Cost_Index',hue='Level',palette='Dark2',fill=True)
# Out:
# <Axes: xlabel='Living_Cost_Index', ylabel='Density'>

# %%
sns.kdeplot(data=cost,x='Tuition_USD',hue='Level',palette='deep',fill=True)
# Out:
# <Axes: xlabel='Tuition_USD', ylabel='Density'>

# %%
sns.kdeplot(data=cost,x='Rent_USD',hue='Level',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='Rent_USD', ylabel='Density'>

# %%
sns.kdeplot(data=cost,x='Visa_Fee_USD',hue='Level',palette='bright',fill=True)
# Out:
# <Axes: xlabel='Visa_Fee_USD', ylabel='Density'>

# %%
sns.kdeplot(data=cost,x='Insurance_USD',hue='Level',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='Insurance_USD', ylabel='Density'>

# %%
sns.kdeplot(data=cost,x='Exchange_Rate',hue='Level',palette='colorblind',fill=True)
# Out:
# <Axes: xlabel='Exchange_Rate', ylabel='Density'>
