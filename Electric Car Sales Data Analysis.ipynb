# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=6,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
car=pd.read_csv(r'C:\Users\admin\Downloads\archive\IEA-EV-dataEV salesHistoricalCars.csv')

# %%
car
# Out:
#          region    category           parameter  mode powertrain  year  \
# 0     Australia  Historical            EV sales  Cars        BEV  2011
# 1     Australia  Historical      EV stock share  Cars         EV  2011
# 2     Australia  Historical      EV sales share  Cars         EV  2011
# 3     Australia  Historical            EV stock  Cars        BEV  2011
# 4     Australia  Historical            EV stock  Cars        BEV  2012
# ...         ...         ...                 ...   ...        ...   ...
# 3793      World  Historical            EV stock  Cars        BEV  2023
# 3794      World  Historical            EV sales  Cars        BEV  2023
# 3795      World  Historical      EV sales share  Cars         EV  2023
# 3796      World  Historical      EV stock share  Cars         EV  2023
# 3797      World  Historical  Electricity demand  Cars         EV  2023
#
#           unit         value
# 0     Vehicles  4.900000e+01
# 1      percent  3.900000e-04
# ...

# %%
car.shape
# Out:
# (3798, 8)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3798 entries, 0 to 3797
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      3798 non-null   object
#  1   category    3798 non-null   object
#  2   parameter   3798 non-null   object
#  3   mode        3798 non-null   object
#  4   powertrain  3798 non-null   object
#  5   year        3798 non-null   int64
#  6   unit        3798 non-null   object
#  7   value       3798 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 237.5+ KB

# %%
car.isnull().sum()
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
car.dtypes
# Out:
# region         object
# category       object
# parameter      object
# mode           object
# powertrain     object
# year            int64
# unit           object
# value         float64
# dtype: object

# %%
car.columns
# Out:
# Index(['region', 'category', 'parameter', 'mode', 'powertrain', 'year', 'unit',
#        'value'],
#       dtype='object')

# %%
len(car.columns)
# Out:
# 8

# %%
car.describe()
# Out:
#               year         value
# count  3798.000000  3.798000e+03
# mean   2017.369932  1.009542e+05
# std       3.809226  8.184402e+05
# min    2010.000000  1.500000e-05
# 25%    2014.000000  2.300000e+00
# 50%    2018.000000  1.900000e+02
# 75%    2021.000000  6.800000e+03
# max    2023.000000  2.800000e+07

# %%
car.describe().transpose()
# Out:
#         count           mean            std          min     25%     50%  \
# year   3798.0    2017.369932       3.809226  2010.000000  2014.0  2018.0
# value  3798.0  100954.233007  818440.248406     0.000015     2.3   190.0
#
#           75%         max
# year   2021.0      2023.0
# value  6800.0  28000000.0

# %%
car.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
sns.distplot(car.year,color='r',bins=10)
# Out:
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.distplot(car.value,color='c',bins=10)
# Out:
# <Axes: xlabel='value', ylabel='Density'>

# %%
car.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
sns.countplot(data=car,x='parameter',palette='dark')
# Out:
# <Axes: xlabel='parameter', ylabel='count'>

# %%
sns.countplot(data=car,x='powertrain',palette='rocket')
# Out:
# <Axes: xlabel='powertrain', ylabel='count'>

# %%
sns.countplot(data=car,x='unit',palette='Dark2')
# Out:
# <Axes: xlabel='unit', ylabel='count'>

# %%
car.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
sns.countplot(data=car,x='category',hue='parameter',palette='dark')
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
sns.countplot(data=car,x='mode',hue='parameter',palette='rocket')
# Out:
# <Axes: xlabel='mode', ylabel='count'>

# %%
sns.countplot(data=car,x='powertrain',hue='parameter',palette='cividis')
# Out:
# <Axes: xlabel='powertrain', ylabel='count'>

# %%
sns.countplot(data=car,x='mode',hue='powertrain',palette='mako')
# Out:
# <Axes: xlabel='mode', ylabel='count'>

# %%
sns.countplot(data=car,x='unit',hue='powertrain',palette='Set1')
# Out:
# <Axes: xlabel='unit', ylabel='count'>

# %%
car.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
sns.lmplot(data=car,x='year',y='value',palette='deep',hue='parameter')

# %%
sns.lmplot(data=car,x='year',y='value',palette='rocket',hue='powertrain')

# %%
sns.lmplot(data=car,x='year',y='value',palette='dark',hue='region')

# %%
sns.jointplot(data=car,x='year',y='value',palette='colorblind',hue='parameter')

# %%
sns.jointplot(data=car,x='year',y='value',palette='mako',hue='powertrain')

# %%
sns.jointplot(data=car,x='year',y='value',palette='Dark2',hue='region')

# %%
sns.jointplot(data=car,x='year',y='value',palette='muted',hue='unit')

# %%
car.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
sns.boxenplot(data=car,x='parameter',y='value',palette='cividis')
# Out:
# <Axes: xlabel='parameter', ylabel='value'>

# %%
sns.boxenplot(data=car,x='mode',y='value',palette='dark')
# Out:
# <Axes: xlabel='mode', ylabel='value'>

# %%
sns.boxenplot(data=car,x='powertrain',y='value',palette='tab20')
# Out:
# <Axes: xlabel='powertrain', ylabel='value'>

# %%
sns.boxenplot(data=car,x='unit',y='value',palette='rocket')
# Out:
# <Axes: xlabel='unit', ylabel='value'>

# %%
car.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
sns.stripplot(data=car,x='parameter',y='year',palette='hls')
# Out:
# <Axes: xlabel='parameter', ylabel='year'>

# %%
sns.stripplot(data=car,x='powertrain',y='value',palette='dark')
# Out:
# <Axes: xlabel='powertrain', ylabel='value'>

# %%
sns.stripplot(data=car,x='unit',y='value',palette='rocket')
# Out:
# <Axes: xlabel='unit', ylabel='value'>

# %%
sns.stripplot(data=car,x='parameter',y='year',palette='Dark2')
# Out:
# <Axes: xlabel='parameter', ylabel='year'>

# %%
sns.stripplot(data=car,x='powertrain',y='value',palette='colorblind')
# Out:
# <Axes: xlabel='powertrain', ylabel='value'>

# %%
car.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
sns.kdeplot(data=car,x='year',hue='parameter',palette='cubehelix',fill=True)
# Out:
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='year',hue='powertrain',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.kdeplot(data=car,x='year',hue='unit',palette='mako',fill=True)
# Out:
# <Axes: xlabel='year', ylabel='Density'>
