# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=8,3
sns.set_theme(style="whitegrid", palette="dark")

# %%
insurance=pd.read_csv(r'C:\Users\admin\Downloads\archive\insurance.csv')

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance.shape
# Out:
# (1338, 7)

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
len(insurance.columns)
# Out:
# 7

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance.describe().transpose()
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.distplot(insurance.age,color='m',bins=10)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(insurance.charges,color='g',bins=10)
# Out:
# <Axes: xlabel='charges', ylabel='Density'>

# %%
sns.distplot(insurance.bmi,color='r',bins=10)
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(insurance.children,color='c',bins=10)
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.countplot(data=insurance,x='sex',palette='dark')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=insurance,x='children',palette='rocket')
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(data=insurance,x='smoker',palette='Set1')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=insurance,x='region',palette='mako')
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.countplot(data=insurance,x='sex',palette='magma',hue='children')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=insurance,x='smoker',palette='colorblind',hue='sex')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=insurance,x='smoker',palette='ch:23',hue='region')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=insurance,x='region',palette='Dark2',hue='sex')
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.boxplot(data=insurance,x='sex',y='age',palette='hls')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=insurance,x='smoker',y='bmi',palette='mako')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.boxplot(data=insurance,x='region',y='charges',palette='dark')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.boxplot(data=insurance,x='sex',y='children',palette='colorblind')
# Out:
# <Axes: xlabel='sex', ylabel='children'>

# %%
sns.boxplot(data=insurance,x='smoker',y='bmi',palette='rocket')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.boxplot(data=insurance,x='region',y='age',palette='cividis')
# Out:
# <Axes: xlabel='region', ylabel='age'>

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.stripplot(data=insurance,x='sex',y='age',palette='hls')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(data=insurance,x='smoker',y='bmi',palette='mako')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.stripplot(data=insurance,x='region',y='charges',palette='dark')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.stripplot(data=insurance,x='smoker',y='bmi',palette='rocket')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.stripplot(data=insurance,x='region',y='age',palette='cividis')
# Out:
# <Axes: xlabel='region', ylabel='age'>

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.lmplot(data=insurance,x='age',y='bmi',palette='dark',hue='sex')

# %%
sns.lmplot(data=insurance,x='age',y='children',palette='ch:23',hue='smoker')

# %%
sns.lmplot(data=insurance,x='age',y='charges',palette='rocket',hue='region')

# %%
sns.lmplot(data=insurance,x='bmi',y='charges',palette='colorblind',hue='sex')

# %%
sns.lmplot(data=insurance,x='children',y='charges',palette='magma',hue='region')

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.kdeplot(data=insurance,x='age',hue='sex',palette='dark',fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=insurance,x='bmi',hue='region',palette='hls',fill=True)
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
sns.kdeplot(data=insurance,x='children',hue='smoker',palette='Set1',fill=True)
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
sns.kdeplot(data=insurance,x='charges',hue='smoker',palette='rocket',fill=True)
# Out:
# <Axes: xlabel='charges', ylabel='Density'>

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.pairplot(insurance, hue="sex",palette='Dark2')

# %%
sns.pairplot(insurance, hue="smoker",palette='Set1')

# %%
sns.pairplot(insurance, hue="region",palette='magma')
